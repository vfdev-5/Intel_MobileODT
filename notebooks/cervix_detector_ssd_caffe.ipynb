# %% [markdown]
# # Cervix detector with [Single Shot Detector (SSD)](https://github.com/weiliu89/caffe/tree/ssd)
#
# Use Caffe-MSLS
#
#
# Useful links :
#
# - [Train SSD on custom dataset](https://github.com/weiliu89/caffe/wiki/Train-SSD-on-custom-dataset)
#
# - [SSD detect notebook](https://github.com/weiliu89/caffe/blob/ssd/examples/ssd_detect.ipynb)
#
# - [SSD notebook](https://github.com/weiliu89/caffe/tree/ssd)

# %%
# https://ipython.org/ipython-doc/3/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

# %%
sys.path.append(os.path.join("..","common"))

# %% [markdown]
# ## Check available `Caffe` distributions

# %%
# !ls /opt/caffe*
# Out:
# /opt/caffe-master:
# build		 data	     include	      Makefile.config.example  src
# caffe.cloc	 distribute  INSTALL.md       matlab		       tools
# cmake		 docker      LICENSE	      models		       xbyak
# CMakeLists.txt	 docs	     Makefile	      python
# CONTRIBUTING.md  examples    Makefile.bak     README.md
# CONTRIBUTORS.md  external    Makefile.config  scripts
#
# /opt/caffe-mlsl:
# build		 data	     include		      matlab	 tools
# caffe.cloc	 distribute  INSTALL.md		      models	 xbyak
# cmake		 docker      LICENSE		      python
# CMakeLists.txt	 docs	     Makefile		      README.md
# CONTRIBUTING.md  examples    Makefile.config	      scripts
# CONTRIBUTORS.md  external    Makefile.config.example  src

# %%
#!diff /opt/caffe-master/Makefile.config  /opt/caffe-mlsl/Makefile.config

# %% [markdown]
# ## Setup `Caffe` and check SSD512\* model

# %%
#os.environ["CAFFE_ROOT"] = "/opt/caffe-master"
os.environ["CAFFE_ROOT"] = "/opt/caffe-mlsl"
os.environ["PATH"] += ":%s/build/tools" % os.environ["CAFFE_ROOT"]
# LD_LIBRARY_PATH is setup in .bash_profile
# os.environ["LD_LIBRARY_PATH"] += ":%s/external/mkl/mklml_lnx_2017.0.2.20170110/lib" % os.environ["CAFFE_ROOT"]
# os.environ["LD_LIBRARY_PATH"] += ":/opt/intel/mlsl_2017.0.006/intel64/lib"

# %%
sys.path.append("%s/python" % os.environ["CAFFE_ROOT"])

# %%
# !ls "$CAFFE_ROOT"/models/intel_optimized_models
# Out:
# alexnet  googlenet  googlenet_v2  resnet_50

# %% [markdown]
# ## Setup trainval datasets

# %%
from data_utils import get_annotations
from PIL import Image

# %%
labels_dict = {
    'os': 0,
    'cervix': 1,
}
sloth_annotations_filename =  os.path.join('..', 'resources', 'cervix_os.json')

# %%
def write_images_labels(data_path, annotations, labels_dict, output_path):
    """
    Method to convert create image files (sym links) and txt annotations and write a listfile
    
    - plain txt detection annotation: label_id, xmin, ymin, xmax, ymax
    """
    output_images_folder = os.path.join(output_path, "images")
    os.makedirs(output_images_folder)
    
    output_labels_folder = os.path.join(output_path, "labels")
    os.makedirs(output_labels_folder)
    
    def _clamp(x, dim):
        return min(max(x, 0), dim-1)
    
    listfile = os.path.join(output_path, "listfile.txt")
    with open(listfile, 'w') as listfile_writer:    
        for annotation in annotations:
            img_filename = annotation['filename']
            basename, ext = os.path.splitext(os.path.basename(img_filename))
            basename = os.path.split(os.path.dirname(img_filename))[1] + '_' + basename
            src_image_filename = os.path.abspath(os.path.join(data_path, img_filename))
            dst_image_filename = "%s%s" % (basename,ext)
            dst_label_filename = "%s.txt" % basename
            listfile_writer.write("%s %s\n" % (os.path.join("images", dst_image_filename), 
                                               os.path.join("labels", dst_label_filename)))
                                  
            dst_image_filename = os.path.abspath(os.path.join(output_images_folder, dst_image_filename))
            dst_label_filename = os.path.abspath(os.path.join(output_labels_folder, dst_label_filename))
            os.symlink(src_image_filename, dst_image_filename)
            pil_image = Image.open(img_filename)
            image_size = pil_image.size       

            with open(dst_label_filename, 'w') as writer:
                for obj in annotation['annotations']:
                    # format : class_name bbox_left bbox_top bbox_right bbox_bottom
                    l, t, w, h = int(obj['x']), int(obj['y']), int(obj['width']), int(obj['height'])
                    r = l+w; b = t+h
                    l = _clamp(l, image_size[0])
                    t = _clamp(t, image_size[1])
                    r = _clamp(r, image_size[0])
                    b = _clamp(b, image_size[1])
                    line = "{label_id} {l} {t} {r} {b}\n".format(
                        label_id=labels_dict[obj['class']],
                        l=l, t=t, r=r, b=b
                    )   
                    writer.write(line)

    return output_images_folder, output_labels_folder, listfile

# %%
import numpy as np
np.random.seed(2017)

train_test_split = 0.75

annotations = get_annotations(sloth_annotations_filename)
# Create data split
num_labels = len(annotations)
indices = np.random.permutation(num_labels)
split_index = int(num_labels * train_test_split)
train_annotations = np.array(annotations)[indices[:split_index]]
test_annotations = np.array(annotations)[indices[split_index:]]

print "Total : %s, Train : %s, Val : %s" % (num_labels, len(train_annotations), len(test_annotations))
# Out:
# Total : 208, Train : 156, Val : 52

# %% [markdown]
# Create LMDB for training and validation datasets

# %%
INPUT_DATA = os.path.abspath(os.path.join("..", "input"))
RESOURCES_PATH = os.path.abspath(os.path.join("..", "resources"))
GENERATED_DATA = os.path.abspath(os.path.join(INPUT_DATA, "generated"))

# %%
label_map_filename = os.path.join(RESOURCES_PATH,"labelmap_ccs.prototxt")

# %%
import shutil

for _dataset, _annotations in zip(['train', 'val'], [train_annotations, test_annotations]):
    
    _dataset_path = os.path.join(GENERATED_DATA, _dataset)

    if os.path.exists(os.path.join(_dataset_path, _dataset + ".lmdb")):
        print("Found existing file: ", os.path.join(_dataset_path, _dataset + ".lmdb"))
        continue
    
    if os.path.isdir(_dataset_path):
        shutil.rmtree(_dataset_path)        
    ret = write_images_labels(RESOURCES_PATH, _annotations, labels_dict, _dataset_path)
    output_images_folder, output_labels_folder, listfile = ret
    
    args = [
        # See the code source : https://github.com/intel/caffe/blob/master/tools/convert_annoset.cpp 
        "--anno_type=detection", # The type of annotation {classification, detection}.
        "--label_type=txt", # The type of label file format for detection {xml, json, txt}.
        "--backend=lmdb",
        "--label_map_file=" + label_map_filename, # A file with LabelMap protobuf message.
        "--check_label=True", # Check that there is no duplicated name/label. 
        "--resize_height=512", # Height images are resized to.
        "--resize_width=512", # Width images are resized to.
        "--encode_type=png", 
        "--encoded=True",
        "--shuffle=True", # Randomly shuffle the order of images and their labels.
        os.path.join(GENERATED_DATA, _dataset_path) + '/', # root, The root directory which contains the images and annotations.
        os.path.join(RESOURCES_PATH, listfile), # listfile, The file which contains image paths and annotation info paths.
        os.path.join(_dataset_path, _dataset + ".lmdb"), # outdir, The output directory which stores the database file.        
    ]
    
    args_str = " ".join(args)
    qsub_script = "\"#PBS -V -I -x -N convert_annoset\nconvert_annoset %s\"" % args_str
    # !echo {qsub_script} > qsub_script
    # !chmod +x qsub_script
    # !qsub $PWD/qsub_script    
    
    # !rm $PWD/qsub_script
# Out:
# ('Found existing file: ', '/home/u2459/Intel_MobileODT/input/generated/train/train.lmdb')
# ('Found existing file: ', '/home/u2459/Intel_MobileODT/input/generated/val/val.lmdb')

# %%
# !echo Training : $(ls {GENERATED_DATA}/train)
# !echo Validation : $(ls {GENERATED_DATA}/val)
# Out:
# Training : images labels listfile.txt train.lmdb
# Validation : detection_out images labels listfile.txt val.lmdb

# %% [markdown]
# ## Setup network and solver
#
# Following https://github.com/intel/caffe/wiki/SSD:-Single-Shot-MultiBox-Detector

# %%
ssd300_path = os.path.join(RESOURCES_PATH, "SSD_300x300")
weights_filename = os.path.join(ssd300_path, "VGG_ILSVRC_16_layers_fc_reduced.caffemodel")

if not os.path.exists(weights_filename):
    # !cd {RESOURCES_PATH}/SSD_300x300 && wget http://cs.unc.edu/~wliu/projects/ParseNet/VGG_ILSVRC_16_layers_fc_reduced.caffemodel -o {weights_filename}

# %%
import caffe
from caffe.proto import caffe_pb2

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 10)
plt.rcParams['image.interpolation'] = 'none'

# solver = caffe.SGDSolver(os.path.join(ssd300_path, "solver.prototxt"))

# # input preprocessing: 'data' is the name of the input blob == net.inputs[0]
# transformer = caffe.io.Transformer({'data': solver.net.blobs['data'].data.shape})
# transformer.set_transpose('data', (2, 0, 1))
# transformer.set_mean('data', np.array([104,117,123])) # mean pixel
# transformer.set_raw_scale('data', 255)  # the reference model operates on images in [0,255] range instead of [0,1]
# transformer.set_channel_swap('data', (2,1,0))  # the reference model has channels in BGR order instead of RGB

# net = solver.net
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-003047d9884d> in <module>()
# ----> 1 import caffe
#       2 from caffe.proto import caffe_pb2
#       3
#       4 import matplotlib.pyplot as plt
#       5 get_ipython().magic(u'matplotlib inline')
#
# /opt/caffe-mlsl/python/caffe/__init__.py in <module>()
#      35 # OF THIS SOFTWARE, EVEN IF ADVISED OF THE POSSIBILITY OF SUCH DAMAGE.
#      36 #
# ---> 37 from .pycaffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, RMSPropSolver, AdaDeltaSolver, AdamSolver
#      38 from ._caffe import set_mode_cpu, set_mode_gpu, set_device, Layer, get_solver, layer_type_list, set_random_seed
#      39 from ._caffe import __version__
#
# /opt/caffe-mlsl/python/caffe/pycaffe.py in <module>()
#      47 import numpy as np
#      48
# ---> 49 from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \
#      50         RMSPropSolver, AdaDeltaSolver, AdamSolver
#      51 import caffe.io
#
# ImportError: /opt/caffe-mlsl/python/caffe/../../build/lib/libcaffe.so.1.0.0-rc3: undefined symbol: __isnormalf

# %%
batch_size = 32
n_epochs = 100
data_augmentation_factor = 7
train_dataset_size = !cat {GENERATED_DATA}/train/listfile.txt | wc -l
train_dataset_size = int(train_dataset_size[0])
val_dataset_size = !cat {GENERATED_DATA}/val/listfile.txt | wc -l
val_dataset_size = int(val_dataset_size[0])

train_dataset_size, val_dataset_size

n_train_iterations = int(data_augmentation_factor * train_dataset_size * n_epochs * 1.0 / batch_size + 0.5)
n_train_iterations_per_epoch = int(data_augmentation_factor * train_dataset_size * 1.0 / batch_size + 0.5)
n_val_iterations = int(val_dataset_size * 1.0 / batch_size + 0.5)

n_iterations = n_train_iterations + n_val_iterations


print("max_iter", n_train_iterations)
print("test_iter", n_val_iterations)
print("test_interval", n_train_iterations_per_epoch)
# Out:
# ('max_iter', 3413)
# ('test_iter', 2)
# ('test_interval', 34)

# %%
#train_dataset_filename = os.path.join(GENERATED_DATA, "train", "train.lmdb")
#val_dataset_filename = os.path.join(GENERATED_DATA, "train", "val.lmdb")

# %% [markdown]
# ## Train network

# %%
from datetime import datetime

# Create job folder
JOBS_PATH = os.path.join(GENERATED_DATA, 'jobs')
if not os.path.exists(JOBS_PATH):
    os.makedirs(JOBS_PATH)

# Create current job path
#now = datetime.now()
#current_job_path = os.path.join(JOBS_PATH, "train_%s" % str(now.strftime("%Y-%m-%d-%H-%M")))
#os.makedirs(current_job_path)

# %%
# !ls {GENERATED_DATA}
# !ls {JOBS_PATH}
# Out:
# ls: cannot access {GENERATED_DATA}: No such file or directory
# ls: cannot access {JOBS_PATH}: No such file or directory

# %%
from qsub_utils import submit_job
from qsub_utils import setup_configuration
from qsub_utils import PBS_CONFIGURATION
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-668a5d2888c2> in <module>()
# ----> 1 from qsub_utils import submit_job
#       2 from qsub_utils import setup_configuration
#       3 from qsub_utils import PBS_CONFIGURATION
#
# ImportError: No module named qsub_utils

# %%
setup_configuration(nodes='4:knl7210:ram96gb')

# %%
# !cat {os.path.join(ssd300_path, "solver.prototxt")}
# Out:
# ###### Networks ######
# train_net: "train.prototxt"
# test_net: "val.prototxt"
# ###### Training parameters ######
# base_lr: 0.0001
# max_iter: 3413
# lr_policy: "exp"
# gamma: 0.975
# weight_decay: 7e-07
# ###### Validation parameters ######
# test_iter: 2
# test_interval: 34
# test_initialization: false
# ###### Optimizer ######
# type: "AdaDelta"
# momentum: 0.9
# ###### Other ######
# display: 5
# solver_mode: CPU
# snapshot: 34
# snapshot_prefix: "snapshot_VGG_VOC0712_SSD_300x300"
# debug_info: false
# snapshot_after_train: true
# average_loss: 34
# iter_size: 1
# eval_type: "detection"
# ap_version: "11point"

# %%
import time 

caffe_train_cmd = [
    "caffe",
    "train",
    "-solver", os.path.join(ssd300_path, "solver.prototxt"),
    #"-weights", weights_filename
]

process, job_info = submit_job(caffe_train_cmd, name='caffe_train_ssd300', cwd=ssd300_path)

try:
    while True:
        out = process.stdout.readline()    
        if len(out) > 0:        
            print out

        if process.poll() is not None and len(out) == 0:
            break
except KeyboardInterrupt:
    # !qdel {job_info['id']}
    time.sleep(1.0)
    # !qstat
# Out:
# qsub: job 4237.c001 ready
#
#
#
#
#
#   ########################################################################
#
#   # Colfax Cluster - https://colfaxresearch.com/
#
#   #      Date:           Thu Mar 23 09:07:31 PDT 2017
#
#   #    Job ID:           4237.c001
#
#   #      User:           u2459
#
#   # Resources:           neednodes=4:knl7210:ram96gb,nodes=4:knl7210:ram96gb,walltime=24:00:00
#
#   ########################################################################
#
#
#
# I0323 09:07:33.506315 190428 caffe.cpp:274] Use CPU.
#
# I0323 09:07:33.507730 190428 solver.cpp:108] Initializing solver from parameters:
#
# train_net: "train.prototxt"
#
# test_net: "val.prototxt"
#
# test_iter: 2
#
# test_interval: 34
#
# base_lr: 0.0001
#
# display: 5
#
# max_iter: 3413
#
# lr_policy: "exp"
#
# gamma: 0.975
#
# momentum: 0.9
#
# weight_decay: 7e-07
#
# snapshot: 34
#
# snapshot_prefix: "snapshot_VGG_VOC0712_SSD_300x300"
#
# solver_mode: CPU
#
# debug_info: false
#
# train_state {
#
#   level: 0
#
#   stage: ""
#
# }
#
# snapshot_after_train: true
#
# test_initialization: false
#
# average_loss: 34
#
# iter_size: 1
#
# type: "AdaDelta"
#
# eval_type: "detection"
#
# ap_version: "11point"
#
# I0323 09:07:33.521015 190428 solver.cpp:147] Creating training net from train_net file: train.prototxt
#
# I0323 09:07:33.658231 190428 cpu_info.cpp:452] Processor speed [MHz]: 1300
#
# I0323 09:07:33.658732 190428 cpu_info.cpp:455] Total number of sockets: 1
#
# I0323 09:07:33.658808 190428 cpu_info.cpp:458] Total number of CPU cores: 64
#
# I0323 09:07:33.659474 190428 cpu_info.cpp:461] Total number of processors: 256
#
# I0323 09:07:33.659859 190428 cpu_info.cpp:464] GPU is used: no
#
# I0323 09:07:33.659939 190428 cpu_info.cpp:467] OpenMP environmental variables are specified: no
#
# I0323 09:07:33.660591 190428 cpu_info.cpp:470] OpenMP thread bind allowed: yes
#
# I0323 09:07:33.660671 190428 cpu_info.cpp:473] Number of OpenMP threads: 64
#
# I0323 09:07:33.667840 190428 net.cpp:155] Initializing net from parameters:
#
# name: "VGG_VOC0712_SSD_300x300_train"
#
# state {
#
#   phase: TRAIN
#
#   level: 0
#
#   stage: ""
#
# }
#
# layer {
#
#   name: "data"
#
#   type: "AnnotatedData"
#
#   top: "data"
#
#   top: "label"
#
#   include {
#
#     phase: TRAIN
#
#   }
#
#   transform_param {
#
#     mirror: true
#
#     resize_param {
#
#       prob: 1
#
#       resize_mode: WARP
#
#       height: 300
#
#       width: 300
#
#       interp_mode: LINEAR
#
#       interp_mode: AREA
#
#       interp_mode: NEAREST
#
#       interp_mode: CUBIC
#
#       interp_mode: LANCZOS4
#
#     }
#
#     emit_constraint {
#
#       emit_type: CENTER
#
#     }
#
#     distort_param {
#
#       brightness_prob: 0.5
#
#       brightness_delta: 32
#
#       contrast_prob: 0.5
#
#       contrast_lower: 0.5
#
#       contrast_upper: 1.5
#
#       hue_prob: 0.5
#
#       hue_delta: 18
#
#       saturation_prob: 0.5
#
#       saturation_lower: 0.5
#
#       saturation_upper: 1.5
#
#       random_order_prob: 0
#
#     }
#
#     expand_param {
#
#       prob: 0.5
#
#       max_expand_ratio: 4
#
#     }
#
#   }
#
#   data_param {
#
#     source: "../../input/generated/train/train.lmdb"
#
#     batch_size: 32
#
#     backend: LMDB
#
#   }
#
#   annotated_data_param {
#
#     batch_sampler {
#
#       max_sample: 1
#
#       max_trials: 1
#
#     }
#
#     batch_sampler {
#
#       sampler {
#
#         min_scale: 0.3
#
#         max_scale: 1
#
#         min_aspect_ratio: 0.5
#
#         max_aspect_ratio: 2
#
#       }
#
#       sample_constraint {
#
#         min_jaccard_overlap: 0.1
#
#       }
#
#       max_sample: 1
#
#       max_trials: 50
#
#     }
#
#     batch_sampler {
#
#       sampler {
#
#         min_scale: 0.3
#
#         max_scale: 1
#
#         min_aspect_ratio: 0.5
#
#         max_aspect_ratio: 2
#
#       }
#
#       sample_constraint {
#
#         min_jaccard_overlap: 0.3
#
#       }
#
#       max_sample: 1
#
#       max_trials: 50
#
#     }
#
#     batch_sampler {
#
#       sampler {
#
#         min_scale: 0.3
#
#         max_scale: 1
#
#         min_aspect_ratio: 0.5
#
#         max_aspect_ratio: 2
#
#       }
#
#       sample_constraint {
#
#         min_jaccard_overlap: 0.5
#
#       }
#
#       max_sample: 1
#
#       max_trials: 50
#
#     }
#
#     batch_sampler {
#
#       sampler {
#
#         min_scale: 0.3
#
#         max_scale: 1
#
#         min_aspect_ratio: 0.5
#
#         max_aspect_ratio: 2
#
#       }
#
#       sample_constraint {
#
#         min_jaccard_overlap: 0.7
#
#       }
#
#       max_sample: 1
#
#       max_trials: 50
#
#     }
#
#     batch_sampler {
#
#       sampler {
#
#         min_scale: 0.3
#
#         max_scale: 1
#
#         min_aspect_ratio: 0.5
#
#         max_aspect_ratio: 2
#
#       }
#
#       sample_constraint {
#
#         min_jaccard_overlap: 0.9
#
#       }
#
#       max_sample: 1
#
#       max_trials: 50
#
#     }
#
#     batch_sampler {
#
#       sampler {
#
#         min_scale: 0.3
#
#         max_scale: 1
#
#         min_aspect_ratio: 0.5
#
#         max_aspect_ratio: 2
#
#       }
#
#       sample_constraint {
#
#         max_jaccard_overlap: 1
#
#       }
#
#       max_sample: 1
#
#       max_trials: 50
#
#     }
#
#     label_map_file: "../labelmap_ccs.prototxt"
#
#   }
#
# }
#
# layer {
#
#   name: "data_data_0_split"
#
#   type: "Split"
#
#   bottom: "data"
#
#   top: "data_data_0_split_0"
#
#   top: "data_data_0_split_1"
#
#   top: "data_data_0_split_2"
#
#   top: "data_data_0_split_3"
#
#   top: "data_data_0_split_4"
#
#   top: "data_data_0_split_5"
#
#   top: "data_data_0_split_6"
#
# }
#
# layer {
#
#   name: "conv1_1"
#
#   type: "Convolution"
#
#   bottom: "data_data_0_split_0"
#
#   top: "conv1_1"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 64
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu1_1"
#
#   type: "ReLU"
#
#   bottom: "conv1_1"
#
#   top: "conv1_1"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv1_2"
#
#   type: "Convolution"
#
#   bottom: "conv1_1"
#
#   top: "conv1_2"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 64
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu1_2"
#
#   type: "ReLU"
#
#   bottom: "conv1_2"
#
#   top: "conv1_2"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "pool1"
#
#   type: "Pooling"
#
#   bottom: "conv1_2"
#
#   top: "pool1"
#
#   pooling_param {
#
#     pool: MAX
#
#     kernel_size: 2
#
#     stride: 2
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv2_1"
#
#   type: "Convolution"
#
#   bottom: "pool1"
#
#   top: "conv2_1"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 128
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu2_1"
#
#   type: "ReLU"
#
#   bottom: "conv2_1"
#
#   top: "conv2_1"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv2_2"
#
#   type: "Convolution"
#
#   bottom: "conv2_1"
#
#   top: "conv2_2"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 128
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu2_2"
#
#   type: "ReLU"
#
#   bottom: "conv2_2"
#
#   top: "conv2_2"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "pool2"
#
#   type: "Pooling"
#
#   bottom: "conv2_2"
#
#   top: "pool2"
#
#   pooling_param {
#
#     pool: MAX
#
#     kernel_size: 2
#
#     stride: 2
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv3_1"
#
#   type: "Convolution"
#
#   bottom: "pool2"
#
#   top: "conv3_1"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 256
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu3_1"
#
#   type: "ReLU"
#
#   bottom: "conv3_1"
#
#   top: "conv3_1"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv3_2"
#
#   type: "Convolution"
#
#   bottom: "conv3_1"
#
#   top: "conv3_2"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 256
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu3_2"
#
#   type: "ReLU"
#
#   bottom: "conv3_2"
#
#   top: "conv3_2"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv3_3"
#
#   type: "Convolution"
#
#   bottom: "conv3_2"
#
#   top: "conv3_3"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 256
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu3_3"
#
#   type: "ReLU"
#
#   bottom: "conv3_3"
#
#   top: "conv3_3"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "pool3"
#
#   type: "Pooling"
#
#   bottom: "conv3_3"
#
#   top: "pool3"
#
#   pooling_param {
#
#     pool: MAX
#
#     kernel_size: 2
#
#     stride: 2
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv4_1"
#
#   type: "Convolution"
#
#   bottom: "pool3"
#
#   top: "conv4_1"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 512
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu4_1"
#
#   type: "ReLU"
#
#   bottom: "conv4_1"
#
#   top: "conv4_1"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv4_2"
#
#   type: "Convolution"
#
#   bottom: "conv4_1"
#
#   top: "conv4_2"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 512
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu4_2"
#
#   type: "ReLU"
#
#   bottom: "conv4_2"
#
#   top: "conv4_2"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv4_3"
#
#   type: "Convolution"
#
#   bottom: "conv4_2"
#
#   top: "conv4_3"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 512
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu4_3"
#
#   type: "ReLU"
#
#   bottom: "conv4_3"
#
#   top: "conv4_3"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv4_3_relu4_3_0_split"
#
#   type: "Split"
#
#   bottom: "conv4_3"
#
#   top: "conv4_3_relu4_3_0_split_0"
#
#   top: "conv4_3_relu4_3_0_split_1"
#
# }
#
# layer {
#
#   name: "pool4"
#
#   type: "Pooling"
#
#   bottom: "conv4_3_relu4_3_0_split_0"
#
#   top: "pool4"
#
#   pooling_param {
#
#     pool: MAX
#
#     kernel_size: 2
#
#     stride: 2
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv5_1"
#
#   type: "Convolution"
#
#   bottom: "pool4"
#
#   top: "conv5_1"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 512
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#     dilation: 1
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu5_1"
#
#   type: "ReLU"
#
#   bottom: "conv5_1"
#
#   top: "conv5_1"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv5_2"
#
#   type: "Convolution"
#
#   bottom: "conv5_1"
#
#   top: "conv5_2"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 512
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#     dilation: 1
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu5_2"
#
#   type: "ReLU"
#
#   bottom: "conv5_2"
#
#   top: "conv5_2"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv5_3"
#
#   type: "Convolution"
#
#   bottom: "conv5_2"
#
#   top: "conv5_3"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 512
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#     dilation: 1
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu5_3"
#
#   type: "ReLU"
#
#   bottom: "conv5_3"
#
#   top: "conv5_3"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "pool5"
#
#   type: "Pooling"
#
#   bottom: "conv5_3"
#
#   top: "pool5"
#
#   pooling_param {
#
#     pool: MAX
#
#     kernel_size: 3
#
#     stride: 1
#
#     pad: 1
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "fc6"
#
#   type: "Convolution"
#
#   bottom: "pool5"
#
#   top: "fc6"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 1024
#
#     pad: 6
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#     dilation: 6
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu6"
#
#   type: "ReLU"
#
#   bottom: "fc6"
#
#   top: "fc6"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "fc7"
#
#   type: "Convolution"
#
#   bottom: "fc6"
#
#   top: "fc7"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 1024
#
#     kernel_size: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu7"
#
#   type: "ReLU"
#
#   bottom: "fc7"
#
#   top: "fc7"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "fc7_relu7_0_split"
#
#   type: "Split"
#
#   bottom: "fc7"
#
#   top: "fc7_relu7_0_split_0"
#
#   top: "fc7_relu7_0_split_1"
#
#   top: "fc7_relu7_0_split_2"
#
#   top: "fc7_relu7_0_split_3"
#
# }
#
# layer {
#
#   name: "conv6_1"
#
#   type: "Convolution"
#
#   bottom: "fc7_relu7_0_split_0"
#
#   top: "conv6_1"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 256
#
#     pad: 0
#
#     kernel_size: 1
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv6_1_relu"
#
#   type: "ReLU"
#
#   bottom: "conv6_1"
#
#   top: "conv6_1"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv6_2"
#
#   type: "Convolution"
#
#   bottom: "conv6_1"
#
#   top: "conv6_2"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 512
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 2
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv6_2_relu"
#
#   type: "ReLU"
#
#   bottom: "conv6_2"
#
#   top: "conv6_2"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv6_2_conv6_2_relu_0_split"
#
#   type: "Split"
#
#   bottom: "conv6_2"
#
#   top: "conv6_2_conv6_2_relu_0_split_0"
#
#   top: "conv6_2_conv6_2_relu_0_split_1"
#
#   top: "conv6_2_conv6_2_relu_0_split_2"
#
#   top: "conv6_2_conv6_2_relu_0_split_3"
#
# }
#
# layer {
#
#   name: "conv7_1"
#
#   type: "Convolution"
#
#   bottom: "conv6_2_conv6_2_relu_0_split_0"
#
#   top: "conv7_1"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 128
#
#     pad: 0
#
#     kernel_size: 1
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv7_1_relu"
#
#   type: "ReLU"
#
#   bottom: "conv7_1"
#
#   top: "conv7_1"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv7_2"
#
#   type: "Convolution"
#
#   bottom: "conv7_1"
#
#   top: "conv7_2"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 256
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 2
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv7_2_relu"
#
#   type: "ReLU"
#
#   bottom: "conv7_2"
#
#   top: "conv7_2"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv7_2_conv7_2_relu_0_split"
#
#   type: "Split"
#
#   bottom: "conv7_2"
#
#   top: "conv7_2_conv7_2_relu_0_split_0"
#
#   top: "conv7_2_conv7_2_relu_0_split_1"
#
#   top: "conv7_2_conv7_2_relu_0_split_2"
#
#   top: "conv7_2_conv7_2_relu_0_split_3"
#
# }
#
# layer {
#
#   name: "conv8_1"
#
#   type: "Convolution"
#
#   bottom: "conv7_2_conv7_2_relu_0_split_0"
#
#   top: "conv8_1"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 128
#
#     pad: 0
#
#     kernel_size: 1
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv8_1_relu"
#
#   type: "ReLU"
#
#   bottom: "conv8_1"
#
#   top: "conv8_1"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv8_2"
#
#   type: "Convolution"
#
#   bottom: "conv8_1"
#
#   top: "conv8_2"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 256
#
#     pad: 0
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv8_2_relu"
#
#   type: "ReLU"
#
#   bottom: "conv8_2"
#
#   top: "conv8_2"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv8_2_conv8_2_relu_0_split"
#
#   type: "Split"
#
#   bottom: "conv8_2"
#
#   top: "conv8_2_conv8_2_relu_0_split_0"
#
#   top: "conv8_2_conv8_2_relu_0_split_1"
#
#   top: "conv8_2_conv8_2_relu_0_split_2"
#
#   top: "conv8_2_conv8_2_relu_0_split_3"
#
# }
#
# layer {
#
#   name: "conv9_1"
#
#   type: "Convolution"
#
#   bottom: "conv8_2_conv8_2_relu_0_split_0"
#
#   top: "conv9_1"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 128
#
#     pad: 0
#
#     kernel_size: 1
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv9_1_relu"
#
#   type: "ReLU"
#
#   bottom: "conv9_1"
#
#   top: "conv9_1"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv9_2"
#
#   type: "Convolution"
#
#   bottom: "conv9_1"
#
#   top: "conv9_2"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 256
#
#     pad: 0
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv9_2_relu"
#
#   type: "ReLU"
#
#   bottom: "conv9_2"
#
#   top: "conv9_2"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv9_2_conv9_2_relu_0_split"
#
#   type: "Split"
#
#   bottom: "conv9_2"
#
#   top: "conv9_2_conv9_2_relu_0_split_0"
#
#   top: "conv9_2_conv9_2_relu_0_split_1"
#
#   top: "conv9_2_conv9_2_relu_0_split_2"
#
# }
#
# layer {
#
#   name: "conv4_3_norm"
#
#   type: "Normalize"
#
#   bottom: "conv4_3_relu4_3_0_split_1"
#
#   top: "conv4_3_norm"
#
#   norm_param {
#
#     across_spatial: false
#
#     scale_filler {
#
#       type: "constant"
#
#       value: 20
#
#     }
#
#     channel_shared: false
#
#   }
#
# }
#
# layer {
#
#   name: "conv4_3_norm_conv4_3_norm_0_split"
#
#   type: "Split"
#
#   bottom: "conv4_3_norm"
#
#   top: "conv4_3_norm_conv4_3_norm_0_split_0"
#
#   top: "conv4_3_norm_conv4_3_norm_0_split_1"
#
#   top: "conv4_3_norm_conv4_3_norm_0_split_2"
#
# }
#
# layer {
#
#   name: "conv4_3_norm_mbox_loc"
#
#   type: "Convolution"
#
#   bottom: "conv4_3_norm_conv4_3_norm_0_split_0"
#
#   top: "conv4_3_norm_mbox_loc"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 16
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
# }
#
# layer {
#
#   name: "conv4_3_norm_mbox_loc_perm"
#
#   type: "Permute"
#
#   bottom: "conv4_3_norm_mbox_loc"
#
#   top: "conv4_3_norm_mbox_loc_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv4_3_norm_mbox_loc_flat"
#
#   type: "Flatten"
#
#   bottom: "conv4_3_norm_mbox_loc_perm"
#
#   top: "conv4_3_norm_mbox_loc_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv4_3_norm_mbox_conf"
#
#   type: "Convolution"
#
#   bottom: "conv4_3_norm_conv4_3_norm_0_split_1"
#
#   top: "conv4_3_norm_mbox_conf"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 84
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
# }
#
# layer {
#
#   name: "conv4_3_norm_mbox_conf_perm"
#
#   type: "Permute"
#
#   bottom: "conv4_3_norm_mbox_conf"
#
#   top: "conv4_3_norm_mbox_conf_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv4_3_norm_mbox_conf_flat"
#
#   type: "Flatten"
#
#   bottom: "conv4_3_norm_mbox_conf_perm"
#
#   top: "conv4_3_norm_mbox_conf_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv4_3_norm_mbox_priorbox"
#
#   type: "PriorBox"
#
#   bottom: "conv4_3_norm_conv4_3_norm_0_split_2"
#
#   bottom: "data_data_0_split_1"
#
#   top: "conv4_3_norm_mbox_priorbox"
#
#   prior_box_param {
#
#     min_size: 30
#
#     max_size: 60
#
#     aspect_ratio: 2
#
#     flip: true
#
#     clip: false
#
#     variance: 0.1
#
#     variance: 0.1
#
#     variance: 0.2
#
#     variance: 0.2
#
#     step: 8
#
#     offset: 0.5
#
#   }
#
# }
#
# layer {
#
#   name: "fc7_mbox_loc"
#
#   type: "Convolution"
#
#   bottom: "fc7_relu7_0_split_1"
#
#   top: "fc7_mbox_loc"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 24
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "fc7_mbox_loc_perm"
#
#   type: "Permute"
#
#   bottom: "fc7_mbox_loc"
#
#   top: "fc7_mbox_loc_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "fc7_mbox_loc_flat"
#
#   type: "Flatten"
#
#   bottom: "fc7_mbox_loc_perm"
#
#   top: "fc7_mbox_loc_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "fc7_mbox_conf"
#
#   type: "Convolution"
#
#   bottom: "fc7_relu7_0_split_2"
#
#   top: "fc7_mbox_conf"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 126
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
# }
#
# layer {
#
#   name: "fc7_mbox_conf_perm"
#
#   type: "Permute"
#
#   bottom: "fc7_mbox_conf"
#
#   top: "fc7_mbox_conf_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "fc7_mbox_conf_flat"
#
#   type: "Flatten"
#
#   bottom: "fc7_mbox_conf_perm"
#
#   top: "fc7_mbox_conf_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "fc7_mbox_priorbox"
#
#   type: "PriorBox"
#
#   bottom: "fc7_relu7_0_split_3"
#
#   bottom: "data_data_0_split_2"
#
#   top: "fc7_mbox_priorbox"
#
#   prior_box_param {
#
#     min_size: 60
#
#     max_size: 111
#
#     aspect_ratio: 2
#
#     aspect_ratio: 3
#
#     flip: true
#
#     clip: false
#
#     variance: 0.1
#
#     variance: 0.1
#
#     variance: 0.2
#
#     variance: 0.2
#
#     step: 16
#
#     offset: 0.5
#
#   }
#
# }
#
# layer {
#
#   name: "conv6_2_mbox_loc"
#
#   type: "Convolution"
#
#   bottom: "conv6_2_conv6_2_relu_0_split_1"
#
#   top: "conv6_2_mbox_loc"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 24
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv6_2_mbox_loc_perm"
#
#   type: "Permute"
#
#   bottom: "conv6_2_mbox_loc"
#
#   top: "conv6_2_mbox_loc_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv6_2_mbox_loc_flat"
#
#   type: "Flatten"
#
#   bottom: "conv6_2_mbox_loc_perm"
#
#   top: "conv6_2_mbox_loc_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv6_2_mbox_conf"
#
#   type: "Convolution"
#
#   bottom: "conv6_2_conv6_2_relu_0_split_2"
#
#   top: "conv6_2_mbox_conf"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 126
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
# }
#
# layer {
#
#   name: "conv6_2_mbox_conf_perm"
#
#   type: "Permute"
#
#   bottom: "conv6_2_mbox_conf"
#
#   top: "conv6_2_mbox_conf_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv6_2_mbox_conf_flat"
#
#   type: "Flatten"
#
#   bottom: "conv6_2_mbox_conf_perm"
#
#   top: "conv6_2_mbox_conf_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv6_2_mbox_priorbox"
#
#   type: "PriorBox"
#
#   bottom: "conv6_2_conv6_2_relu_0_split_3"
#
#   bottom: "data_data_0_split_3"
#
#   top: "conv6_2_mbox_priorbox"
#
#   prior_box_param {
#
#     min_size: 111
#
#     max_size: 162
#
#     aspect_ratio: 2
#
#     aspect_ratio: 3
#
#     flip: true
#
#     clip: false
#
#     variance: 0.1
#
#     variance: 0.1
#
#     variance: 0.2
#
#     variance: 0.2
#
#     step: 32
#
#     offset: 0.5
#
#   }
#
# }
#
# layer {
#
#   name: "conv7_2_mbox_loc"
#
#   type: "Convolution"
#
#   bottom: "conv7_2_conv7_2_relu_0_split_1"
#
#   top: "conv7_2_mbox_loc"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 24
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
# }
#
# layer {
#
#   name: "conv7_2_mbox_loc_perm"
#
#   type: "Permute"
#
#   bottom: "conv7_2_mbox_loc"
#
#   top: "conv7_2_mbox_loc_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv7_2_mbox_loc_flat"
#
#   type: "Flatten"
#
#   bottom: "conv7_2_mbox_loc_perm"
#
#   top: "conv7_2_mbox_loc_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv7_2_mbox_conf"
#
#   type: "Convolution"
#
#   bottom: "conv7_2_conv7_2_relu_0_split_2"
#
#   top: "conv7_2_mbox_conf"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 126
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv7_2_mbox_conf_perm"
#
#   type: "Permute"
#
#   bottom: "conv7_2_mbox_conf"
#
#   top: "conv7_2_mbox_conf_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv7_2_mbox_conf_flat"
#
#   type: "Flatten"
#
#   bottom: "conv7_2_mbox_conf_perm"
#
#   top: "conv7_2_mbox_conf_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv7_2_mbox_priorbox"
#
#   type: "PriorBox"
#
#   bottom: "conv7_2_conv7_2_relu_0_split_3"
#
#   bottom: "data_data_0_split_4"
#
#   top: "conv7_2_mbox_priorbox"
#
#   prior_box_param {
#
#     min_size: 162
#
#     max_size: 213
#
#     aspect_ratio: 2
#
#     aspect_ratio: 3
#
#     flip: true
#
#     clip: false
#
#     variance: 0.1
#
#     variance: 0.1
#
#     variance: 0.2
#
#     variance: 0.2
#
#     step: 64
#
#     offset: 0.5
#
#   }
#
# }
#
# layer {
#
#   name: "conv8_2_mbox_loc"
#
#   type: "Convolution"
#
#   bottom: "conv8_2_conv8_2_relu_0_split_1"
#
#   top: "conv8_2_mbox_loc"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 16
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv8_2_mbox_loc_perm"
#
#   type: "Permute"
#
#   bottom: "conv8_2_mbox_loc"
#
#   top: "conv8_2_mbox_loc_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv8_2_mbox_loc_flat"
#
#   type: "Flatten"
#
#   bottom: "conv8_2_mbox_loc_perm"
#
#   top: "conv8_2_mbox_loc_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv8_2_mbox_conf"
#
#   type: "Convolution"
#
#   bottom: "conv8_2_conv8_2_relu_0_split_2"
#
#   top: "conv8_2_mbox_conf"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 84
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv8_2_mbox_conf_perm"
#
#   type: "Permute"
#
#   bottom: "conv8_2_mbox_conf"
#
#   top: "conv8_2_mbox_conf_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv8_2_mbox_conf_flat"
#
#   type: "Flatten"
#
#   bottom: "conv8_2_mbox_conf_perm"
#
#   top: "conv8_2_mbox_conf_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv8_2_mbox_priorbox"
#
#   type: "PriorBox"
#
#   bottom: "conv8_2_conv8_2_relu_0_split_3"
#
#   bottom: "data_data_0_split_5"
#
#   top: "conv8_2_mbox_priorbox"
#
#   prior_box_param {
#
#     min_size: 213
#
#     max_size: 264
#
#     aspect_ratio: 2
#
#     flip: true
#
#     clip: false
#
#     variance: 0.1
#
#     variance: 0.1
#
#     variance: 0.2
#
#     variance: 0.2
#
#     step: 100
#
#     offset: 0.5
#
#   }
#
# }
#
# layer {
#
#   name: "conv9_2_mbox_loc"
#
#   type: "Convolution"
#
#   bottom: "conv9_2_conv9_2_relu_0_split_0"
#
#   top: "conv9_2_mbox_loc"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 16
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
# }
#
# layer {
#
#   name: "conv9_2_mbox_loc_perm"
#
#   type: "Permute"
#
#   bottom: "conv9_2_mbox_loc"
#
#   top: "conv9_2_mbox_loc_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv9_2_mbox_loc_flat"
#
#   type: "Flatten"
#
#   bottom: "conv9_2_mbox_loc_perm"
#
#   top: "conv9_2_mbox_loc_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv9_2_mbox_conf"
#
#   type: "Convolution"
#
#   bottom: "conv9_2_conv9_2_relu_0_split_1"
#
#   top: "conv9_2_mbox_conf"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 84
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv9_2_mbox_conf_perm"
#
#   type: "Permute"
#
#   bottom: "conv9_2_mbox_conf"
#
#   top: "conv9_2_mbox_conf_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv9_2_mbox_conf_flat"
#
#   type: "Flatten"
#
#   bottom: "conv9_2_mbox_conf_perm"
#
#   top: "conv9_2_mbox_conf_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv9_2_mbox_priorbox"
#
#   type: "PriorBox"
#
#   bottom: "conv9_2_conv9_2_relu_0_split_2"
#
#   bottom: "data_data_0_split_6"
#
#   top: "conv9_2_mbox_priorbox"
#
#   prior_box_param {
#
#     min_size: 264
#
#     max_size: 315
#
#     aspect_ratio: 2
#
#     flip: true
#
#     clip: false
#
#     variance: 0.1
#
#     variance: 0.1
#
#     variance: 0.2
#
#     variance: 0.2
#
#     step: 300
#
#     offset: 0.5
#
#   }
#
# }
#
# layer {
#
#   name: "mbox_loc"
#
#   type: "Concat"
#
#   bottom: "conv4_3_norm_mbox_loc_flat"
#
#   bottom: "fc7_mbox_loc_flat"
#
#   bottom: "conv6_2_mbox_loc_flat"
#
#   bottom: "conv7_2_mbox_loc_flat"
#
#   bottom: "conv8_2_mbox_loc_flat"
#
#   bottom: "conv9_2_mbox_loc_flat"
#
#   top: "mbox_loc"
#
#   concat_param {
#
#     axis: 1
#
#   }
#
#   engine: "CAFFE"
#
# }
#
# layer {
#
#   name: "mbox_conf"
#
#   type: "Concat"
#
#   bottom: "conv4_3_norm_mbox_conf_flat"
#
#   bottom: "fc7_mbox_conf_flat"
#
#   bottom: "conv6_2_mbox_conf_flat"
#
#   bottom: "conv7_2_mbox_conf_flat"
#
#   bottom: "conv8_2_mbox_conf_flat"
#
#   bottom: "conv9_2_mbox_conf_flat"
#
#   top: "mbox_conf"
#
#   concat_param {
#
#     axis: 1
#
#   }
#
#   engine: "CAFFE"
#
# }
#
# layer {
#
#   name: "mbox_priorbox"
#
#   type: "Concat"
#
#   bottom: "conv4_3_norm_mbox_priorbox"
#
#   bottom: "fc7_mbox_priorbox"
#
#   bottom: "conv6_2_mbox_priorbox"
#
#   bottom: "conv7_2_mbox_priorbox"
#
#   bottom: "conv8_2_mbox_priorbox"
#
#   bottom: "conv9_2_mbox_priorbox"
#
#   top: "mbox_priorbox"
#
#   concat_param {
#
#     axis: 2
#
#   }
#
#   engine: "CAFFE"
#
# }
#
# layer {
#
#   name: "mbox_loss"
#
#   type: "MultiBoxLoss"
#
#   bottom: "mbox_loc"
#
#   bottom: "mbox_conf"
#
#   bottom: "mbox_priorbox"
#
#   bottom: "label"
#
#
#
# I0323 09:07:33.698156 190428 layer_factory.hpp:114] Creating layer data
#
# I0323 09:07:33.700570 190428 net.cpp:197] Creating Layer data
#
# I0323 09:07:33.700695 190428 net.cpp:866] data -> data
#
# I0323 09:07:33.700814 190428 net.cpp:866] data -> label
#
# I0323 09:07:33.717587 190493 db_lmdb.cpp:72] Opened lmdb ../../input/generated/train/train.lmdb
#
# I0323 09:07:33.747746 190428 annotated_data_layer.cpp:100] output data size: 32,3,300,300
#
# I0323 09:07:33.817288 190428 net.cpp:282] Setting up data
#
# I0323 09:07:33.817791 190428 net.cpp:289] Top shape: 32 3 300 300 (8640000)
#
# I0323 09:07:33.818241 190428 net.cpp:289] Top shape: 1 1 2 8 (16)
#
# I0323 09:07:33.818703 190428 net.cpp:297] Memory required for data: 34560064
#
# I0323 09:07:33.819114 190428 layer_factory.hpp:114] Creating layer data_data_0_split
#
# I0323 09:07:33.819298 190428 net.cpp:197] Creating Layer data_data_0_split
#
# I0323 09:07:33.819475 190428 net.cpp:892] data_data_0_split <- data
#
# I0323 09:07:33.819669 190428 net.cpp:866] data_data_0_split -> data_data_0_split_0
#
# I0323 09:07:33.819870 190428 net.cpp:866] data_data_0_split -> data_data_0_split_1
#
# I0323 09:07:33.820046 190428 net.cpp:866] data_data_0_split -> data_data_0_split_2
#
# I0323 09:07:33.820188 190428 net.cpp:866] data_data_0_split -> data_data_0_split_3
#
# I0323 09:07:33.820313 190428 net.cpp:866] data_data_0_split -> data_data_0_split_4
#
# I0323 09:07:33.820526 190428 net.cpp:866] data_data_0_split -> data_data_0_split_5
#
# I0323 09:07:33.820715 190428 net.cpp:866] data_data_0_split -> data_data_0_split_6
#
# I0323 09:07:33.821056 190428 net.cpp:282] Setting up data_data_0_split
#
# I0323 09:07:33.821190 190428 net.cpp:289] Top shape: 32 3 300 300 (8640000)
#
# I0323 09:07:33.821301 190428 net.cpp:289] Top shape: 32 3 300 300 (8640000)
#
# I0323 09:07:33.821463 190428 net.cpp:289] Top shape: 32 3 300 300 (8640000)
#
# I0323 09:07:33.821571 190428 net.cpp:289] Top shape: 32 3 300 300 (8640000)
#
# I0323 09:07:33.821662 190428 net.cpp:289] Top shape: 32 3 300 300 (8640000)
#
# I0323 09:07:33.821760 190428 net.cpp:289] Top shape: 32 3 300 300 (8640000)
#
# I0323 09:07:33.821866 190428 net.cpp:289] Top shape: 32 3 300 300 (8640000)
#
# I0323 09:07:33.821965 190428 net.cpp:297] Memory required for data: 276480064
#
# I0323 09:07:33.822060 190428 layer_factory.hpp:114] Creating layer conv1_1
#
# I0323 09:07:33.822253 190428 net.cpp:197] Creating Layer conv1_1
#
# I0323 09:07:33.822387 190428 net.cpp:892] conv1_1 <- data_data_0_split_0
#
# I0323 09:07:33.822516 190428 net.cpp:866] conv1_1 -> conv1_1
#
# I0323 09:07:34.167124 190428 net.cpp:282] Setting up conv1_1
#
# I0323 09:07:34.167279 190428 net.cpp:289] Top shape: 32 64 300 300 (184320000)
#
# I0323 09:07:34.167695 190428 net.cpp:297] Memory required for data: 1013760064
#
# I0323 09:07:34.168442 190428 layer_factory.hpp:114] Creating layer relu1_1
#
# I0323 09:07:34.168898 190428 net.cpp:197] Creating Layer relu1_1
#
# I0323 09:07:34.169271 190428 net.cpp:892] relu1_1 <- conv1_1
#
# I0323 09:07:34.169404 190428 net.cpp:853] relu1_1 -> conv1_1 (in-place)
#
# I0323 09:07:34.169595 190428 net.cpp:282] Setting up relu1_1
#
# I0323 09:07:34.169692 190428 net.cpp:289] Top shape: 32 64 300 300 (184320000)
#
# I0323 09:07:34.169792 190428 net.cpp:297] Memory required for data: 1751040064
#
# I0323 09:07:34.169880 190428 layer_factory.hpp:114] Creating layer conv1_2
#
# I0323 09:07:34.170043 190428 net.cpp:197] Creating Layer conv1_2
#
# I0323 09:07:34.170136 190428 net.cpp:892] conv1_2 <- conv1_1
#
# I0323 09:07:34.170248 190428 net.cpp:866] conv1_2 -> conv1_2
#
# I0323 09:07:36.287742 190428 net.cpp:282] Setting up conv1_2
#
# I0323 09:07:36.287945 190428 net.cpp:289] Top shape: 32 64 300 300 (184320000)
#
# I0323 09:07:36.288048 190428 net.cpp:297] Memory required for data: 2488320064
#
# I0323 09:07:36.288445 190428 layer_factory.hpp:114] Creating layer relu1_2
#
# I0323 09:07:36.288602 190428 net.cpp:197] Creating Layer relu1_2
#
# I0323 09:07:36.288691 190428 net.cpp:892] relu1_2 <- conv1_2
#
# I0323 09:07:36.288974 190428 net.cpp:853] relu1_2 -> conv1_2 (in-place)
#
# I0323 09:07:36.289167 190428 net.cpp:282] Setting up relu1_2
#
# I0323 09:07:36.289563 190428 net.cpp:289] Top shape: 32 64 300 300 (184320000)
#
# I0323 09:07:36.289644 190428 net.cpp:297] Memory required for data: 3225600064
#
# I0323 09:07:36.289716 190428 layer_factory.hpp:114] Creating layer pool1
#
# I0323 09:07:36.289837 190428 net.cpp:197] Creating Layer pool1
#
# I0323 09:07:36.289918 190428 net.cpp:892] pool1 <- conv1_2
#
# I0323 09:07:36.290007 190428 net.cpp:866] pool1 -> pool1
#
# I0323 09:07:36.290192 190428 net.cpp:282] Setting up pool1
#
# I0323 09:07:36.290268 190428 net.cpp:289] Top shape: 32 64 150 150 (46080000)
#
# I0323 09:07:36.290375 190428 net.cpp:297] Memory required for data: 3409920064
#
# I0323 09:07:36.290457 190428 layer_factory.hpp:114] Creating layer conv2_1
#
# I0323 09:07:36.290612 190428 net.cpp:197] Creating Layer conv2_1
#
# I0323 09:07:36.290689 190428 net.cpp:892] conv2_1 <- pool1
#
# I0323 09:07:36.290786 190428 net.cpp:866] conv2_1 -> conv2_1
#
# I0323 09:07:36.814906 190428 net.cpp:282] Setting up conv2_1
#
# I0323 09:07:36.815070 190428 net.cpp:289] Top shape: 32 128 150 150 (92160000)
#
# I0323 09:07:36.815172 190428 net.cpp:297] Memory required for data: 3778560064
#
# I0323 09:07:36.815542 190428 layer_factory.hpp:114] Creating layer relu2_1
#
# I0323 09:07:36.815692 190428 net.cpp:197] Creating Layer relu2_1
#
# I0323 09:07:36.815776 190428 net.cpp:892] relu2_1 <- conv2_1
#
# I0323 09:07:36.816066 190428 net.cpp:853] relu2_1 -> conv2_1 (in-place)
#
# I0323 09:07:36.816563 190428 net.cpp:282] Setting up relu2_1
#
# I0323 09:07:36.816761 190428 net.cpp:289] Top shape: 32 128 150 150 (92160000)
#
# I0323 09:07:36.816845 190428 net.cpp:297] Memory required for data: 4147200064
#
# I0323 09:07:36.817034 190428 layer_factory.hpp:114] Creating layer conv2_2
#
# I0323 09:07:36.817203 190428 net.cpp:197] Creating Layer conv2_2
#
# I0323 09:07:36.817287 190428 net.cpp:892] conv2_2 <- conv2_1
#
# I0323 09:07:36.817427 190428 net.cpp:866] conv2_2 -> conv2_2
#
# I0323 09:07:37.922330 190428 net.cpp:282] Setting up conv2_2
#
# I0323 09:07:37.922533 190428 net.cpp:289] Top shape: 32 128 150 150 (92160000)
#
# I0323 09:07:37.922631 190428 net.cpp:297] Memory required for data: 4515840064
#
# I0323 09:07:37.922943 190428 layer_factory.hpp:114] Creating layer relu2_2
#
# I0323 09:07:37.923285 190428 net.cpp:197] Creating Layer relu2_2
#
# I0323 09:07:37.923393 190428 net.cpp:892] relu2_2 <- conv2_2
#
# I0323 09:07:37.923492 190428 net.cpp:853] relu2_2 -> conv2_2 (in-place)
#
# I0323 09:07:37.923807 190428 net.cpp:282] Setting up relu2_2
#
# I0323 09:07:37.923907 190428 net.cpp:289] Top shape: 32 128 150 150 (92160000)
#
# I0323 09:07:37.924008 190428 net.cpp:297] Memory required for data: 4884480064
#
# I0323 09:07:37.924268 190428 layer_factory.hpp:114] Creating layer pool2
#
# I0323 09:07:37.924428 190428 net.cpp:197] Creating Layer pool2
#
# I0323 09:07:37.924526 190428 net.cpp:892] pool2 <- conv2_2
#
# I0323 09:07:37.924624 190428 net.cpp:866] pool2 -> pool2
#
# I0323 09:07:37.924789 190428 net.cpp:282] Setting up pool2
#
# I0323 09:07:37.924885 190428 net.cpp:289] Top shape: 32 128 75 75 (23040000)
#
# I0323 09:07:37.924976 190428 net.cpp:297] Memory required for data: 4976640064
#
# I0323 09:07:37.925058 190428 layer_factory.hpp:114] Creating layer conv3_1
#
# I0323 09:07:37.925200 190428 net.cpp:197] Creating Layer conv3_1
#
# I0323 09:07:37.925284 190428 net.cpp:892] conv3_1 <- pool2
#
# I0323 09:07:37.925405 190428 net.cpp:866] conv3_1 -> conv3_1
#
# I0323 09:07:38.218406 190428 net.cpp:282] Setting up conv3_1
#
# I0323 09:07:38.218566 190428 net.cpp:289] Top shape: 32 256 75 75 (46080000)
#
# I0323 09:07:38.218665 190428 net.cpp:297] Memory required for data: 5160960064
#
# I0323 09:07:38.218994 190428 layer_factory.hpp:114] Creating layer relu3_1
#
# I0323 09:07:38.219108 190428 net.cpp:197] Creating Layer relu3_1
#
# I0323 09:07:38.219420 190428 net.cpp:892] relu3_1 <- conv3_1
#
# I0323 09:07:38.219666 190428 net.cpp:853] relu3_1 -> conv3_1 (in-place)
#
# I0323 09:07:38.220103 190428 net.cpp:282] Setting up relu3_1
#
# I0323 09:07:38.220190 190428 net.cpp:289] Top shape: 32 256 75 75 (46080000)
#
# I0323 09:07:38.220285 190428 net.cpp:297] Memory required for data: 5345280064
#
# I0323 09:07:38.220412 190428 layer_factory.hpp:114] Creating layer conv3_2
#
# I0323 09:07:38.220607 190428 net.cpp:197] Creating Layer conv3_2
#
# I0323 09:07:38.220701 190428 net.cpp:892] conv3_2 <- conv3_1
#
# I0323 09:07:38.220818 190428 net.cpp:866] conv3_2 -> conv3_2
#
# I0323 09:07:38.789913 190428 net.cpp:282] Setting up conv3_2
#
# I0323 09:07:38.790088 190428 net.cpp:289] Top shape: 32 256 75 75 (46080000)
#
# I0323 09:07:38.790184 190428 net.cpp:297] Memory required for data: 5529600064
#
# I0323 09:07:38.790546 190428 layer_factory.hpp:114] Creating layer relu3_2
#
# I0323 09:07:38.790733 190428 net.cpp:197] Creating Layer relu3_2
#
# I0323 09:07:38.790894 190428 net.cpp:892] relu3_2 <- conv3_2
#
# I0323 09:07:38.790978 190428 net.cpp:853] relu3_2 -> conv3_2 (in-place)
#
# I0323 09:07:38.791370 190428 net.cpp:282] Setting up relu3_2
#
# I0323 09:07:38.791456 190428 net.cpp:289] Top shape: 32 256 75 75 (46080000)
#
# I0323 09:07:38.791558 190428 net.cpp:297] Memory required for data: 5713920064
#
# I0323 09:07:38.791633 190428 layer_factory.hpp:114] Creating layer conv3_3
#
# I0323 09:07:38.791795 190428 net.cpp:197] Creating Layer conv3_3
#
# I0323 09:07:38.791884 190428 net.cpp:892] conv3_3 <- conv3_2
#
# I0323 09:07:38.791980 190428 net.cpp:866] conv3_3 -> conv3_3
#
# I0323 09:07:39.358903 190428 net.cpp:282] Setting up conv3_3
#
# I0323 09:07:39.359071 190428 net.cpp:289] Top shape: 32 256 75 75 (46080000)
#
# I0323 09:07:39.359170 190428 net.cpp:297] Memory required for data: 5898240064
#
# I0323 09:07:39.359532 190428 layer_factory.hpp:114] Creating layer relu3_3
#
# I0323 09:07:39.359660 190428 net.cpp:197] Creating Layer relu3_3
#
# I0323 09:07:39.359921 190428 net.cpp:892] relu3_3 <- conv3_3
#
# I0323 09:07:39.360172 190428 net.cpp:853] relu3_3 -> conv3_3 (in-place)
#
# I0323 09:07:39.360476 190428 net.cpp:282] Setting up relu3_3
#
# I0323 09:07:39.360574 190428 net.cpp:289] Top shape: 32 256 75 75 (46080000)
#
# I0323 09:07:39.360671 190428 net.cpp:297] Memory required for data: 6082560064
#
# I0323 09:07:39.360920 190428 layer_factory.hpp:114] Creating layer pool3
#
# I0323 09:07:39.361038 190428 net.cpp:197] Creating Layer pool3
#
# I0323 09:07:39.361135 190428 net.cpp:892] pool3 <- conv3_3
#
# I0323 09:07:39.361227 190428 net.cpp:866] pool3 -> pool3
#
# I0323 09:07:39.361415 190428 net.cpp:282] Setting up pool3
#
# I0323 09:07:39.361500 190428 net.cpp:289] Top shape: 32 256 38 38 (11829248)
#
# I0323 09:07:39.361594 190428 net.cpp:297] Memory required for data: 6129877056
#
# I0323 09:07:39.361672 190428 layer_factory.hpp:114] Creating layer conv4_1
#
# I0323 09:07:39.361827 190428 net.cpp:197] Creating Layer conv4_1
#
# I0323 09:07:39.361915 190428 net.cpp:892] conv4_1 <- pool3
#
# I0323 09:07:39.362015 190428 net.cpp:866] conv4_1 -> conv4_1
#
# I0323 09:07:39.576493 190428 net.cpp:282] Setting up conv4_1
#
# I0323 09:07:39.576650 190428 net.cpp:289] Top shape: 32 512 38 38 (23658496)
#
# I0323 09:07:39.576750 190428 net.cpp:297] Memory required for data: 6224511040
#
# I0323 09:07:39.577075 190428 layer_factory.hpp:114] Creating layer relu4_1
#
# I0323 09:07:39.577368 190428 net.cpp:197] Creating Layer relu4_1
#
# I0323 09:07:39.577450 190428 net.cpp:892] relu4_1 <- conv4_1
#
# I0323 09:07:39.577549 190428 net.cpp:853] relu4_1 -> conv4_1 (in-place)
#
# I0323 09:07:39.578018 190428 net.cpp:282] Setting up relu4_1
#
# I0323 09:07:39.578094 190428 net.cpp:289] Top shape: 32 512 38 38 (23658496)
#
# I0323 09:07:39.578191 190428 net.cpp:297] Memory required for data: 6319145024
#
# I0323 09:07:39.578258 190428 layer_factory.hpp:114] Creating layer conv4_2
#
# I0323 09:07:39.578430 190428 net.cpp:197] Creating Layer conv4_2
#
# I0323 09:07:39.578512 190428 net.cpp:892] conv4_2 <- conv4_1
#
# I0323 09:07:39.578600 190428 net.cpp:866] conv4_2 -> conv4_2
#
# I0323 09:07:40.004601 190428 net.cpp:282] Setting up conv4_2
#
# I0323 09:07:40.004760 190428 net.cpp:289] Top shape: 32 512 38 38 (23658496)
#
# I0323 09:07:40.004859 190428 net.cpp:297] Memory required for data: 6413779008
#
# I0323 09:07:40.005197 190428 layer_factory.hpp:114] Creating layer relu4_2
#
# I0323 09:07:40.005317 190428 net.cpp:197] Creating Layer relu4_2
#
# I0323 09:07:40.005738 190428 net.cpp:892] relu4_2 <- conv4_2
#
# I0323 09:07:40.005823 190428 net.cpp:853] relu4_2 -> conv4_2 (in-place)
#
# I0323 09:07:40.006196 190428 net.cpp:282] Setting up relu4_2
#
# I0323 09:07:40.006270 190428 net.cpp:289] Top shape: 32 512 38 38 (23658496)
#
# I0323 09:07:40.006389 190428 net.cpp:297] Memory required for data: 6508412992
#
# I0323 09:07:40.006460 190428 layer_factory.hpp:114] Creating layer conv4_3
#
# I0323 09:07:40.006619 190428 net.cpp:197] Creating Layer conv4_3
#
# I0323 09:07:40.006693 190428 net.cpp:892] conv4_3 <- conv4_2
#
# I0323 09:07:40.006786 190428 net.cpp:866] conv4_3 -> conv4_3
#
# I0323 09:07:40.411770 190428 net.cpp:282] Setting up conv4_3
#
# I0323 09:07:40.411933 190428 net.cpp:289] Top shape: 32 512 38 38 (23658496)
#
# I0323 09:07:40.412029 190428 net.cpp:297] Memory required for data: 6603046976
#
# I0323 09:07:40.412375 190428 layer_factory.hpp:114] Creating layer relu4_3
#
# I0323 09:07:40.412506 190428 net.cpp:197] Creating Layer relu4_3
#
# I0323 09:07:40.412576 190428 net.cpp:892] relu4_3 <- conv4_3
#
# I0323 09:07:40.412654 190428 net.cpp:853] relu4_3 -> conv4_3 (in-place)
#
# I0323 09:07:40.412791 190428 net.cpp:282] Setting up relu4_3
#
# I0323 09:07:40.413108 190428 net.cpp:289] Top shape: 32 512 38 38 (23658496)
#
# I0323 09:07:40.413187 190428 net.cpp:297] Memory required for data: 6697680960
#
# I0323 09:07:40.413523 190428 layer_factory.hpp:114] Creating layer conv4_3_relu4_3_0_split
#
# I0323 09:07:40.413626 190428 net.cpp:197] Creating Layer conv4_3_relu4_3_0_split
#
# I0323 09:07:40.413709 190428 net.cpp:892] conv4_3_relu4_3_0_split <- conv4_3
#
# I0323 09:07:40.413800 190428 net.cpp:866] conv4_3_relu4_3_0_split -> conv4_3_relu4_3_0_split_0
#
# I0323 09:07:40.413893 190428 net.cpp:866] conv4_3_relu4_3_0_split -> conv4_3_relu4_3_0_split_1
#
# I0323 09:07:40.414010 190428 net.cpp:282] Setting up conv4_3_relu4_3_0_split
#
# I0323 09:07:40.414198 190428 net.cpp:289] Top shape: 32 512 38 38 (23658496)
#
# I0323 09:07:40.414294 190428 net.cpp:289] Top shape: 32 512 38 38 (23658496)
#
# I0323 09:07:40.414414 190428 net.cpp:297] Memory required for data: 6886948928
#
# I0323 09:07:40.414507 190428 layer_factory.hpp:114] Creating layer pool4
#
# ...
#
# I0323 09:07:53.822571 190428 net.cpp:892] mbox_conf <- conv4_3_norm_mbox_conf_flat
#
# I0323 09:07:53.822643 190428 net.cpp:892] mbox_conf <- fc7_mbox_conf_flat
#
# I0323 09:07:53.822712 190428 net.cpp:892] mbox_conf <- conv6_2_mbox_conf_flat
#
# I0323 09:07:53.822782 190428 net.cpp:892] mbox_conf <- conv7_2_mbox_conf_flat
#
# I0323 09:07:53.822850 190428 net.cpp:892] mbox_conf <- conv8_2_mbox_conf_flat
#
# I0323 09:07:53.822921 190428 net.cpp:892] mbox_conf <- conv9_2_mbox_conf_flat
#
# I0323 09:07:53.822994 190428 net.cpp:866] mbox_conf -> mbox_conf
#
# I0323 09:07:53.823086 190428 net.cpp:282] Setting up mbox_conf
#
# I0323 09:07:53.823151 190428 net.cpp:289] Top shape: 32 183372 (5867904)
#
# I0323 09:07:53.823225 190428 net.cpp:297] Memory required for data: 8019557312
#
# I0323 09:07:53.823292 190428 layer_factory.hpp:114] Creating layer mbox_priorbox
#
# I0323 09:07:53.823395 190428 net.cpp:197] Creating Layer mbox_priorbox
#
# I0323 09:07:53.823464 190428 net.cpp:892] mbox_priorbox <- conv4_3_norm_mbox_priorbox
#
# I0323 09:07:53.823535 190428 net.cpp:892] mbox_priorbox <- fc7_mbox_priorbox
#
# I0323 09:07:53.823606 190428 net.cpp:892] mbox_priorbox <- conv6_2_mbox_priorbox
#
# I0323 09:07:53.823676 190428 net.cpp:892] mbox_priorbox <- conv7_2_mbox_priorbox
#
# I0323 09:07:53.823743 190428 net.cpp:892] mbox_priorbox <- conv8_2_mbox_priorbox
#
# I0323 09:07:53.823813 190428 net.cpp:892] mbox_priorbox <- conv9_2_mbox_priorbox
#
# I0323 09:07:53.823889 190428 net.cpp:866] mbox_priorbox -> mbox_priorbox
#
# I0323 09:07:53.823981 190428 net.cpp:282] Setting up mbox_priorbox
#
# I0323 09:07:53.824045 190428 net.cpp:289] Top shape: 1 2 34928 (69856)
#
# I0323 09:07:53.824120 190428 net.cpp:297] Memory required for data: 8019836736
#
# I0323 09:07:53.824187 190428 layer_factory.hpp:114] Creating layer mbox_conf_reshape
#
# I0323 09:07:53.824287 190428 net.cpp:197] Creating Layer mbox_conf_reshape
#
# I0323 09:07:53.824374 190428 net.cpp:892] mbox_conf_reshape <- mbox_conf
#
# I0323 09:07:53.824455 190428 net.cpp:866] mbox_conf_reshape -> mbox_conf_reshape
#
# I0323 09:07:53.824573 190428 net.cpp:282] Setting up mbox_conf_reshape
#
# I0323 09:07:53.824640 190428 net.cpp:289] Top shape: 32 8732 21 (5867904)
#
# I0323 09:07:53.824715 190428 net.cpp:297] Memory required for data: 8043308352
#
# I0323 09:07:53.824784 190428 layer_factory.hpp:114] Creating layer mbox_conf_softmax
#
# I0323 09:07:53.824863 190428 net.cpp:197] Creating Layer mbox_conf_softmax
#
# I0323 09:07:53.824929 190428 net.cpp:892] mbox_conf_softmax <- mbox_conf_reshape
#
# I0323 09:07:53.825006 190428 net.cpp:866] mbox_conf_softmax -> mbox_conf_softmax
#
# I0323 09:07:53.825137 190428 net.cpp:282] Setting up mbox_conf_softmax
#
# I0323 09:07:53.825208 190428 net.cpp:289] Top shape: 32 8732 21 (5867904)
#
# I0323 09:07:53.825284 190428 net.cpp:297] Memory required for data: 8066779968
#
# I0323 09:07:53.825381 190428 layer_factory.hpp:114] Creating layer mbox_conf_flatten
#
# I0323 09:07:53.825460 190428 net.cpp:197] Creating Layer mbox_conf_flatten
#
# I0323 09:07:53.825525 190428 net.cpp:892] mbox_conf_flatten <- mbox_conf_softmax
#
# I0323 09:07:53.825603 190428 net.cpp:866] mbox_conf_flatten -> mbox_conf_flatten
#
# I0323 09:07:53.825691 190428 net.cpp:282] Setting up mbox_conf_flatten
#
# I0323 09:07:53.825755 190428 net.cpp:289] Top shape: 32 183372 (5867904)
#
# I0323 09:07:53.825932 190428 net.cpp:297] Memory required for data: 8090251584
#
# I0323 09:07:53.826011 190428 layer_factory.hpp:114] Creating layer detection_out
#
# I0323 09:07:53.826124 190428 net.cpp:197] Creating Layer detection_out
#
# I0323 09:07:53.826195 190428 net.cpp:892] detection_out <- mbox_loc
#
# I0323 09:07:53.826268 190428 net.cpp:892] detection_out <- mbox_conf_flatten
#
# I0323 09:07:53.826365 190428 net.cpp:892] detection_out <- mbox_priorbox
#
# I0323 09:07:53.826449 190428 net.cpp:866] detection_out -> detection_out
#
# I0323 09:07:53.835644 190428 net.cpp:282] Setting up detection_out
#
# I0323 09:07:53.835971 190428 net.cpp:289] Top shape: 1 1 1 7 (7)
#
# I0323 09:07:53.836199 190428 net.cpp:297] Memory required for data: 8090251612
#
# I0323 09:07:53.836447 190428 layer_factory.hpp:114] Creating layer detection_eval
#
# I0323 09:07:53.836825 190428 net.cpp:197] Creating Layer detection_eval
#
# I0323 09:07:53.836918 190428 net.cpp:892] detection_eval <- detection_out
#
# I0323 09:07:53.837003 190428 net.cpp:892] detection_eval <- label
#
# I0323 09:07:53.837092 190428 net.cpp:866] detection_eval -> detection_eval
#
# I0323 09:07:53.837246 190428 net.cpp:282] Setting up detection_eval
#
# I0323 09:07:53.837323 190428 net.cpp:289] Top shape: 1 1 21 5 (105)
#
# I0323 09:07:53.837478 190428 net.cpp:297] Memory required for data: 8090252032
#
# I0323 09:07:53.837555 190428 net.cpp:361] detection_eval does not need backward computation.
#
# I0323 09:07:53.837631 190428 net.cpp:361] detection_out does not need backward computation.
#
# I0323 09:07:53.837707 190428 net.cpp:361] mbox_conf_flatten does not need backward computation.
#
# I0323 09:07:53.837780 190428 net.cpp:361] mbox_conf_softmax does not need backward computation.
#
# I0323 09:07:53.837855 190428 net.cpp:361] mbox_conf_reshape does not need backward computation.
#
# I0323 09:07:53.837929 190428 net.cpp:361] mbox_priorbox does not need backward computation.
#
# I0323 09:07:53.838002 190428 net.cpp:361] mbox_conf does not need backward computation.
#
# I0323 09:07:53.838075 190428 net.cpp:361] mbox_loc does not need backward computation.
#
# I0323 09:07:53.838146 190428 net.cpp:361] conv9_2_mbox_priorbox does not need backward computation.
#
# I0323 09:07:53.838214 190428 net.cpp:361] conv9_2_mbox_conf_flat does not need backward computation.
#
# I0323 09:07:53.838280 190428 net.cpp:361] conv9_2_mbox_conf_perm does not need backward computation.
#
# I0323 09:07:53.838367 190428 net.cpp:361] conv9_2_mbox_conf does not need backward computation.
#
# I0323 09:07:53.838438 190428 net.cpp:361] conv9_2_mbox_loc_flat does not need backward computation.
#
# I0323 09:07:53.838505 190428 net.cpp:361] conv9_2_mbox_loc_perm does not need backward computation.
#
# I0323 09:07:53.838572 190428 net.cpp:361] conv9_2_mbox_loc does not need backward computation.
#
# I0323 09:07:53.838639 190428 net.cpp:361] conv8_2_mbox_priorbox does not need backward computation.
#
# I0323 09:07:53.838706 190428 net.cpp:361] conv8_2_mbox_conf_flat does not need backward computation.
#
# I0323 09:07:53.838774 190428 net.cpp:361] conv8_2_mbox_conf_perm does not need backward computation.
#
# I0323 09:07:53.838840 190428 net.cpp:361] conv8_2_mbox_conf does not need backward computation.
#
# I0323 09:07:53.838908 190428 net.cpp:361] conv8_2_mbox_loc_flat does not need backward computation.
#
# I0323 09:07:53.838975 190428 net.cpp:361] conv8_2_mbox_loc_perm does not need backward computation.
#
# I0323 09:07:53.839042 190428 net.cpp:361] conv8_2_mbox_loc does not need backward computation.
#
# I0323 09:07:53.839109 190428 net.cpp:361] conv7_2_mbox_priorbox does not need backward computation.
#
# I0323 09:07:53.839177 190428 net.cpp:361] conv7_2_mbox_conf_flat does not need backward computation.
#
# I0323 09:07:53.839246 190428 net.cpp:361] conv7_2_mbox_conf_perm does not need backward computation.
#
# I0323 09:07:53.839313 190428 net.cpp:361] conv7_2_mbox_conf does not need backward computation.
#
# I0323 09:07:53.839396 190428 net.cpp:361] conv7_2_mbox_loc_flat does not need backward computation.
#
# I0323 09:07:53.839473 190428 net.cpp:361] conv7_2_mbox_loc_perm does not need backward computation.
#
# I0323 09:07:53.839546 190428 net.cpp:361] conv7_2_mbox_loc does not need backward computation.
#
# I0323 09:07:53.839717 190428 net.cpp:361] conv6_2_mbox_priorbox does not need backward computation.
#
# I0323 09:07:53.839787 190428 net.cpp:361] conv6_2_mbox_conf_flat does not need backward computation.
#
# I0323 09:07:53.839855 190428 net.cpp:361] conv6_2_mbox_conf_perm does not need backward computation.
#
# I0323 09:07:53.839922 190428 net.cpp:361] conv6_2_mbox_conf does not need backward computation.
#
# I0323 09:07:53.839989 190428 net.cpp:361] conv6_2_mbox_loc_flat does not need backward computation.
#
# I0323 09:07:53.840056 190428 net.cpp:361] conv6_2_mbox_loc_perm does not need backward computation.
#
# I0323 09:07:53.840124 190428 net.cpp:361] conv6_2_mbox_loc does not need backward computation.
#
# I0323 09:07:53.840191 190428 net.cpp:361] fc7_mbox_priorbox does not need backward computation.
#
# I0323 09:07:53.840260 190428 net.cpp:361] fc7_mbox_conf_flat does not need backward computation.
#
# I0323 09:07:53.840327 190428 net.cpp:361] fc7_mbox_conf_perm does not need backward computation.
#
# I0323 09:07:53.840422 190428 net.cpp:361] fc7_mbox_conf does not need backward computation.
#
# I0323 09:07:53.840490 190428 net.cpp:361] fc7_mbox_loc_flat does not need backward computation.
#
# I0323 09:07:53.840557 190428 net.cpp:361] fc7_mbox_loc_perm does not need backward computation.
#
# I0323 09:07:53.840625 190428 net.cpp:361] fc7_mbox_loc does not need backward computation.
#
# I0323 09:07:53.840692 190428 net.cpp:361] conv4_3_norm_mbox_priorbox does not need backward computation.
#
# I0323 09:07:53.840759 190428 net.cpp:361] conv4_3_norm_mbox_conf_flat does not need backward computation.
#
# I0323 09:07:53.840826 190428 net.cpp:361] conv4_3_norm_mbox_conf_perm does not need backward computation.
#
# I0323 09:07:53.840893 190428 net.cpp:361] conv4_3_norm_mbox_conf does not need backward computation.
#
# I0323 09:07:53.840961 190428 net.cpp:361] conv4_3_norm_mbox_loc_flat does not need backward computation.
#
# I0323 09:07:53.841028 190428 net.cpp:361] conv4_3_norm_mbox_loc_perm does not need backward computation.
#
# I0323 09:07:53.841096 190428 net.cpp:361] conv4_3_norm_mbox_loc does not need backward computation.
#
# I0323 09:07:53.841163 190428 net.cpp:361] conv4_3_norm_conv4_3_norm_0_split does not need backward computation.
#
# I0323 09:07:53.841231 190428 net.cpp:361] conv4_3_norm does not need backward computation.
#
# I0323 09:07:53.841300 190428 net.cpp:361] conv9_2_conv9_2_relu_0_split does not need backward computation.
#
# I0323 09:07:53.841382 190428 net.cpp:361] conv9_2_relu does not need backward computation.
#
# I0323 09:07:53.841449 190428 net.cpp:361] conv9_2 does not need backward computation.
#
# I0323 09:07:53.841516 190428 net.cpp:361] conv9_1_relu does not need backward computation.
#
# I0323 09:07:53.841583 190428 net.cpp:361] conv9_1 does not need backward computation.
#
# I0323 09:07:53.841650 190428 net.cpp:361] conv8_2_conv8_2_relu_0_split does not need backward computation.
#
# I0323 09:07:53.841717 190428 net.cpp:361] conv8_2_relu does not need backward computation.
#
# I0323 09:07:53.841784 190428 net.cpp:361] conv8_2 does not need backward computation.
#
# I0323 09:07:53.841850 190428 net.cpp:361] conv8_1_relu does not need backward computation.
#
# I0323 09:07:53.841917 190428 net.cpp:361] conv8_1 does not need backward computation.
#
# I0323 09:07:53.841985 190428 net.cpp:361] conv7_2_conv7_2_relu_0_split does not need backward computation.
#
# I0323 09:07:53.842052 190428 net.cpp:361] conv7_2_relu does not need backward computation.
#
# I0323 09:07:53.842118 190428 net.cpp:361] conv7_2 does not need backward computation.
#
# I0323 09:07:53.842186 190428 net.cpp:361] conv7_1_relu does not need backward computation.
#
# I0323 09:07:53.842252 190428 net.cpp:361] conv7_1 does not need backward computation.
#
# I0323 09:07:53.842320 190428 net.cpp:361] conv6_2_conv6_2_relu_0_split does not need backward computation.
#
# I0323 09:07:53.842399 190428 net.cpp:361] conv6_2_relu does not need backward computation.
#
# I0323 09:07:53.842466 190428 net.cpp:361] conv6_2 does not need backward computation.
#
# I0323 09:07:53.842533 190428 net.cpp:361] conv6_1_relu does not need backward computation.
#
# I0323 09:07:53.842599 190428 net.cpp:361] conv6_1 does not need backward computation.
#
# I0323 09:07:53.842707 190428 net.cpp:361] fc7_relu7_0_split does not need backward computation.
#
# I0323 09:07:53.842775 190428 net.cpp:361] relu7 does not need backward computation.
#
# I0323 09:07:53.842841 190428 net.cpp:361] fc7 does not need backward computation.
#
# I0323 09:07:53.842910 190428 net.cpp:361] relu6 does not need backward computation.
#
# I0323 09:07:53.842975 190428 net.cpp:361] fc6 does not need backward computation.
#
# I0323 09:07:53.843041 190428 net.cpp:361] pool5 does not need backward computation.
#
# I0323 09:07:53.843109 190428 net.cpp:361] relu5_3 does not need backward computation.
#
# I0323 09:07:53.843175 190428 net.cpp:361] conv5_3 does not need backward computation.
#
# I0323 09:07:53.843242 190428 net.cpp:361] relu5_2 does not need backward computation.
#
# I0323 09:07:53.843309 190428 net.cpp:361] conv5_2 does not need backward computation.
#
# I0323 09:07:53.843394 190428 net.cpp:361] relu5_1 does not need backward computation.
#
# I0323 09:07:53.843461 190428 net.cpp:361] conv5_1 does not need backward computation.
#
# I0323 09:07:53.843528 190428 net.cpp:361] pool4 does not need backward computation.
#
# I0323 09:07:53.843595 190428 net.cpp:361] conv4_3_relu4_3_0_split does not need backward computation.
#
# I0323 09:07:53.843664 190428 net.cpp:361] relu4_3 does not need backward computation.
#
# I0323 09:07:53.843730 190428 net.cpp:361] conv4_3 does not need backward computation.
#
# I0323 09:07:53.843797 190428 net.cpp:361] relu4_2 does not need backward computation.
#
# I0323 09:07:53.843863 190428 net.cpp:361] conv4_2 does not need backward computation.
#
# I0323 09:07:53.843931 190428 net.cpp:361] relu4_1 does not need backward computation.
#
# I0323 09:07:53.843997 190428 net.cpp:361] conv4_1 does not need backward computation.
#
# I0323 09:07:53.844063 190428 net.cpp:361] pool3 does not need backward computation.
#
# I0323 09:07:53.844130 190428 net.cpp:361] relu3_3 does not need backward computation.
#
# I0323 09:07:53.844197 190428 net.cpp:361] conv3_3 does not need backward computation.
#
# I0323 09:07:53.844265 190428 net.cpp:361] relu3_2 does not need backward computation.
#
# I0323 09:07:53.844331 190428 net.cpp:361] conv3_2 does not need backward computation.
#
# I0323 09:07:53.844413 190428 net.cpp:361] relu3_1 does not need backward computation.
#
# I0323 09:07:53.844480 190428 net.cpp:361] conv3_1 does not need backward computation.
#
# I0323 09:07:53.844547 190428 net.cpp:361] pool2 does not need backward computation.
#
# I0323 09:07:53.844614 190428 net.cpp:361] relu2_2 does not need backward computation.
#
# I0323 09:07:53.844679 190428 net.cpp:361] conv2_2 does not need backward computation.
#
# I0323 09:07:53.844746 190428 net.cpp:361] relu2_1 does not need backward computation.
#
# I0323 09:07:53.844813 190428 net.cpp:361] conv2_1 does not need backward computation.
#
# I0323 09:07:53.844879 190428 net.cpp:361] pool1 does not need backward computation.
#
# I0323 09:07:53.844946 190428 net.cpp:361] relu1_2 does not need backward computation.
#
# I0323 09:07:53.845012 190428 net.cpp:361] conv1_2 does not need backward computation.
#
# I0323 09:07:53.845078 190428 net.cpp:361] relu1_1 does not need backward computation.
#
# I0323 09:07:53.845145 190428 net.cpp:361] conv1_1 does not need backward computation.
#
# I0323 09:07:53.845214 190428 net.cpp:361] data_data_0_split does not need backward computation.
#
# I0323 09:07:53.845283 190428 net.cpp:361] data does not need backward computation.
#
# I0323 09:07:53.845358 190428 net.cpp:403] This network produces output detection_eval
#
# I0323 09:07:53.845633 190428 net.cpp:496] Network initialization done.
#
# I0323 09:07:53.847394 190428 solver.cpp:122] Solver scaffolding done.
#
# I0323 09:07:53.848080 190428 caffe.cpp:324] Starting Optimization
#
# I0323 09:07:53.848172 190428 solver.cpp:495] Solving VGG_VOC0712_SSD_300x300_train
#
# I0323 09:07:53.848242 190428 solver.cpp:496] Learning Rate Policy: exp
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-efa303a4d2ed> in <module>()
#      16         if process.poll() is not None and len(out) == 0:
#      17             break
# ---> 18 except KeyboardInterupt:
#      19     get_ipython().system(u"qdel {job_info['id']}")
#      20     get_ipython().system(u'qstat')
#
# NameError: name 'KeyboardInterupt' is not defined
