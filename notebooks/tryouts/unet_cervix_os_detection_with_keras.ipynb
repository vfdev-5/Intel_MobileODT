# %% [markdown]
# # Train U-Net for cervix/os detection

# %%
# https://ipython.org/ipython-doc/3/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from datetime import datetime
    
# Project
project_common_path = os.path.abspath(os.path.join('..', 'common'))
if not project_common_path in sys.path:
    sys.path.append(project_common_path)

# %%
import matplotlib.pylab as plt
# %matplotlib inline

def plt_st(n, m):
    plt.figure(figsize=(n, m))
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# ## Transform `sloth` annotations to label images

# %%
from data_utils import type_1_ids, type_2_ids, type_3_ids, test_ids
from data_utils import RESOURCES_PATH, GENERATED_DATA, get_annotations

from image_utils import get_image_data
from image_utils import generate_label_images

# %%
sloth_annotations_filename = os.path.join(RESOURCES_PATH, 'cervix_os.json')
annotations = get_annotations(sloth_annotations_filename)
print(len(annotations))

#generate_label_images(annotations)
# Out:
# 1303

# %%
# !ls {GENERATED_DATA}/
ret = !ls {GENERATED_DATA}/trainval_labels_0 | wc -l
print(ret[0])

assert len(annotations) == int(ret[0]), "WTF"
# Out:
# cervix_train_stats.npz
# check_cervix_stats.npz
# check_os_stats.npz
# os_cervix_labels_1
# os_cervix_labels_2
# os_cervix_labels_final
# resnet_4_dense_adadelta_seed=2017_stats.npz
# resnet_4_dense_cervix_adadelta_seed=2017_stats.npz
# resnet_4_dense_cervix_nadam_seed=2017_stats.npz
# resnet_4_dense_nadam_seed=2017_stats.npz
# resnet_4_dense_seed=2017_stats.npz
# resnet_not_trained_original_cervix_adadelta_seed=2017_stats.npz
# resnet_not_trained_original_norm_cervix_adadelta_seed=2017_stats.npz
# resnet_original_cervix_seed=2017_stats.npz
# templates.csv
# test
# train
# trainval_labels_0
# unet_os_cervix_detector_opt=adadelta_seed=54321_lr=1.000_a=0.975_stats.npz
# unet_os_cervix_detector_seed=2017_lr=0.001_a=0.925_stats.npz
# xception_trained_3_dense_norm_cervix_adadelta_seed=2017_stats.npz
# xception_trained_3_dense_norm_os_adadelta_seed=2017_stats.npz
# xception_trained_norm_os_adadelta_seed=2017_stats.npz
# xception_trained_original_cervix_adadelta_seed=2017_stats.npz
# xception_trained_original_norm_cervix_adadelta_seed=2017_stats.npz
#     1303

# %% [markdown]
# ## Train and validate

# %%
import numpy as np

from training_utils import get_trainval_id_type_lists2
from test_utils import get_test_id_type_list2

from unet_keras_v1 import get_unet

from training_utils import segmentation_train as train, segmentation_validate as validate
from test_utils import segmentation_predict as predict
from xy_providers import DataCache
# Out:
# Using Theano backend.
# Couldn't import dot_parser, loading of dot files will not be possible.
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# Using gpu device 0: GeForce GT 750M (CNMeM is enabled with initial size: 50.0% of memory, cuDNN 5110)

# %%
print("\n {} - Get U-Net model ...".format(datetime.now()))
optimizer = 'adadelta'
unet = get_unet(input_shape=(3, 224, 224), n_classes=2, optimizer=optimizer)
# Out:
#  2017-04-15 16:12:13.750688 - Get U-Net model ...

# %%
unet.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 3, 224, 224)   0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)  (None, 32, 224, 224)  896         input_1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_1 (BatchNorma (None, 32, 224, 224)  128         convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 32, 224, 224)  0           batchnormalization_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)  (None, 32, 224, 224)  9248        activation_1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_2 (BatchNorma (None, 32, 224, 224)  128         convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 32, 224, 224)  0           batchnormalization_2[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_1 (MaxPooling2D)    (None, 32, 112, 112)  0           activation_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)  (None, 64, 112, 112)  18496       maxpooling2d_1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_3 (BatchNorma (None, 64, 112, 112)  256         convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 64, 112, 112)  0           batchnormalization_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)  (None, 64, 112, 112)  36928       activation_3[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_4 (BatchNorma (None, 64, 112, 112)  256         convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 64, 112, 112)  0           batchnormalization_4[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_2 (MaxPooling2D)    (None, 64, 56, 56)    0           activation_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)  (None, 128, 56, 56)   73856       maxpooling2d_2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_5 (BatchNorma (None, 128, 56, 56)   512         convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 128, 56, 56)   0           batchnormalization_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6 (Convolution2D)  (None, 128, 56, 56)   147584      activation_5[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_6 (BatchNorma (None, 128, 56, 56)   512         convolution2d_6[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 128, 56, 56)   0           batchnormalization_6[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_3 (MaxPooling2D)    (None, 128, 28, 28)   0           activation_6[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7 (Convolution2D)  (None, 256, 28, 28)   295168      maxpooling2d_3[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_7 (BatchNorma (None, 256, 28, 28)   1024        convolution2d_7[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 256, 28, 28)   0           batchnormalization_7[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)  (None, 256, 28, 28)   590080      activation_7[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_8 (BatchNorma (None, 256, 28, 28)   1024        convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, 256, 28, 28)   0           batchnormalization_8[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_4 (MaxPooling2D)    (None, 256, 14, 14)   0           activation_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_9 (Convolution2D)  (None, 512, 14, 14)   1180160     maxpooling2d_4[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_9 (BatchNorma (None, 512, 14, 14)   2048        convolution2d_9[0][0]
# ____________________________________________________________________________________________________
# activation_9 (Activation)        (None, 512, 14, 14)   0           batchnormalization_9[0][0]
# ____________________________________________________________________________________________________
# convolution2d_10 (Convolution2D) (None, 512, 14, 14)   2359808     activation_9[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_10 (BatchNorm (None, 512, 14, 14)   2048        convolution2d_10[0][0]
# ____________________________________________________________________________________________________
# activation_10 (Activation)       (None, 512, 14, 14)   0           batchnormalization_10[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_5 (MaxPooling2D)    (None, 512, 7, 7)     0           activation_10[0][0]
# ____________________________________________________________________________________________________
# convolution2d_11 (Convolution2D) (None, 1024, 7, 7)    4719616     maxpooling2d_5[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_11 (BatchNorm (None, 1024, 7, 7)    4096        convolution2d_11[0][0]
# ____________________________________________________________________________________________________
# activation_11 (Activation)       (None, 1024, 7, 7)    0           batchnormalization_11[0][0]
# ____________________________________________________________________________________________________
# convolution2d_12 (Convolution2D) (None, 1024, 7, 7)    9438208     activation_11[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_12 (BatchNorm (None, 1024, 7, 7)    4096        convolution2d_12[0][0]
# ____________________________________________________________________________________________________
# activation_12 (Activation)       (None, 1024, 7, 7)    0           batchnormalization_12[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_1 (UpSampling2D)    (None, 1024, 14, 14)  0           activation_12[0][0]
# ____________________________________________________________________________________________________
# merge_1 (Merge)                  (None, 1536, 14, 14)  0           upsampling2d_1[0][0]
#                                                                    activation_10[0][0]
# ____________________________________________________________________________________________________
# convolution2d_13 (Convolution2D) (None, 512, 14, 14)   7078400     merge_1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_13 (BatchNorm (None, 512, 14, 14)   2048        convolution2d_13[0][0]
# ____________________________________________________________________________________________________
# activation_13 (Activation)       (None, 512, 14, 14)   0           batchnormalization_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D) (None, 512, 14, 14)   2359808     activation_13[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_14 (BatchNorm (None, 512, 14, 14)   2048        convolution2d_14[0][0]
# ____________________________________________________________________________________________________
# activation_14 (Activation)       (None, 512, 14, 14)   0           batchnormalization_14[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_2 (UpSampling2D)    (None, 512, 28, 28)   0           activation_14[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                  (None, 768, 28, 28)   0           upsampling2d_2[0][0]
#                                                                    activation_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D) (None, 256, 28, 28)   1769728     merge_2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_15 (BatchNorm (None, 256, 28, 28)   1024        convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# activation_15 (Activation)       (None, 256, 28, 28)   0           batchnormalization_15[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D) (None, 256, 28, 28)   590080      activation_15[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_16 (BatchNorm (None, 256, 28, 28)   1024        convolution2d_16[0][0]
# ____________________________________________________________________________________________________
# activation_16 (Activation)       (None, 256, 28, 28)   0           batchnormalization_16[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_3 (UpSampling2D)    (None, 256, 56, 56)   0           activation_16[0][0]
# ____________________________________________________________________________________________________
# merge_3 (Merge)                  (None, 384, 56, 56)   0           upsampling2d_3[0][0]
#                                                                    activation_6[0][0]
# ____________________________________________________________________________________________________
# convolution2d_17 (Convolution2D) (None, 128, 56, 56)   442496      merge_3[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_17 (BatchNorm (None, 128, 56, 56)   512         convolution2d_17[0][0]
# ____________________________________________________________________________________________________
# activation_17 (Activation)       (None, 128, 56, 56)   0           batchnormalization_17[0][0]
# ____________________________________________________________________________________________________
# convolution2d_18 (Convolution2D) (None, 128, 56, 56)   147584      activation_17[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_18 (BatchNorm (None, 128, 56, 56)   512         convolution2d_18[0][0]
# ____________________________________________________________________________________________________
# activation_18 (Activation)       (None, 128, 56, 56)   0           batchnormalization_18[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_4 (UpSampling2D)    (None, 128, 112, 112) 0           activation_18[0][0]
# ____________________________________________________________________________________________________
# merge_4 (Merge)                  (None, 192, 112, 112) 0           upsampling2d_4[0][0]
#                                                                    activation_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_19 (Convolution2D) (None, 64, 112, 112)  110656      merge_4[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_19 (BatchNorm (None, 64, 112, 112)  256         convolution2d_19[0][0]
# ____________________________________________________________________________________________________
# activation_19 (Activation)       (None, 64, 112, 112)  0           batchnormalization_19[0][0]
# ____________________________________________________________________________________________________
# convolution2d_20 (Convolution2D) (None, 64, 112, 112)  36928       activation_19[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_20 (BatchNorm (None, 64, 112, 112)  256         convolution2d_20[0][0]
# ____________________________________________________________________________________________________
# activation_20 (Activation)       (None, 64, 112, 112)  0           batchnormalization_20[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_5 (UpSampling2D)    (None, 64, 224, 224)  0           activation_20[0][0]
# ____________________________________________________________________________________________________
# merge_5 (Merge)                  (None, 96, 224, 224)  0           upsampling2d_5[0][0]
#                                                                    activation_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_21 (Convolution2D) (None, 32, 224, 224)  27680       merge_5[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_21 (BatchNorm (None, 32, 224, 224)  128         convolution2d_21[0][0]
# ____________________________________________________________________________________________________
# activation_21 (Activation)       (None, 32, 224, 224)  0           batchnormalization_21[0][0]
# ____________________________________________________________________________________________________
# convolution2d_22 (Convolution2D) (None, 32, 224, 224)  9248        activation_21[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_22 (BatchNorm (None, 32, 224, 224)  128         convolution2d_22[0][0]
# ____________________________________________________________________________________________________
# activation_22 (Activation)       (None, 32, 224, 224)  0           batchnormalization_22[0][0]
# ____________________________________________________________________________________________________
# convolution2d_23 (Convolution2D) (None, 2, 224, 224)   66          activation_22[0][0]
# ____________________________________________________________________________________________________
# activation_23 (Activation)       (None, 2, 224, 224)   0           convolution2d_23[0][0]
# ====================================================================================================
# Total params: 31,466,786
# Trainable params: 31,454,754
# Non-trainable params: 12,032
# ____________________________________________________________________________________________________

# %% [markdown]
# Load trained weights

# %%
from training_utils import exp_decay

lr_base = 1.0
lr_1 = 1 * lr_base; a_1 = 0.975
lr_2 = 1 * lr_base; a_2 = 0.875
lr_3 = 1 * lr_base; a_3 = 0.8

epochs = np.arange(0, 50)
lrs_1 = exp_decay(epochs, lr=lr_1, a=a_1)
lrs_2 = exp_decay(epochs, lr=lr_2, a=a_2)
lrs_3 = exp_decay(epochs, lr=lr_3, a=a_3)
plt_st(12, 5)
plt.plot(epochs, lrs_1, label="lr=%f, a=%f" % (lr_1, a_1))
plt.plot(epochs, lrs_2, label="lr=%f, a=%f" % (lr_2, a_2))
plt.plot(epochs, lrs_3, label="lr=%f, a=%f" % (lr_3, a_3))
plt.legend()

# %%
seed = 54321
np.random.seed(seed)
save_prefix='unet_os_cervix_detector_opt=%s_seed=%i_lr=%.3f_a=%.3f' % (optimizer, seed, lr_1, a_1)

# %%
train_id_type_list, val_id_type_list = get_trainval_id_type_lists2(annotations=annotations, val_split=0.215)

print "Total : %s, Train : %s, Val : %s" % (len(annotations), len(train_id_type_list), len(val_id_type_list))
# Out:
# Total : 1303, Train : 1022, Val : 281

# %%
from glob import glob
from training_utils import find_best_weights_file

weights_files = glob("weights/%s*.h5" % save_prefix)
best_weights_filename, best_val_loss = find_best_weights_file(weights_files)
print("Best val loss weights: ", best_weights_filename)

if len(best_weights_filename) > 0:
    # load weights to the model
    print("Load found weights: ", best_weights_filename)
    unet.load_weights(best_weights_filename)
# Out:
# ('Best val loss weights: ', '')

# %%
# Define only once
try:
    if cache is None: 
        cache = DataCache(0)    
except NameError:
    cache = DataCache(0)

# %%
if True:
        
    nb_epochs = 50
    batch_size = 4
    
    #lr_1 = 1e-5; a_1 = 0.985
    lrate_decay_f = lambda epoch: exp_decay(epoch, lr=lr_1, a=a_1) 

    print("\n {} - Start training ...".format(datetime.now()))
    h = train(unet, 
              train_id_type_list, 
              val_id_type_list, 
              nb_epochs=nb_epochs,
              samples_per_epoch=1024,
              nb_val_samples=512,
              lrate_decay_f=lrate_decay_f,
              batch_size=batch_size, 
              xy_provider_cache=cache,
              seed=seed,
              save_prefix=save_prefix)
# Out:
#  2017-04-15 16:12:15.081427 - Start training ...
#
# -- Training parameters: 4, 50, 1024, 512
#
# -- Fit stats of train dataset
# Load existing file: /Users/vfomin/Documents/ML/Kaggle/Intel_MobileODT/input/generated/unet_os_cervix_detector_opt=adadelta_seed=54321_lr=1.000_a=0.975_stats.npz
# No need to recompute statistics
#
# -- Fit model
# Epoch 1/50
# 1024/1024 [==============================] - 933s - loss: 0.7118 - jaccard_index: 0.2882 - recall: 0.8336 - precision: 0.4383 - val_loss: 0.6501 - val_jaccard_index: 0.3499 - val_recall: 0.8802 - val_precision: 0.5309
# Epoch 2/50
# 1024/1024 [==============================] - 839s - loss: 0.6712 - jaccard_index: 0.3288 - recall: 0.7898 - precision: 0.5374 - val_loss: 0.5970 - val_jaccard_index: 0.4030 - val_recall: 0.8304 - val_precision: 0.6203
# Epoch 3/50
# 1024/1024 [==============================] - 839s - loss: 0.6428 - jaccard_index: 0.3572 - recall: 0.7870 - precision: 0.5992 - val_loss: 0.5644 - val_jaccard_index: 0.4356 - val_recall: 0.8253 - val_precision: 0.6570
# Epoch 4/50
# 1024/1024 [==============================] - 841s - loss: 0.6308 - jaccard_index: 0.3692 - recall: 0.7858 - precision: 0.6153 - val_loss: 0.5736 - val_jaccard_index: 0.4264 - val_recall: 0.7873 - val_precision: 0.6703
# Epoch 5/50
# 1024/1024 [==============================] - 847s - loss: 0.6193 - jaccard_index: 0.3807 - recall: 0.7886 - precision: 0.6373 - val_loss: 0.5630 - val_jaccard_index: 0.4370 - val_recall: 0.8636 - val_precision: 0.6301
# Epoch 6/50
# 1024/1024 [==============================] - 848s - loss: 0.6041 - jaccard_index: 0.3959 - recall: 0.8058 - precision: 0.6495 - val_loss: 0.5265 - val_jaccard_index: 0.4735 - val_recall: 0.8484 - val_precision: 0.6740
# Epoch 7/50
# 1024/1024 [==============================] - 848s - loss: 0.5860 - jaccard_index: 0.4140 - recall: 0.8146 - precision: 0.6786 - val_loss: 0.4862 - val_jaccard_index: 0.5138 - val_recall: 0.8555 - val_precision: 0.7118
# Epoch 8/50
# 1024/1024 [==============================] - 848s - loss: 0.5714 - jaccard_index: 0.4286 - recall: 0.8231 - precision: 0.6963 - val_loss: 0.4644 - val_jaccard_index: 0.5356 - val_recall: 0.8362 - val_precision: 0.7643
# Epoch 9/50
# 1024/1024 [==============================] - 840s - loss: 0.5648 - jaccard_index: 0.4352 - recall: 0.8284 - precision: 0.7086 - val_loss: 0.4629 - val_jaccard_index: 0.5371 - val_recall: 0.8739 - val_precision: 0.7188
# Epoch 10/50
# 1024/1024 [==============================] - 839s - loss: 0.5576 - jaccard_index: 0.4424 - recall: 0.8311 - precision: 0.7152 - val_loss: 0.4604 - val_jaccard_index: 0.5396 - val_recall: 0.9049 - val_precision: 0.7040
# Epoch 11/50
# 1024/1024 [==============================] - 839s - loss: 0.5485 - jaccard_index: 0.4515 - recall: 0.8380 - precision: 0.7219 - val_loss: 0.4516 - val_jaccard_index: 0.5484 - val_recall: 0.8769 - val_precision: 0.7398
# Epoch 12/50
# 1024/1024 [==============================] - 838s - loss: 0.5507 - jaccard_index: 0.4493 - recall: 0.8376 - precision: 0.7262 - val_loss: 0.4808 - val_jaccard_index: 0.5192 - val_recall: 0.8637 - val_precision: 0.7219
# Epoch 13/50
# 1024/1024 [==============================] - 848s - loss: 0.5442 - jaccard_index: 0.4558 - recall: 0.8401 - precision: 0.7269 - val_loss: 0.4422 - val_jaccard_index: 0.5578 - val_recall: 0.8950 - val_precision: 0.7304
# Epoch 14/50
# 1024/1024 [==============================] - 846s - loss: 0.5407 - jaccard_index: 0.4593 - recall: 0.8450 - precision: 0.7319 - val_loss: 0.4404 - val_jaccard_index: 0.5596 - val_recall: 0.8723 - val_precision: 0.7554
# Epoch 15/50
# 1024/1024 [==============================] - 840s - loss: 0.5381 - jaccard_index: 0.4619 - recall: 0.8458 - precision: 0.7375 - val_loss: 0.4197 - val_jaccard_index: 0.5803 - val_recall: 0.8738 - val_precision: 0.7742
# Epoch 16/50
# 1024/1024 [==============================] - 841s - loss: 0.5367 - jaccard_index: 0.4633 - recall: 0.8431 - precision: 0.7377 - val_loss: 0.4289 - val_jaccard_index: 0.5711 - val_recall: 0.8540 - val_precision: 0.7828
# Epoch 17/50
# 1024/1024 [==============================] - 839s - loss: 0.5262 - jaccard_index: 0.4738 - recall: 0.8456 - precision: 0.7498 - val_loss: 0.4145 - val_jaccard_index: 0.5855 - val_recall: 0.8677 - val_precision: 0.7774
# Epoch 18/50
# 1024/1024 [==============================] - 837s - loss: 0.5313 - jaccard_index: 0.4687 - recall: 0.8457 - precision: 0.7486 - val_loss: 0.4211 - val_jaccard_index: 0.5789 - val_recall: 0.8638 - val_precision: 0.7825
# Epoch 19/50
# 1024/1024 [==============================] - 839s - loss: 0.5224 - jaccard_index: 0.4776 - recall: 0.8492 - precision: 0.7540 - val_loss: 0.4135 - val_jaccard_index: 0.5865 - val_recall: 0.8580 - val_precision: 0.7908
# Epoch 20/50
# 1024/1024 [==============================] - 839s - loss: 0.5173 - jaccard_index: 0.4827 - recall: 0.8535 - precision: 0.7648 - val_loss: 0.4115 - val_jaccard_index: 0.5885 - val_recall: 0.8641 - val_precision: 0.7935
# Epoch 21/50
# 1024/1024 [==============================] - 838s - loss: 0.5187 - jaccard_index: 0.4813 - recall: 0.8552 - precision: 0.7607 - val_loss: 0.4107 - val_jaccard_index: 0.5893 - val_recall: 0.8315 - val_precision: 0.8174
# Epoch 22/50
# 1024/1024 [==============================] - 838s - loss: 0.5217 - jaccard_index: 0.4783 - recall: 0.8550 - precision: 0.7594 - val_loss: 0.3971 - val_jaccard_index: 0.6029 - val_recall: 0.8805 - val_precision: 0.7942
# Epoch 23/50
# 1024/1024 [==============================] - 840s - loss: 0.5171 - jaccard_index: 0.4829 - recall: 0.8560 - precision: 0.7618 - val_loss: 0.3983 - val_jaccard_index: 0.6017 - val_recall: 0.8750 - val_precision: 0.7939
# Epoch 24/50
# 1024/1024 [==============================] - 840s - loss: 0.5142 - jaccard_index: 0.4858 - recall: 0.8527 - precision: 0.7711 - val_loss: 0.4003 - val_jaccard_index: 0.5997 - val_recall: 0.8790 - val_precision: 0.7957
# Epoch 25/50
# 1024/1024 [==============================] - 838s - loss: 0.5149 - jaccard_index: 0.4851 - recall: 0.8535 - precision: 0.7685 - val_loss: 0.4304 - val_jaccard_index: 0.5696 - val_recall: 0.9069 - val_precision: 0.7377
# Epoch 26/50
# 1024/1024 [==============================] - 839s - loss: 0.5138 - jaccard_index: 0.4862 - recall: 0.8612 - precision: 0.7676 - val_loss: 0.3999 - val_jaccard_index: 0.6001 - val_recall: 0.8869 - val_precision: 0.7840
# Epoch 27/50
# 1024/1024 [==============================] - 839s - loss: 0.5084 - jaccard_index: 0.4916 - recall: 0.8552 - precision: 0.7754 - val_loss: 0.3963 - val_jaccard_index: 0.6037 - val_recall: 0.8874 - val_precision: 0.7854
# Epoch 28/50
# 1024/1024 [==============================] - 838s - loss: 0.5107 - jaccard_index: 0.4893 - recall: 0.8619 - precision: 0.7724 - val_loss: 0.4051 - val_jaccard_index: 0.5949 - val_recall: 0.8845 - val_precision: 0.7799
# Epoch 29/50
# 1024/1024 [==============================] - 839s - loss: 0.5055 - jaccard_index: 0.4945 - recall: 0.8551 - precision: 0.7817 - val_loss: 0.4016 - val_jaccard_index: 0.5984 - val_recall: 0.8992 - val_precision: 0.7703
# Epoch 30/50
# 1024/1024 [==============================] - 836s - loss: 0.5116 - jaccard_index: 0.4884 - recall: 0.8623 - precision: 0.7735 - val_loss: 0.3995 - val_jaccard_index: 0.6005 - val_recall: 0.9001 - val_precision: 0.7761
# Epoch 31/50
# 1024/1024 [==============================] - 838s - loss: 0.5051 - jaccard_index: 0.4949 - recall: 0.8642 - precision: 0.7741 - val_loss: 0.4070 - val_jaccard_index: 0.5930 - val_recall: 0.8955 - val_precision: 0.7609
# Epoch 32/50
# 1024/1024 [==============================] - 836s - loss: 0.5108 - jaccard_index: 0.4892 - recall: 0.8603 - precision: 0.7753 - val_loss: 0.3949 - val_jaccard_index: 0.6051 - val_recall: 0.8794 - val_precision: 0.7965
# Epoch 33/50
# 1024/1024 [==============================] - 839s - loss: 0.5016 - jaccard_index: 0.4984 - recall: 0.8635 - precision: 0.7844 - val_loss: 0.3872 - val_jaccard_index: 0.6128 - val_recall: 0.8711 - val_precision: 0.8085
# Epoch 34/50
# 1024/1024 [==============================] - 838s - loss: 0.5004 - jaccard_index: 0.4996 - recall: 0.8646 - precision: 0.7857 - val_loss: 0.3863 - val_jaccard_index: 0.6137 - val_recall: 0.8620 - val_precision: 0.8169
# Epoch 35/50
# 1024/1024 [==============================] - 857s - loss: 0.5029 - jaccard_index: 0.4971 - recall: 0.8669 - precision: 0.7782 - val_loss: 0.3942 - val_jaccard_index: 0.6058 - val_recall: 0.8693 - val_precision: 0.8027
# Epoch 36/50
# 1024/1024 [==============================] - 846s - loss: 0.4977 - jaccard_index: 0.5023 - recall: 0.8668 - precision: 0.7882 - val_loss: 0.3940 - val_jaccard_index: 0.6060 - val_recall: 0.8876 - val_precision: 0.7905
# Epoch 37/50
# 1024/1024 [==============================] - 850s - loss: 0.4964 - jaccard_index: 0.5036 - recall: 0.8631 - precision: 0.7907 - val_loss: 0.3878 - val_jaccard_index: 0.6122 - val_recall: 0.8881 - val_precision: 0.7946
# Epoch 38/50
# 1024/1024 [==============================] - 860s - loss: 0.5003 - jaccard_index: 0.4997 - recall: 0.8602 - precision: 0.7898 - val_loss: 0.3885 - val_jaccard_index: 0.6115 - val_recall: 0.8963 - val_precision: 0.7865
# Epoch 39/50
# 1024/1024 [==============================] - 840s - loss: 0.4932 - jaccard_index: 0.5068 - recall: 0.8709 - precision: 0.7889 - val_loss: 0.3864 - val_jaccard_index: 0.6136 - val_recall: 0.8695 - val_precision: 0.8133
# Epoch 40/50
# 1024/1024 [==============================] - 838s - loss: 0.4937 - jaccard_index: 0.5063 - recall: 0.8651 - precision: 0.7929 - val_loss: 0.3967 - val_jaccard_index: 0.6033 - val_recall: 0.8905 - val_precision: 0.7880
# Epoch 41/50
# 1024/1024 [==============================] - 838s - loss: 0.4964 - jaccard_index: 0.5036 - recall: 0.8616 - precision: 0.7948 - val_loss: 0.3874 - val_jaccard_index: 0.6126 - val_recall: 0.8832 - val_precision: 0.8015
# Epoch 42/50
# 1024/1024 [==============================] - 838s - loss: 0.4964 - jaccard_index: 0.5036 - recall: 0.8664 - precision: 0.7925 - val_loss: 0.3809 - val_jaccard_index: 0.6191 - val_recall: 0.8830 - val_precision: 0.8078
# Epoch 43/50
# 1024/1024 [==============================] - 839s - loss: 0.4891 - jaccard_index: 0.5109 - recall: 0.8706 - precision: 0.7939 - val_loss: 0.3881 - val_jaccard_index: 0.6119 - val_recall: 0.8916 - val_precision: 0.7923
# Epoch 44/50
# 1024/1024 [==============================] - 839s - loss: 0.4892 - jaccard_index: 0.5108 - recall: 0.8735 - precision: 0.7961 - val_loss: 0.3967 - val_jaccard_index: 0.6033 - val_recall: 0.8963 - val_precision: 0.7838
# Epoch 45/50
# 1024/1024 [==============================] - 838s - loss: 0.4939 - jaccard_index: 0.5061 - recall: 0.8705 - precision: 0.7923 - val_loss: 0.3895 - val_jaccard_index: 0.6105 - val_recall: 0.8803 - val_precision: 0.8045
# Epoch 46/50
# 1024/1024 [==============================] - 838s - loss: 0.4895 - jaccard_index: 0.5105 - recall: 0.8721 - precision: 0.7966 - val_loss: 0.3803 - val_jaccard_index: 0.6197 - val_recall: 0.8879 - val_precision: 0.8069
# Epoch 47/50
# 1024/1024 [==============================] - 839s - loss: 0.4858 - jaccard_index: 0.5142 - recall: 0.8699 - precision: 0.7973 - val_loss: 0.3882 - val_jaccard_index: 0.6118 - val_recall: 0.9010 - val_precision: 0.7839
# Epoch 48/50
# 1024/1024 [==============================] - 839s - loss: 0.4849 - jaccard_index: 0.5151 - recall: 0.8747 - precision: 0.8002 - val_loss: 0.3821 - val_jaccard_index: 0.6179 - val_recall: 0.8810 - val_precision: 0.8111
# Epoch 49/50
# 1024/1024 [==============================] - 838s - loss: 0.4854 - jaccard_index: 0.5146 - recall: 0.8707 - precision: 0.8008 - val_loss: 0.3869 - val_jaccard_index: 0.6131 - val_recall: 0.8913 - val_precision: 0.7984
# Epoch 50/50
# 1024/1024 [==============================] - 838s - loss: 0.4891 - jaccard_index: 0.5109 - recall: 0.8726 - precision: 0.8006 - val_loss: 0.3805 - val_jaccard_index: 0.6195 - val_recall: 0.9041 - val_precision: 0.7907
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-fc01c7fdd61c> in <module>()
#      18               xy_provider_cache=cache,
#      19               seed=seed,
# ---> 20               save_prefix=save_prefix)
#
# /Users/vfomin/Documents/ML/Kaggle/Intel_MobileODT/common/training_utils.pyc in segmentation_train(model, train_id_type_list, val_id_type_list, batch_size, nb_epochs, lrate_decay_f, image_size, samples_per_epoch, nb_val_samples, xy_provider_cache, save_prefix, seed, verbose)
#     271         # save the last
#     272         val_loss = history.history['val_loss'][-1]
# --> 273         weights_filename = weights_filename.format(epoch=nb_epochs, val_loss=val_loss)
#     274         model.save_weights(weights_filename)
#     275
#
# KeyError: 'val_jaccard_index'

# %%
if True:
        
    nb_epochs = 20
    batch_size = 4
    
    lr_1 = 0.4; a_1 = 0.985
    lrate_decay_f = lambda epoch: exp_decay(epoch, lr=lr_1, a=a_1) 

    print("\n {} - Start training ...".format(datetime.now()))
    h = train(unet, 
              train_id_type_list, 
              val_id_type_list, 
              nb_epochs=nb_epochs,
              samples_per_epoch=1024,
              nb_val_samples=512,
              lrate_decay_f=lrate_decay_f,
              batch_size=batch_size, 
              xy_provider_cache=cache,
              seed=seed,
              save_prefix=save_prefix)
# Out:
#  2017-04-16 09:23:00.294463 - Start training ...
#
# -- Training parameters: 4, 20, 1024, 512
#
# -- Fit stats of train dataset
# Load existing file: /Users/vfomin/Documents/ML/Kaggle/Intel_MobileODT/input/generated/unet_os_cervix_detector_opt=adadelta_seed=54321_lr=1.000_a=0.975_stats.npz
# No need to recompute statistics
#
# -- Fit model
# Epoch 1/20
# 1024/1024 [==============================] - 840s - loss: 0.4872 - jaccard_index: 0.5128 - recall: 0.8725 - precision: 0.7972 - val_loss: 0.3740 - val_jaccard_index: 0.6260 - val_recall: 0.8939 - val_precision: 0.8002
# Epoch 2/20
# 1024/1024 [==============================] - 837s - loss: 0.4892 - jaccard_index: 0.5108 - recall: 0.8686 - precision: 0.7940 - val_loss: 0.3780 - val_jaccard_index: 0.6220 - val_recall: 0.8971 - val_precision: 0.7984
# Epoch 3/20
# 1024/1024 [==============================] - 838s - loss: 0.4843 - jaccard_index: 0.5157 - recall: 0.8769 - precision: 0.7999 - val_loss: 0.3783 - val_jaccard_index: 0.6217 - val_recall: 0.8848 - val_precision: 0.8071
# Epoch 4/20
# 1024/1024 [==============================] - 836s - loss: 0.4884 - jaccard_index: 0.5116 - recall: 0.8685 - precision: 0.8001 - val_loss: 0.3772 - val_jaccard_index: 0.6228 - val_recall: 0.8768 - val_precision: 0.8194
# Epoch 5/20
# 1024/1024 [==============================] - 837s - loss: 0.4875 - jaccard_index: 0.5125 - recall: 0.8715 - precision: 0.8020 - val_loss: 0.3664 - val_jaccard_index: 0.6336 - val_recall: 0.8777 - val_precision: 0.8245
# Epoch 6/20
# 1024/1024 [==============================] - 837s - loss: 0.4904 - jaccard_index: 0.5096 - recall: 0.8700 - precision: 0.7980 - val_loss: 0.3719 - val_jaccard_index: 0.6281 - val_recall: 0.8761 - val_precision: 0.8242
# Epoch 7/20
# 1024/1024 [==============================] - 837s - loss: 0.4875 - jaccard_index: 0.5125 - recall: 0.8740 - precision: 0.7992 - val_loss: 0.3763 - val_jaccard_index: 0.6237 - val_recall: 0.8940 - val_precision: 0.8008
# Epoch 8/20
# 1024/1024 [==============================] - 840s - loss: 0.4829 - jaccard_index: 0.5171 - recall: 0.8763 - precision: 0.8034 - val_loss: 0.3628 - val_jaccard_index: 0.6372 - val_recall: 0.8809 - val_precision: 0.8250
# Epoch 9/20
# 1024/1024 [==============================] - 838s - loss: 0.4877 - jaccard_index: 0.5123 - recall: 0.8731 - precision: 0.7986 - val_loss: 0.3740 - val_jaccard_index: 0.6260 - val_recall: 0.8887 - val_precision: 0.8095
# Epoch 10/20
# 1024/1024 [==============================] - 839s - loss: 0.4826 - jaccard_index: 0.5174 - recall: 0.8758 - precision: 0.8029 - val_loss: 0.3919 - val_jaccard_index: 0.6081 - val_recall: 0.9182 - val_precision: 0.7643
# Epoch 11/20
# 1024/1024 [==============================] - 839s - loss: 0.4821 - jaccard_index: 0.5179 - recall: 0.8757 - precision: 0.8023 - val_loss: 0.3741 - val_jaccard_index: 0.6259 - val_recall: 0.8708 - val_precision: 0.8222
# Epoch 12/20
# 1024/1024 [==============================] - 840s - loss: 0.4861 - jaccard_index: 0.5139 - recall: 0.8748 - precision: 0.8045 - val_loss: 0.3725 - val_jaccard_index: 0.6275 - val_recall: 0.8935 - val_precision: 0.8046
# Epoch 13/20
# 1024/1024 [==============================] - 841s - loss: 0.4812 - jaccard_index: 0.5188 - recall: 0.8770 - precision: 0.8038 - val_loss: 0.3725 - val_jaccard_index: 0.6275 - val_recall: 0.8672 - val_precision: 0.8292
# Epoch 14/20
# 1024/1024 [==============================] - 837s - loss: 0.4827 - jaccard_index: 0.5173 - recall: 0.8724 - precision: 0.8054 - val_loss: 0.3751 - val_jaccard_index: 0.6249 - val_recall: 0.8982 - val_precision: 0.8044
# Epoch 15/20
# 1024/1024 [==============================] - 842s - loss: 0.4853 - jaccard_index: 0.5147 - recall: 0.8763 - precision: 0.8009 - val_loss: 0.3740 - val_jaccard_index: 0.6260 - val_recall: 0.8696 - val_precision: 0.8278
# Epoch 16/20
# 1024/1024 [==============================] - 860s - loss: 0.4797 - jaccard_index: 0.5203 - recall: 0.8741 - precision: 0.8063 - val_loss: 0.3708 - val_jaccard_index: 0.6292 - val_recall: 0.8820 - val_precision: 0.8196
# Epoch 17/20
# 1024/1024 [==============================] - 909s - loss: 0.4748 - jaccard_index: 0.5252 - recall: 0.8771 - precision: 0.8082 - val_loss: 0.3704 - val_jaccard_index: 0.6296 - val_recall: 0.8793 - val_precision: 0.8215
# Epoch 18/20
# 1024/1024 [==============================] - 877s - loss: 0.4796 - jaccard_index: 0.5204 - recall: 0.8755 - precision: 0.8112 - val_loss: 0.3670 - val_jaccard_index: 0.6330 - val_recall: 0.8785 - val_precision: 0.8287
# Epoch 19/20
# 1024/1024 [==============================] - 932s - loss: 0.4749 - jaccard_index: 0.5251 - recall: 0.8761 - precision: 0.8121 - val_loss: 0.3717 - val_jaccard_index: 0.6283 - val_recall: 0.8878 - val_precision: 0.8133
# Epoch 20/20
# 1024/1024 [==============================] - 876s - loss: 0.4769 - jaccard_index: 0.5231 - recall: 0.8783 - precision: 0.8099 - val_loss: 0.3658 - val_jaccard_index: 0.6342 - val_recall: 0.8778 - val_precision: 0.8337

# %%
batch_size = 4
print("\n {} - Start validation ...".format(datetime.now()))
validate(unet, val_id_type_list, save_prefix, batch_size=batch_size)
# Out:
#  2017-04-16 14:13:57.306402 - Start validation ...
# Load existing file: /Users/vfomin/Documents/ML/Kaggle/Intel_MobileODT/input/generated/unet_os_cervix_detector_opt=adadelta_seed=54321_lr=1.000_a=0.975_stats.npz
# ('--', 4, 'batch jaccard index : ', 0.75999081, ' | info:', array([(u'1457', u'Type_2'), (u'148', u'Type_1'), (u'5045', u'AType_3'),
#        (u'619', u'AType_3')], dtype=object))
# ('--', 8, 'batch jaccard index : ', 0.66805661, ' | info:', array([(u'1140', u'Type_2'), (u'501', u'Type_2'), (u'296', u'AType_3'),
#        (u'1135', u'Type_2')], dtype=object))
# ('--', 12, 'batch jaccard index : ', 0.50375628, ' | info:', array([(u'552', u'Type_2'), (u'1451', u'Type_2'), (u'2065', u'AType_3'),
#        (u'884', u'Type_2')], dtype=object))
# ('--', 16, 'batch jaccard index : ', 0.69262218, ' | info:', array([(u'615', u'Type_2'), (u'578', u'Type_1'), (u'1052', u'AType_3'),
#        (u'227', u'AType_3')], dtype=object))
# ('--', 20, 'batch jaccard index : ', 0.62236774, ' | info:', array([(u'1299', u'Type_2'), (u'5396', u'AType_3'), (u'606', u'AType_3'),
#        (u'794', u'Type_2')], dtype=object))
# ('--', 24, 'batch jaccard index : ', 0.59870774, ' | info:', array([(u'1311', u'Type_2'), (u'1058', u'Type_2'), (u'1996', u'AType_3'),
#        (u'623', u'Type_1')], dtype=object))
# ('--', 28, 'batch jaccard index : ', 0.60553938, ' | info:', array([(u'379', u'Type_1'), (u'1389', u'Type_1'), (u'1880', u'AType_3'),
#        (u'561', u'Type_2')], dtype=object))
# ('--', 32, 'batch jaccard index : ', 0.73431528, ' | info:', array([(u'478', u'AType_3'), (u'385', u'Type_2'), (u'1222', u'Type_2'),
#        (u'404', u'Type_2')], dtype=object))
# ('--', 36, 'batch jaccard index : ', 0.58440816, ' | info:', array([(u'8', u'Type_2'), (u'1172', u'Type_2'), (u'1075', u'Type_2'),
#        (u'219', u'Type_2')], dtype=object))
# ('--', 40, 'batch jaccard index : ', 0.56396389, ' | info:', array([(u'1842', u'AType_3'), (u'1369', u'Type_2'), (u'1414', u'Type_1'),
#        (u'738', u'Type_2')], dtype=object))
# ('--', 44, 'batch jaccard index : ', 0.46003103, ' | info:', array([(u'836', u'Type_1'), (u'6053', u'AType_3'), (u'29', u'AType_3'),
#        (u'1096', u'Type_2')], dtype=object))
# ('--', 48, 'batch jaccard index : ', 0.69773388, ' | info:', array([(u'471', u'Type_1'), (u'1026', u'Type_1'), (u'214', u'AType_3'),
#        (u'303', u'Type_2')], dtype=object))
# ('--', 52, 'batch jaccard index : ', 0.65983415, ' | info:', array([(u'372', u'Type_2'), (u'1468', u'Type_1'), (u'5044', u'AType_3'),
#        (u'1117', u'Type_2')], dtype=object))
# ('--', 56, 'batch jaccard index : ', 0.60431087, ' | info:', array([(u'153', u'Type_2'), (u'1', u'Type_2'), (u'890', u'AType_3'),
#        (u'349', u'Type_1')], dtype=object))
# ('--', 60, 'batch jaccard index : ', 0.6670413, ' | info:', array([(u'1076', u'Type_2'), (u'117', u'Type_2'), (u'67', u'AType_3'),
#        (u'1443', u'Type_2')], dtype=object))
# ('--', 64, 'batch jaccard index : ', 0.55483294, ' | info:', array([(u'1043', u'Type_2'), (u'393', u'Type_2'), (u'1066', u'Type_2'),
#        (u'601', u'Type_2')], dtype=object))
# ('--', 68, 'batch jaccard index : ', 0.48889667, ' | info:', array([(u'596', u'Type_1'), (u'921', u'Type_1'), (u'250', u'Type_2'),
#        (u'1356', u'AType_3')], dtype=object))
# ('--', 72, 'batch jaccard index : ', 0.59166449, ' | info:', array([(u'256', u'AType_3'), (u'1604', u'AType_3'), (u'856', u'Type_2'),
#        (u'1944', u'AType_3')], dtype=object))
# ('--', 76, 'batch jaccard index : ', 0.69903302, ' | info:', array([(u'34', u'Type_1'), (u'374', u'Type_2'), (u'241', u'Type_2'),
#        (u'5973', u'AType_3')], dtype=object))
# ('--', 80, 'batch jaccard index : ', 0.73085308, ' | info:', array([(u'129', u'Type_1'), (u'605', u'Type_1'), (u'165', u'Type_2'),
#        (u'841', u'Type_2')], dtype=object))
# ('--', 84, 'batch jaccard index : ', 0.60784924, ' | info:', array([(u'700', u'Type_1'), (u'64', u'Type_2'), (u'101', u'Type_2'),
#        (u'58', u'AType_3')], dtype=object))
# ('--', 88, 'batch jaccard index : ', 0.68479371, ' | info:', array([(u'586', u'Type_2'), (u'326', u'Type_2'), (u'1385', u'Type_2'),
#        (u'112', u'Type_2')], dtype=object))
# ('--', 92, 'batch jaccard index : ', 0.75400835, ' | info:', array([(u'1247', u'Type_2'), (u'185', u'Type_2'), (u'254', u'Type_1'),
#        (u'1288', u'Type_1')], dtype=object))
# ('--', 96, 'batch jaccard index : ', 0.68851209, ' | info:', array([(u'5145', u'AType_3'), (u'270', u'Type_2'), (u'403', u'Type_2'),
#        (u'918', u'Type_1')], dtype=object))
# ('--', 100, 'batch jaccard index : ', 0.67171961, ' | info:', array([(u'191', u'Type_1'), (u'959', u'Type_2'), (u'1005', u'Type_2'),
#        (u'207', u'AType_3')], dtype=object))
# ('--', 104, 'batch jaccard index : ', 0.67751116, ' | info:', array([(u'5206', u'AType_3'), (u'816', u'Type_2'), (u'92', u'Type_2'),
#        (u'381', u'Type_2')], dtype=object))
# ('--', 108, 'batch jaccard index : ', 0.54450488, ' | info:', array([(u'7', u'Type_1'), (u'175', u'Type_2'), (u'430', u'AType_3'),
#        (u'242', u'AType_3')], dtype=object))
# ('--', 112, 'batch jaccard index : ', 0.61010242, ' | info:', array([(u'12', u'Type_1'), (u'1272', u'Type_2'), (u'1188', u'Type_2'),
#        (u'821', u'Type_1')], dtype=object))
# ('--', 116, 'batch jaccard index : ', 0.58681399, ' | info:', array([(u'5023', u'AType_3'), (u'86', u'Type_2'), (u'1415', u'Type_2'),
#        (u'1211', u'Type_2')], dtype=object))
# ('--', 120, 'batch jaccard index : ', 0.6291616, ' | info:', array([(u'1061', u'Type_1'), (u'522', u'AType_3'), (u'35', u'Type_1'),
#        (u'24', u'Type_2')], dtype=object))
# ('--', 124, 'batch jaccard index : ', 0.63947505, ' | info:', array([(u'2122', u'AType_3'), (u'1438', u'Type_2'), (u'850', u'Type_2'),
#        (u'9', u'Type_2')], dtype=object))
# ('--', 128, 'batch jaccard index : ', 0.65089381, ' | info:', array([(u'215', u'Type_1'), (u'330', u'AType_3'), (u'322', u'AType_3'),
#        (u'1329', u'Type_2')], dtype=object))
# ('--', 132, 'batch jaccard index : ', 0.76724529, ' | info:', array([(u'127', u'Type_2'), (u'1363', u'Type_2'), (u'368', u'Type_2'),
#        (u'562', u'Type_1')], dtype=object))
# ('--', 136, 'batch jaccard index : ', 0.57973641, ' | info:', array([(u'704', u'AType_3'), (u'5232', u'AType_3'), (u'5273', u'AType_3'),
#        (u'1201', u'AType_3')], dtype=object))
# ('--', 140, 'batch jaccard index : ', 0.53330451, ' | info:', array([(u'779', u'AType_3'), (u'1072', u'Type_2'), (u'1131', u'AType_3'),
#        (u'1359', u'Type_2')], dtype=object))
# ('--', 144, 'batch jaccard index : ', 0.65643084, ' | info:', array([(u'642', u'AType_3'), (u'5185', u'AType_3'), (u'506', u'Type_2'),
#        (u'1512', u'AType_3')], dtype=object))
# ('--', 148, 'batch jaccard index : ', 0.63909292, ' | info:', array([(u'166', u'AType_3'), (u'5154', u'AType_3'), (u'1473', u'Type_1'),
#        (u'313', u'Type_2')], dtype=object))
# ('--', 152, 'batch jaccard index : ', 0.60739124, ' | info:', array([(u'206', u'AType_3'), (u'269', u'AType_3'), (u'862', u'Type_2'),
#        (u'46', u'Type_2')], dtype=object))
# ('--', 156, 'batch jaccard index : ', 0.68411303, ' | info:', array([(u'329', u'Type_2'), (u'718', u'Type_2'), (u'817', u'Type_1'),
#        (u'310', u'Type_2')], dtype=object))
# ('--', 160, 'batch jaccard index : ', 0.66402125, ' | info:', array([(u'542', u'AType_3'), (u'181', u'Type_1'), (u'1059', u'Type_1'),
#        (u'1406', u'Type_2')], dtype=object))
# ('--', 164, 'batch jaccard index : ', 0.64341187, ' | info:', array([(u'5555', u'AType_3'), (u'1418', u'Type_2'), (u'771', u'Type_2'),
#        (u'134', u'Type_2')], dtype=object))
# ('--', 168, 'batch jaccard index : ', 0.5357815, ' | info:', array([(u'1216', u'Type_2'), (u'2322', u'AType_3'), (u'1146', u'Type_2'),
#        (u'935', u'Type_2')], dtype=object))
# ('--', 172, 'batch jaccard index : ', 0.6839388, ' | info:', array([(u'5042', u'AType_3'), (u'1213', u'Type_2'), (u'268', u'Type_2'),
#        (u'1353', u'Type_2')], dtype=object))
# ('--', 176, 'batch jaccard index : ', 0.55116123, ' | info:', array([(u'1047', u'Type_2'), (u'235', u'AType_3'), (u'533', u'AType_3'),
#        (u'1345', u'Type_2')], dtype=object))
# ('--', 180, 'batch jaccard index : ', 0.63244593, ' | info:', array([(u'209', u'Type_2'), (u'990', u'Type_2'), (u'19', u'Type_2'),
#        (u'85', u'Type_2')], dtype=object))
# ('--', 184, 'batch jaccard index : ', 0.69969767, ' | info:', array([(u'1308', u'AType_3'), (u'1391', u'Type_2'), (u'231', u'Type_2'),
#        (u'394', u'Type_2')], dtype=object))
# ('--', 188, 'batch jaccard index : ', 0.72236431, ' | info:', array([(u'985', u'Type_2'), (u'359', u'AType_3'), (u'1281', u'Type_1'),
#        (u'419', u'Type_2')], dtype=object))
# ('--', 192, 'batch jaccard index : ', 0.60731804, ' | info:', array([(u'2648', u'AType_3'), (u'1699', u'AType_3'), (u'116', u'Type_2'),
#        (u'311', u'Type_1')], dtype=object))
# ('--', 196, 'batch jaccard index : ', 0.64561856, ' | info:', array([(u'2055', u'AType_3'), (u'5291', u'AType_3'), (u'1250', u'AType_3'),
#        (u'732', u'Type_1')], dtype=object))
# ('--', 200, 'batch jaccard index : ', 0.60213071, ' | info:', array([(u'764', u'Type_1'), (u'1169', u'Type_2'), (u'282', u'Type_2'),
#        (u'1189', u'Type_2')], dtype=object))
# ('--', 204, 'batch jaccard index : ', 0.66820461, ' | info:', array([(u'537', u'Type_2'), (u'1173', u'Type_2'), (u'5152', u'AType_3'),
#        (u'89', u'AType_3')], dtype=object))
# ('--', 208, 'batch jaccard index : ', 0.6024555, ' | info:', array([(u'1100', u'AType_3'), (u'66', u'Type_2'), (u'500', u'AType_3'),
#        (u'1376', u'AType_3')], dtype=object))
# ('--', 212, 'batch jaccard index : ', 0.64683628, ' | info:', array([(u'504', u'AType_3'), (u'683', u'Type_1'), (u'484', u'AType_3'),
#        (u'568', u'Type_2')], dtype=object))
# ('--', 216, 'batch jaccard index : ', 0.65600765, ' | info:', array([(u'1399', u'AType_3'), (u'842', u'Type_1'), (u'1411', u'Type_2'),
#        (u'1324', u'Type_1')], dtype=object))
# ('--', 220, 'batch jaccard index : ', 0.72319388, ' | info:', array([(u'397', u'Type_2'), (u'365', u'Type_2'), (u'744', u'Type_2'),
#        (u'1225', u'Type_2')], dtype=object))
# ('--', 224, 'batch jaccard index : ', 0.65027344, ' | info:', array([(u'339', u'Type_2'), (u'743', u'Type_2'), (u'47', u'Type_1'),
#        (u'14', u'Type_1')], dtype=object))
# ('--', 228, 'batch jaccard index : ', 0.63217413, ' | info:', array([(u'1264', u'AType_3'), (u'546', u'Type_2'), (u'1477', u'AType_3'),
#        (u'1195', u'Type_2')], dtype=object))
# ('--', 232, 'batch jaccard index : ', 0.53217822, ' | info:', array([(u'1018', u'Type_2'), (u'176', u'Type_1'), (u'1156', u'Type_2'),
#        (u'1308', u'Type_1')], dtype=object))
# ('--', 236, 'batch jaccard index : ', 0.64439118, ' | info:', array([(u'1316', u'Type_2'), (u'1083', u'Type_2'), (u'425', u'Type_1'),
#        (u'667', u'Type_1')], dtype=object))
# ('--', 240, 'batch jaccard index : ', 0.62088758, ' | info:', array([(u'198', u'Type_2'), (u'32', u'Type_2'), (u'982', u'Type_1'),
#        (u'5124', u'AType_3')], dtype=object))
# ('--', 244, 'batch jaccard index : ', 0.72368336, ' | info:', array([(u'398', u'Type_2'), (u'769', u'AType_3'), (u'536', u'AType_3'),
#        (u'143', u'AType_3')], dtype=object))
# ('--', 248, 'batch jaccard index : ', 0.67897272, ' | info:', array([(u'312', u'Type_2'), (u'1175', u'Type_2'), (u'97', u'AType_3'),
#        (u'777', u'Type_2')], dtype=object))
# ('--', 252, 'batch jaccard index : ', 0.67487025, ' | info:', array([(u'956', u'Type_2'), (u'445', u'Type_2'), (u'1100', u'Type_1'),
#        (u'224', u'AType_3')], dtype=object))
# ('--', 256, 'batch jaccard index : ', 0.63661778, ' | info:', array([(u'455', u'AType_3'), (u'1077', u'Type_1'), (u'785', u'AType_3'),
#        (u'1245', u'Type_1')], dtype=object))
# ('--', 260, 'batch jaccard index : ', 0.74622893, ' | info:', array([(u'1125', u'Type_2'), (u'1283', u'Type_2'), (u'297', u'Type_2'),
#        (u'120', u'AType_3')], dtype=object))
# ('--', 264, 'batch jaccard index : ', 0.59924746, ' | info:', array([(u'5150', u'AType_3'), (u'974', u'Type_2'), (u'771', u'AType_3'),
#        (u'138', u'AType_3')], dtype=object))
# ('--', 268, 'batch jaccard index : ', 0.50195247, ' | info:', array([(u'89', u'Type_2'), (u'1320', u'Type_1'), (u'936', u'Type_2'),
#        (u'5096', u'AType_3')], dtype=object))
# ('--', 272, 'batch jaccard index : ', 0.5855726, ' | info:', array([(u'567', u'AType_3'), (u'855', u'Type_1'), (u'922', u'Type_2'),
#        (u'5343', u'AType_3')], dtype=object))
# ('--', 276, 'batch jaccard index : ', 0.71406478, ' | info:', array([(u'581', u'Type_2'), (u'67', u'Type_2'), (u'94', u'Type_2'),
#        (u'518', u'Type_1')], dtype=object))
# ('--', 280, 'batch jaccard index : ', 0.74682921, ' | info:', array([(u'2186', u'AType_3'), (u'620', u'Type_1'), (u'497', u'AType_3'),
#        (u'939', u'Type_2')], dtype=object))
# ('--', 281, 'batch jaccard index : ', 0.73736072, ' | info:', array([(u'824', u'Type_2')], dtype=object))
# ('Mean jaccard index : ', 0.63854080756788145)

# %%
# id_type_list = [val_id_type_list[i] for i in [0, 3, 4, 9, 10, 14, 15, 17]]

# %%
from postprocessing_utils import sieve 
from postprocessing_utils import os_cervix_postproc_batch

# %% [markdown]
# ### Predictions on train test

# %%
batch_size = 1
from preprocessing.image.generators import ImageMaskGenerator
from xy_providers import cached_image_mask_provider as xy_provider
from image_utils import scale_percentile

gen = ImageMaskGenerator(featurewise_center=True, featurewise_std_normalization=True)

# Load mean, std, principal_components if file exists
filename = os.path.join(GENERATED_DATA, save_prefix + "_stats.npz")
assert os.path.exists(filename), "WTF"
print("Load existing file: %s" % filename)
npzfile = np.load(filename)
gen.mean = npzfile['mean']
gen.std = npzfile['std']


flow = gen.flow(xy_provider(train_id_type_list,
                            mask_type='trainval_label_0',
                            test_mode=True,
                            cache=cache,
                            image_size=(224, 224)),
                # Ensure that all batches have the same size
                len(train_id_type_list),
                batch_size=batch_size)
# Out:
# Load existing file: /Users/vfomin/Documents/ML/Kaggle/Intel_MobileODT/input/generated/unet_os_cervix_detector_opt=adadelta_seed=54321_lr=1.000_a=0.975_stats.npz

# %%
max_counter = 8
n = 2
counter = 0
for x, y_true, info in flow:           
    y_pred = unet.predict(x)    
    print x.shape, y_pred.shape, y_pred.min(), y_pred.max(), info 
    
    y_pred = os_cervix_postproc_batch(y_pred)
    
    if False:
        if counter % n == 0:
            plt_st(12, 4)
        plt.subplot(1, n, counter % n + 1)
        plt.imshow(x[0, :, :, :].transpose([1, 2, 0]))
        plt.imshow(y_pred[0, 0, :, :], alpha=0.25, cmap='Paired') # Os
        plt.imshow(y_pred[0, 1, :, :], alpha=0.25, cmap='Paired') # Cervix
        plt.title("Image: {}".format(info[0]))
        
        
    if True:
        if counter % 1 == 0:
            plt_st(12, 4)
        plt.subplot(1, 4, 1)
        plt.imshow(x[0, :, :, :].transpose([1, 2, 0]))
        plt.subplot(1, 4, 2)        
        plt.imshow(scale_percentile(x[0, :, :, :].transpose([1, 2, 0])))
        plt.imshow(y_pred[0, 0, :, :], alpha=0.25, cmap='Paired') # Os
        plt.imshow(y_pred[0, 1, :, :], alpha=0.25, cmap='Paired') # Cervix
        plt.subplot(1, 4, 3)        
        plt.imshow(y_pred[0, 0, :, :], cmap='Paired') # Os
        plt.subplot(1, 4, 4)
        plt.imshow(y_pred[0, 1, :, :], cmap='Paired') # Cervix
        plt.suptitle("Image: {}".format(info[0]))            
        
    counter += 1
    if counter == max_counter:
        break
# Out:
# (1, 3, 224, 224) (1, 2, 224, 224) 4.04399e-11 1.0 [(u'604', u'AType_3')]
# (1, 3, 224, 224) (1, 2, 224, 224) 2.8142e-20 1.0 [(u'913', u'Type_2')]
# (1, 3, 224, 224) (1, 2, 224, 224) 1.67002e-11 1.0 [(u'607', u'AType_3')]
# (1, 3, 224, 224) (1, 2, 224, 224) 3.03845e-16 1.0 [(u'1192', u'Type_2')]
# (1, 3, 224, 224) (1, 2, 224, 224) 4.22178e-20 0.999995 [(u'252', u'Type_1')]
# (1, 3, 224, 224) (1, 2, 224, 224) 2.38326e-20 1.0 [(u'1236', u'Type_2')]
# (1, 3, 224, 224) (1, 2, 224, 224) 2.1122e-12 1.0 [(u'1812', u'AType_3')]
# (1, 3, 224, 224) (1, 2, 224, 224) 3.31806e-13 1.0 [(u'1465', u'Type_2')]

# %% [markdown]
# ### Predictions on validation test

# %%
batch_size = 1
flow = gen.flow(xy_provider(val_id_type_list,
                            mask_type='trainval_label_0',
                            test_mode=True,
                            cache=cache,
                            image_size=(224, 224)),
                # Ensure that all batches have the same size
                len(val_id_type_list),
                batch_size=batch_size)

# %%
max_counter = 8
n = 2   
counter = 0
for x, y_true, info in flow:           
    y_pred = unet.predict(x)
    print x.shape, y_pred.shape, y_pred.min(), y_pred.max(), info
    
    y_pred = os_cervix_postproc_batch(y_pred)
    
    if False:
        if counter % n == 0:
            plt_st(12, 4)
        plt.subplot(1, n, counter % n + 1)
        plt.imshow(x[0, :, :, :].transpose([1, 2, 0]))
        plt.imshow(y_pred[0, 0, :, :], alpha=0.25, cmap='Paired') # Os
        plt.imshow(y_pred[0, 1, :, :], alpha=0.25, cmap='Paired') # Cervix
        plt.title("Image: {}".format(info[0]))
        
        
    if True:
        if counter % 1 == 0:
            plt_st(12, 4)
        plt.subplot(1, 4, 1)
        plt.imshow(scale_percentile(x[0, :, :, :].transpose([1, 2, 0])))
        plt.subplot(1, 4, 2)        
        plt.imshow(scale_percentile(x[0, :, :, :].transpose([1, 2, 0])))
        plt.imshow(y_pred[0, 0, :, :], alpha=0.25, cmap='Paired') # Os
        plt.imshow(y_pred[0, 1, :, :], alpha=0.25, cmap='Paired') # Cervix
        plt.subplot(1, 4, 3)        
        plt.imshow(y_pred[0, 0, :, :], cmap='Paired') # Os
        plt.subplot(1, 4, 4)
        plt.imshow(y_pred[0, 1, :, :], cmap='Paired') # Cervix
        plt.suptitle("Image: {}".format(info[0]))                      
    counter += 1
    if counter == max_counter:
        break
# Out:
# (1, 3, 224, 224) (1, 2, 224, 224) 6.61199e-11 1.0 [(u'8', u'Type_2')]
# (1, 3, 224, 224) (1, 2, 224, 224) 8.21499e-16 1.0 [(u'1172', u'Type_2')]
# (1, 3, 224, 224) (1, 2, 224, 224) 3.41255e-14 1.0 [(u'1075', u'Type_2')]
# (1, 3, 224, 224) (1, 2, 224, 224) 5.19426e-13 1.0 [(u'219', u'Type_2')]
# (1, 3, 224, 224) (1, 2, 224, 224) 3.82331e-16 1.0 [(u'1842', u'AType_3')]
# (1, 3, 224, 224) (1, 2, 224, 224) 6.20619e-13 1.0 [(u'1369', u'Type_2')]
# (1, 3, 224, 224) (1, 2, 224, 224) 4.16315e-10 1.0 [(u'1414', u'Type_1')]
# (1, 3, 224, 224) (1, 2, 224, 224) 2.66476e-17 1.0 [(u'738', u'Type_2')]

# %%
# !ls {GENERATED_DATA}/
# Out:
# cervix_train_stats.npz
# check_cervix_stats.npz
# check_os_stats.npz
# os_cervix_labels_1
# os_cervix_labels_2
# os_cervix_labels_final
# resnet_4_dense_adadelta_seed=2017_stats.npz
# resnet_4_dense_cervix_adadelta_seed=2017_stats.npz
# resnet_4_dense_cervix_nadam_seed=2017_stats.npz
# resnet_4_dense_nadam_seed=2017_stats.npz
# resnet_4_dense_seed=2017_stats.npz
# resnet_not_trained_original_cervix_adadelta_seed=2017_stats.npz
# resnet_not_trained_original_norm_cervix_adadelta_seed=2017_stats.npz
# resnet_original_cervix_seed=2017_stats.npz
# templates.csv
# test
# train
# trainval_labels_0
# unet_os_cervix_detector_opt=adadelta_seed=54321_lr=1.000_a=0.975_stats.npz
# unet_os_cervix_detector_seed=2017_lr=0.001_a=0.925_stats.npz
# xception_trained_3_dense_norm_cervix_adadelta_seed=2017_stats.npz
# xception_trained_3_dense_norm_os_adadelta_seed=2017_stats.npz
# xception_trained_norm_os_adadelta_seed=2017_stats.npz
# xception_trained_original_cervix_adadelta_seed=2017_stats.npz
# xception_trained_original_norm_cervix_adadelta_seed=2017_stats.npz
