# %% [markdown]
# # Trained ResNet-50 classification on cervix images

# %%
# https://ipython.org/ipython-doc/3/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
import os
from datetime import datetime
import numpy as np

# %%
# Project
import sys
sys.path.append(os.path.join(os.path.abspath(os.path.dirname('.')), '..', 'common'))

# %%
import matplotlib.pylab as plt
# %matplotlib inline

def plt_st(n, m):
    plt.figure(figsize=(n, m))
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
from resnet_keras122 import get_resnet_original, get_resnet50

# %%
from training_utils import get_trainval_id_type_lists

print("\n {} - Get train/val lists ...".format(datetime.now()))
train_id_type_list, val_id_type_list = get_trainval_id_type_lists()

cervix_train_id_type_list = [(id_type[0], id_type[1] + '_cervix') for id_type in train_id_type_list if id_type[0] != '1339']
cervix_val_id_type_list = [(id_type[0], id_type[1] + '_cervix') for id_type in val_id_type_list if id_type[0] != '1339']
# Out:
#  2017-04-08 01:51:49.254026 - Get train/val lists ...
# Train dataset contains :
# ('-', [175, 546, 315], ' images of corresponding types')
# Validation dataset contains :
# ('-', [75, 234, 135], ' images of corresponding types')

# %%
print("\n {} - Get ResNet-50 model ...".format(datetime.now()))
#resnet = get_resnet_original(opt='nadam')
resnet = get_resnet50(opt='adadelta')
# Out:
#  2017-04-08 01:52:11.034954 - Get ResNet-50 model ...

# %%
from IPython.display import SVG
from keras.utils.visualize_util import model_to_dot

graph = model_to_dot(resnet, True, True)
SVG(graph.create(prog='dot', format='svg'))

# %%
# from training_utils import exp_decay

# lr_1 = 1.0; a_1 = 0.95
# lr_2 = 1e-1; a_2 = 0.985

# epochs = np.arange(0, 50)
# lrs_1 = exp_decay(epochs, lr=lr_1, a=a_1)
# lrs_2 = exp_decay(epochs, lr=lr_2, a=a_2)
# plt_st(12, 5)
# plt.plot(epochs, lrs_1, label="lr=%f, a=%f" % (lr_1, a_1))
# plt.plot(epochs, lrs_2, label="lr=%f, a=%f" % (lr_2, a_2))
# plt.legend()

# %%
seed = 2017
np.random.seed(seed)
save_prefix='resnet_4_dense_cervix_adadelta_seed=%i' % seed

# %%
from glob import glob

weights_files = glob("weights/%s*.h5" % save_prefix)
best_val_loss = 1e5
best_weights_filename = ""
for f in weights_files:
    index = os.path.basename(f).index('-')
    loss = float(os.path.basename(f)[index+1:-4])
    if best_val_loss > loss:
        best_val_loss = loss
        best_weights_filename = f
print("Best val loss weights: ", best_weights_filename)


if len(best_weights_filename) > 0:
    # load weights to the model
    print("Load found weights: ", best_weights_filename)
    resnet.load_weights(best_weights_filename)
# Out:
# ('Best val loss weights: ', 'weights/resnet_4_dense_cervix_adadelta_seed=2017_12-0.9339.h5')
# ('Load found weights: ', 'weights/resnet_4_dense_cervix_adadelta_seed=2017_12-0.9339.h5')

# %%
from xy_providers import DataCache
cache = DataCache(2000)

# %%
if True:
    from training_utils import classification_train as train
      
    nb_epochs = 50
    batch_size = 4
    
#     lrate_decay_f = lambda epoch: exp_decay(epoch, lr=lr_1, a=a_1) 

    print("\n {} - Start training ...".format(datetime.now()))
    h = train(resnet, 
              cervix_train_id_type_list, 
              cervix_val_id_type_list, 
              nb_epochs=nb_epochs,
              lrate_decay_f=None, #lrate_decay_f,
              batch_size=batch_size, 
              xy_provider_cache=cache,
              seed=seed,
              save_prefix=save_prefix)
# Out:
#  2017-04-08 01:53:40.703906 - Start training ...
# ('-- Training parameters: ', 4, 50, 2048, 1024)
# -- Fit stats of train dataset
# 1635/1635 [==============================] - 27s
# -- Fit model
# Epoch 1/50
# 2048/2048 [==============================] - 206s - loss: 1.2207 - acc: 0.3418 - val_loss: 1.0920 - val_acc: 0.3799
# Epoch 2/50
# 2048/2048 [==============================] - 201s - loss: 1.1080 - acc: 0.3516 - val_loss: 1.0815 - val_acc: 0.4453
# Epoch 3/50
# 2048/2048 [==============================] - 203s - loss: 1.0877 - acc: 0.3740 - val_loss: 1.0266 - val_acc: 0.5107
# Epoch 4/50
# 2048/2048 [==============================] - 203s - loss: 1.0446 - acc: 0.4214 - val_loss: 1.0064 - val_acc: 0.4912
# Epoch 5/50
# 2048/2048 [==============================] - 198s - loss: 1.0354 - acc: 0.4351 - val_loss: 0.9791 - val_acc: 0.5215
# Epoch 6/50
# 2048/2048 [==============================] - 201s - loss: 1.0137 - acc: 0.4644 - val_loss: 0.9810 - val_acc: 0.5059
# Epoch 7/50
# 2048/2048 [==============================] - 200s - loss: 1.0094 - acc: 0.4546 - val_loss: 0.9652 - val_acc: 0.5381
# Epoch 8/50
# 2048/2048 [==============================] - 206s - loss: 1.0156 - acc: 0.4756 - val_loss: 1.0005 - val_acc: 0.5137
# Epoch 9/50
# 2048/2048 [==============================] - 198s - loss: 0.9845 - acc: 0.4990 - val_loss: 1.0089 - val_acc: 0.5107
# Epoch 10/50
# 2048/2048 [==============================] - 198s - loss: 0.9985 - acc: 0.4927 - val_loss: 1.0005 - val_acc: 0.5068
# Epoch 11/50
# 2048/2048 [==============================] - 202s - loss: 0.9878 - acc: 0.4810 - val_loss: 1.0345 - val_acc: 0.5107
# Epoch 12/50
# 2048/2048 [==============================] - 199s - loss: 0.9923 - acc: 0.4980 - val_loss: 0.9320 - val_acc: 0.5625
# Epoch 13/50
# 2048/2048 [==============================] - 202s - loss: 0.9830 - acc: 0.5083 - val_loss: 0.9339 - val_acc: 0.5283
# Epoch 14/50
# 2048/2048 [==============================] - 199s - loss: 0.9945 - acc: 0.5020 - val_loss: 1.0568 - val_acc: 0.4727
# Epoch 15/50
# 2048/2048 [==============================] - 203s - loss: 0.9747 - acc: 0.5171 - val_loss: 0.9939 - val_acc: 0.5420
# Epoch 16/50
# 2048/2048 [==============================] - 205s - loss: 0.9830 - acc: 0.4917 - val_loss: 0.9892 - val_acc: 0.5498
# Epoch 17/50
# 2048/2048 [==============================] - 206s - loss: 0.9773 - acc: 0.5049 - val_loss: 0.9477 - val_acc: 0.5488
# Epoch 18/50
# 2048/2048 [==============================] - 205s - loss: 0.9629 - acc: 0.5073 - val_loss: 1.0728 - val_acc: 0.5176
# Epoch 19/50
# 2048/2048 [==============================] - 199s - loss: 0.9682 - acc: 0.5117 - val_loss: 1.0359 - val_acc: 0.5439
# Epoch 20/50
# 2048/2048 [==============================] - 200s - loss: 0.9736 - acc: 0.5132 - val_loss: 1.0223 - val_acc: 0.5293
# Epoch 21/50
# 2048/2048 [==============================] - 197s - loss: 0.9785 - acc: 0.5088 - val_loss: 1.0493 - val_acc: 0.5420
# Epoch 22/50
# 2048/2048 [==============================] - 202s - loss: 0.9540 - acc: 0.5254 - val_loss: 1.0633 - val_acc: 0.5352
# Epoch 23/50
# 2048/2048 [==============================] - 204s - loss: 0.9481 - acc: 0.5283 - val_loss: 0.9902 - val_acc: 0.5771
# Epoch 24/50
# 2048/2048 [==============================] - 204s - loss: 0.9794 - acc: 0.5122 - val_loss: 1.0402 - val_acc: 0.5430
# Epoch 25/50
# 2048/2048 [==============================] - 202s - loss: 0.9546 - acc: 0.5244 - val_loss: 1.1312 - val_acc: 0.5127
# Epoch 26/50
# 2048/2048 [==============================] - 202s - loss: 0.9545 - acc: 0.5312 - val_loss: 1.1916 - val_acc: 0.4951
# Epoch 27/50
# 2048/2048 [==============================] - 204s - loss: 0.9505 - acc: 0.5342 - val_loss: 1.0801 - val_acc: 0.5361
# Epoch 28/50
# 2048/2048 [==============================] - 203s - loss: 0.9756 - acc: 0.5132 - val_loss: 1.0219 - val_acc: 0.5762
# Epoch 29/50
# 2048/2048 [==============================] - 203s - loss: 0.9445 - acc: 0.5376 - val_loss: 1.0927 - val_acc: 0.5381
# Epoch 30/50
#  136/2048 [>.............................] - ETA: 128s - loss: 0.9041 - acc: 0.5368
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-885d2ebaa779> in <module>()
#      16               xy_provider_cache=cache,
#      17               seed=seed,
# ---> 18               save_prefix=save_prefix)
#
# /Users/vfomin/Documents/ML/Kaggle/Intel_MobileODT/notebooks/../common/training_utils.pyc in classification_train(model, train_id_type_list, val_id_type_list, batch_size, nb_epochs, lrate_decay_f, samples_per_epoch, nb_val_samples, xy_provider_cache, seed, save_prefix, verbose)
#     356         nb_val_samples=nb_val_samples,
#     357         callbacks=callbacks,
# --> 358         verbose=verbose,
#     359     )
#     360
#
# /usr/local/lib/python2.7/site-packages/keras/engine/training.pyc in fit_generator(self, generator, samples_per_epoch, nb_epoch, verbose, callbacks, validation_data, nb_val_samples, class_weight, max_q_size, nb_worker, pickle_safe, initial_epoch)
#    1555                     outs = self.train_on_batch(x, y,
#    1556                                                sample_weight=sample_weight,
# -> 1557                                                class_weight=class_weight)
#    1558
#    1559                     if not isinstance(outs, list):
#
# /usr/local/lib/python2.7/site-packages/keras/engine/training.pyc in train_on_batch(self, x, y, sample_weight, class_weight)
#    1318             ins = x + y + sample_weights
#    1319         self._make_train_function()
# -> 1320         outputs = self.train_function(ins)
#    1321         if len(outputs) == 1:
#    1322             return outputs[0]
#
# /usr/local/lib/python2.7/site-packages/keras/backend/theano_backend.pyc in __call__(self, inputs)
#     957     def __call__(self, inputs):
#     958         assert isinstance(inputs, (list, tuple))
# --> 959         return self.function(*inputs)
#     960
#     961
#
# /usr/local/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     882         try:
#     883             outputs =\
# --> 884                 self.fn() if output_subset is None else\
#     885                 self.fn(output_subset=output_subset)
#     886         except Exception:
#
# /usr/local/lib/python2.7/site-packages/theano/ifelse.pyc in thunk()
#     244         outputs = node.outputs
#     245
# --> 246         def thunk():
#     247             if not compute_map[cond][0]:
#     248                 return [0]
#
# KeyboardInterrupt:

# %%
if True:
    from training_utils import classification_train as train, exp_decay
      
    nb_epochs = 50
    batch_size = 4
    
    lr_1 = 1.0; a_1 = 0.975
    lrate_decay_f = lambda epoch: exp_decay(epoch, lr=lr_1, a=a_1) 

    print("\n {} - Start training ...".format(datetime.now()))
    h = train(resnet, 
              cervix_train_id_type_list, 
              cervix_val_id_type_list, 
              nb_epochs=nb_epochs,
              lrate_decay_f=lrate_decay_f,
              batch_size=batch_size, 
              xy_provider_cache=cache,
              seed=seed,
              save_prefix=save_prefix)
# Out:
#  2017-04-08 03:36:59.767949 - Start training ...
# ('-- Training parameters: ', 4, 50, 2048, 1024)
# -- Fit stats of train dataset
# Load existing file: /Users/vfomin/Documents/ML/Kaggle/Intel_MobileODT/input/generated/resnet_4_dense_cervix_adadelta_seed=2017_stats.npz
# No need to recompute statistics
# -- Fit model
# Epoch 1/50
# 2048/2048 [==============================] - 202s - loss: 0.9419 - acc: 0.5337 - val_loss: 1.0274 - val_acc: 0.5469
# Epoch 2/50
# 2048/2048 [==============================] - 202s - loss: 0.9738 - acc: 0.5171 - val_loss: 1.0626 - val_acc: 0.5420
# Epoch 3/50
# 2048/2048 [==============================] - 199s - loss: 0.9447 - acc: 0.5503 - val_loss: 1.1107 - val_acc: 0.5645
# Epoch 4/50
# 2048/2048 [==============================] - 199s - loss: 0.9590 - acc: 0.5308 - val_loss: 1.0625 - val_acc: 0.5488
# Epoch 5/50
# 2048/2048 [==============================] - 199s - loss: 0.9823 - acc: 0.5215 - val_loss: 1.0395 - val_acc: 0.5547
# Epoch 6/50
# 2048/2048 [==============================] - 199s - loss: 0.9581 - acc: 0.5273 - val_loss: 1.0790 - val_acc: 0.5195
# Epoch 7/50
# 2048/2048 [==============================] - 199s - loss: 0.9485 - acc: 0.5371 - val_loss: 1.0238 - val_acc: 0.5518
# Epoch 8/50
# 2048/2048 [==============================] - 199s - loss: 0.9683 - acc: 0.5127 - val_loss: 1.0873 - val_acc: 0.5469
# Epoch 9/50
# 2048/2048 [==============================] - 198s - loss: 0.9382 - acc: 0.5352 - val_loss: 0.9939 - val_acc: 0.5791
# Epoch 10/50
# 2048/2048 [==============================] - 198s - loss: 0.9576 - acc: 0.5298 - val_loss: 1.0437 - val_acc: 0.5420
# Epoch 11/50
# 2048/2048 [==============================] - 198s - loss: 0.9617 - acc: 0.5312 - val_loss: 1.0212 - val_acc: 0.5430
# Epoch 12/50
# 2048/2048 [==============================] - 198s - loss: 0.9305 - acc: 0.5376 - val_loss: 1.0342 - val_acc: 0.5732
# Epoch 13/50
# 2048/2048 [==============================] - 198s - loss: 0.9327 - acc: 0.5474 - val_loss: 1.0537 - val_acc: 0.5254
# Epoch 14/50
# 2048/2048 [==============================] - 198s - loss: 0.9398 - acc: 0.5273 - val_loss: 1.1073 - val_acc: 0.5234
# Epoch 15/50
# 2048/2048 [==============================] - 198s - loss: 0.9347 - acc: 0.5376 - val_loss: 1.1403 - val_acc: 0.5293
# Epoch 16/50
# 2048/2048 [==============================] - 199s - loss: 0.9237 - acc: 0.5444 - val_loss: 1.1350 - val_acc: 0.5518
# Epoch 17/50
# 2048/2048 [==============================] - 198s - loss: 0.9432 - acc: 0.5322 - val_loss: 1.1334 - val_acc: 0.5381
# Epoch 18/50
# 2048/2048 [==============================] - 198s - loss: 0.9469 - acc: 0.5259 - val_loss: 1.0846 - val_acc: 0.5371
# Epoch 19/50
# 2048/2048 [==============================] - 199s - loss: 0.9186 - acc: 0.5483 - val_loss: 1.2674 - val_acc: 0.5439
# Epoch 20/50
# 2048/2048 [==============================] - 198s - loss: 0.9613 - acc: 0.5361 - val_loss: 1.0930 - val_acc: 0.5527
# Epoch 21/50
# 2048/2048 [==============================] - 199s - loss: 0.9331 - acc: 0.5342 - val_loss: 1.1330 - val_acc: 0.5391
# Epoch 22/50
# 2048/2048 [==============================] - 199s - loss: 0.9198 - acc: 0.5532 - val_loss: 1.1514 - val_acc: 0.5605
# Epoch 23/50
# 2048/2048 [==============================] - 199s - loss: 0.9311 - acc: 0.5405 - val_loss: 1.0619 - val_acc: 0.5713
# Epoch 24/50
# 2048/2048 [==============================] - 199s - loss: 0.9486 - acc: 0.5234 - val_loss: 1.1500 - val_acc: 0.5498
# Epoch 25/50
# 2048/2048 [==============================] - 199s - loss: 0.9253 - acc: 0.5493 - val_loss: 1.1844 - val_acc: 0.5381
# Epoch 26/50
# 2048/2048 [==============================] - 199s - loss: 0.9221 - acc: 0.5298 - val_loss: 1.2394 - val_acc: 0.5322
# Epoch 27/50
# 2048/2048 [==============================] - 199s - loss: 0.9386 - acc: 0.5400 - val_loss: 1.1379 - val_acc: 0.5361
# Epoch 28/50
# 2048/2048 [==============================] - 199s - loss: 0.9433 - acc: 0.5303 - val_loss: 1.1255 - val_acc: 0.5723
# Epoch 29/50
# 2048/2048 [==============================] - 199s - loss: 0.9043 - acc: 0.5703 - val_loss: 1.0837 - val_acc: 0.5596
# Epoch 30/50
# 2048/2048 [==============================] - 199s - loss: 0.9384 - acc: 0.5352 - val_loss: 1.0014 - val_acc: 0.5498
# Epoch 31/50
# 2048/2048 [==============================] - 199s - loss: 0.9349 - acc: 0.5352 - val_loss: 1.2071 - val_acc: 0.5186
# Epoch 32/50
# 2048/2048 [==============================] - 199s - loss: 0.9509 - acc: 0.5596 - val_loss: 1.1881 - val_acc: 0.5469
# Epoch 33/50
# 2048/2048 [==============================] - 199s - loss: 0.9482 - acc: 0.5288 - val_loss: 1.1662 - val_acc: 0.5430
# Epoch 34/50
# 2048/2048 [==============================] - 199s - loss: 0.9347 - acc: 0.5391 - val_loss: 1.1570 - val_acc: 0.5332
# Epoch 35/50
# 2048/2048 [==============================] - 199s - loss: 0.9251 - acc: 0.5498 - val_loss: 1.1725 - val_acc: 0.5361
# Epoch 36/50
# 2048/2048 [==============================] - 199s - loss: 0.9292 - acc: 0.5435 - val_loss: 1.1333 - val_acc: 0.5508
# Epoch 37/50
# 2048/2048 [==============================] - 199s - loss: 0.9221 - acc: 0.5439 - val_loss: 1.1838 - val_acc: 0.5469
# Epoch 38/50
# 2048/2048 [==============================] - 199s - loss: 0.9180 - acc: 0.5396 - val_loss: 1.2743 - val_acc: 0.5293
# Epoch 39/50
# 2048/2048 [==============================] - 199s - loss: 0.9459 - acc: 0.5586 - val_loss: 1.2183 - val_acc: 0.5381
# Epoch 40/50
# 2048/2048 [==============================] - 199s - loss: 0.9405 - acc: 0.5464 - val_loss: 1.2148 - val_acc: 0.5527
# Epoch 41/50
# 2048/2048 [==============================] - 199s - loss: 0.9372 - acc: 0.5586 - val_loss: 1.0885 - val_acc: 0.5723
# Epoch 42/50
# 2048/2048 [==============================] - 199s - loss: 0.9245 - acc: 0.5566 - val_loss: 1.1868 - val_acc: 0.5547
# Epoch 43/50
# 2048/2048 [==============================] - 199s - loss: 0.9115 - acc: 0.5557 - val_loss: 1.1768 - val_acc: 0.5469
# Epoch 44/50
# 2048/2048 [==============================] - 199s - loss: 0.9501 - acc: 0.5337 - val_loss: 1.1084 - val_acc: 0.5557
# Epoch 45/50
# 2048/2048 [==============================] - 199s - loss: 0.9273 - acc: 0.5591 - val_loss: 1.1123 - val_acc: 0.5488
# Epoch 46/50
# 2048/2048 [==============================] - 199s - loss: 0.9527 - acc: 0.5293 - val_loss: 1.1778 - val_acc: 0.5537
# Epoch 47/50
# 2048/2048 [==============================] - 199s - loss: 0.9298 - acc: 0.5562 - val_loss: 1.2133 - val_acc: 0.5625
# Epoch 48/50
# 2048/2048 [==============================] - 199s - loss: 0.9202 - acc: 0.5474 - val_loss: 1.1465 - val_acc: 0.5371
# Epoch 49/50
# 2048/2048 [==============================] - 199s - loss: 0.9307 - acc: 0.5479 - val_loss: 1.1649 - val_acc: 0.5771
# Epoch 50/50
# 2048/2048 [==============================] - 199s - loss: 0.9242 - acc: 0.5503 - val_loss: 1.1472 - val_acc: 0.5537

# %%
from training_utils import classification_validate as validate
from test_utils import classification_predict as predict

batch_size = 4

# %%
from xy_providers import cached_image_label_provider
from preprocessing.image.iterators import ImageDataIterator
from metrics import logloss_mc

xy_provider = cached_image_label_provider
val_iter = ImageDataIterator(xy_provider(cervix_val_id_type_list,
                                         test_mode=True,
                                         cache=cache),
                             len(cervix_val_id_type_list),
                             None,  # image generator
                             batch_size=batch_size,
                             data_format='channels_first')

Y_pred = np.zeros((len(cervix_val_id_type_list), 3), dtype=np.float32)
Y_true = np.zeros((len(cervix_val_id_type_list), 3), dtype=np.uint8)
total_counter = 0
for x, y_true, info in val_iter:
    s = y_true.shape[0]
    y_pred = resnet.predict(x)
    Y_pred[total_counter*batch_size:total_counter*batch_size + s, :] = y_pred
    Y_true[total_counter*batch_size:total_counter*batch_size + s, :] = y_true
    print("--", total_counter*batch_size + s)
    total_counter += 1
# Out:
# ('--', 4)
# ('--', 8)
# ('--', 12)
# ('--', 16)
# ('--', 20)
# ('--', 24)
# ('--', 28)
# ('--', 32)
# ('--', 36)
# ('--', 40)
# ('--', 44)
# ('--', 48)
# ('--', 52)
# ('--', 56)
# ('--', 60)
# ('--', 64)
# ('--', 68)
# ('--', 72)
# ('--', 76)
# ('--', 80)
# ('--', 84)
# ('--', 88)
# ('--', 92)
# ('--', 96)
# ('--', 100)
# ('--', 104)
# ('--', 108)
# ('--', 112)
# ('--', 116)
# ('--', 120)
# ('--', 124)
# ('--', 128)
# ('--', 132)
# ('--', 136)
# ('--', 140)
# ('--', 144)
# ('--', 148)
# ('--', 152)
# ('--', 156)
# ('--', 160)
# ('--', 164)
# ('--', 168)
# ('--', 172)
# ('--', 176)
# ('--', 180)
# ('--', 184)
# ('--', 188)
# ('--', 192)
# ('--', 196)
# ('--', 200)
# ('--', 204)
# ('--', 208)
# ('--', 212)
# ('--', 216)
# ('--', 220)
# ('--', 224)
# ('--', 228)
# ('--', 232)
# ('--', 236)
# ('--', 240)
# ('--', 244)
# ('--', 248)
# ('--', 252)
# ('--', 256)
# ('--', 260)
# ('--', 264)
# ('--', 268)
# ('--', 272)
# ('--', 276)
# ('--', 280)
# ('--', 284)
# ('--', 288)
# ('--', 292)
# ('--', 296)
# ('--', 300)
# ('--', 304)
# ('--', 308)
# ('--', 312)
# ('--', 316)
# ('--', 320)
# ('--', 324)
# ('--', 328)
# ('--', 332)
# ('--', 336)
# ('--', 340)
# ('--', 344)
# ('--', 348)
# ('--', 352)
# ('--', 356)
# ('--', 360)
# ('--', 364)
# ('--', 368)
# ('--', 372)
# ('--', 376)
# ('--', 380)
# ('--', 384)
# ('--', 388)
# ('--', 392)
# ('--', 396)
# ('--', 400)
# ('--', 404)
# ('--', 408)
# ('--', 412)
# ('--', 416)
# ('--', 420)
# ('--', 424)
# ('--', 428)
# ('--', 432)
# ('--', 436)
# ('--', 440)
# ('--', 444)
# ('--', 448)
# ('--', 452)
# ('--', 456)
# ('--', 460)
# ('--', 464)
# ('--', 468)
# ('--', 472)
# ('--', 476)
# ('--', 480)
# ('--', 484)
# ('--', 488)
# ('--', 492)
# ('--', 496)
# ('--', 500)
# ('--', 504)
# ('--', 508)
# ('--', 512)
# ('--', 516)
# ('--', 520)
# ('--', 524)
# ('--', 528)
# ('--', 532)
# ('--', 536)
# ('--', 540)
# ('--', 544)
# ('--', 548)
# ('--', 552)
# ('--', 556)
# ('--', 560)
# ('--', 564)
# ('--', 568)
# ('--', 572)
# ('--', 576)
# ('--', 580)
# ('--', 584)
# ('--', 588)
# ('--', 592)
# ('--', 596)
# ('--', 600)
# ('--', 604)
# ('--', 608)
# ('--', 612)
# ('--', 616)
# ('--', 620)
# ('--', 624)
# ('--', 628)
# ('--', 632)
# ('--', 636)
# ('--', 640)
# ('--', 644)
# ('--', 648)
# ('--', 652)
# ('--', 656)
# ('--', 660)
# ('--', 664)
# ('--', 668)
# ('--', 672)
# ('--', 676)
# ('--', 680)
# ('--', 684)
# ('--', 688)
# ('--', 692)
# ('--', 696)
# ('--', 700)
# ('--', 702)

# %%
loss = logloss_mc(Y_true, Y_pred)
print("Loss : ", loss)
# Out:
# ('Loss : ', 1.9932698)

# %%
print("\n {} - Start validation ...".format(datetime.now()))
validate(resnet, cervix_val_id_type_list, batch_size=batch_size, xy_provider_cache=cache)
# Out:
#  2017-04-08 10:44:25.551354 - Start validation ...
# ('--', 4, 'batch loss : ', 2.4019909, ' | info:', array([('619', 'Type_1_cervix'), ('577', 'Type_2_cervix'),
#        ('627', 'Type_3_cervix'), ('620', 'Type_1_cervix')], dtype=object))
# ('--', 8, 'batch loss : ', 2.5462778, ' | info:', array([('581', 'Type_2_cervix'), ('628', 'Type_3_cervix'),
#        ('623', 'Type_1_cervix'), ('584', 'Type_2_cervix')], dtype=object))
# ('--', 12, 'batch loss : ', 1.294191, ' | info:', array([('629', 'Type_3_cervix'), ('624', 'Type_1_cervix'),
#        ('586', 'Type_2_cervix'), ('63', 'Type_3_cervix')], dtype=object))
# ('--', 16, 'batch loss : ', 2.9172502, ' | info:', array([('641', 'Type_1_cervix'), ('588', 'Type_2_cervix'),
#        ('630', 'Type_3_cervix'), ('643', 'Type_1_cervix')], dtype=object))
# ('--', 20, 'batch loss : ', 2.1739337, ' | info:', array([('589', 'Type_2_cervix'), ('631', 'Type_3_cervix'),
#        ('645', 'Type_1_cervix'), ('591', 'Type_2_cervix')], dtype=object))
# ('--', 24, 'batch loss : ', 1.0783577, ' | info:', array([('635', 'Type_3_cervix'), ('649', 'Type_1_cervix'),
#        ('592', 'Type_2_cervix'), ('636', 'Type_3_cervix')], dtype=object))
# ('--', 28, 'batch loss : ', 2.5801868, ' | info:', array([('653', 'Type_1_cervix'), ('595', 'Type_2_cervix'),
#        ('637', 'Type_3_cervix'), ('660', 'Type_1_cervix')], dtype=object))
# ('--', 32, 'batch loss : ', 1.1208193, ' | info:', array([('597', 'Type_2_cervix'), ('638', 'Type_3_cervix'),
#        ('663', 'Type_1_cervix'), ('6', 'Type_2_cervix')], dtype=object))
# ('--', 36, 'batch loss : ', 1.8082992, ' | info:', array([('646', 'Type_3_cervix'), ('667', 'Type_1_cervix'),
#        ('60', 'Type_2_cervix'), ('650', 'Type_3_cervix')], dtype=object))
# ('--', 40, 'batch loss : ', 2.2948368, ' | info:', array([('668', 'Type_1_cervix'), ('601', 'Type_2_cervix'),
#        ('654', 'Type_3_cervix'), ('677', 'Type_1_cervix')], dtype=object))
# ('--', 44, 'batch loss : ', 1.7558017, ' | info:', array([('602', 'Type_2_cervix'), ('661', 'Type_3_cervix'),
#        ('683', 'Type_1_cervix'), ('603', 'Type_2_cervix')], dtype=object))
# ('--', 48, 'batch loss : ', 1.6910311, ' | info:', array([('664', 'Type_3_cervix'), ('685', 'Type_1_cervix'),
#        ('607', 'Type_2_cervix'), ('669', 'Type_3_cervix')], dtype=object))
# ('--', 52, 'batch loss : ', 1.4670721, ' | info:', array([('7', 'Type_1_cervix'), ('608', 'Type_2_cervix'),
#        ('670', 'Type_3_cervix'), ('700', 'Type_1_cervix')], dtype=object))
# ('--', 56, 'batch loss : ', 1.8187326, ' | info:', array([('609', 'Type_2_cervix'), ('672', 'Type_3_cervix'),
#        ('708', 'Type_1_cervix'), ('610', 'Type_2_cervix')], dtype=object))
# ('--', 60, 'batch loss : ', 1.5584964, ' | info:', array([('675', 'Type_3_cervix'), ('709', 'Type_1_cervix'),
#        ('611', 'Type_2_cervix'), ('679', 'Type_3_cervix')], dtype=object))
# ('--', 64, 'batch loss : ', 2.330852, ' | info:', array([('710', 'Type_1_cervix'), ('612', 'Type_2_cervix'),
#        ('682', 'Type_3_cervix'), ('713', 'Type_1_cervix')], dtype=object))
# ('--', 68, 'batch loss : ', 2.3804085, ' | info:', array([('613', 'Type_2_cervix'), ('689', 'Type_3_cervix'),
#        ('725', 'Type_1_cervix'), ('614', 'Type_2_cervix')], dtype=object))
# ('--', 72, 'batch loss : ', 1.1898063, ' | info:', array([('69', 'Type_3_cervix'), ('727', 'Type_1_cervix'),
#        ('615', 'Type_2_cervix'), ('690', 'Type_3_cervix')], dtype=object))
# ('--', 76, 'batch loss : ', 2.3737979, ' | info:', array([('732', 'Type_1_cervix'), ('616', 'Type_2_cervix'),
#        ('692', 'Type_3_cervix'), ('739', 'Type_1_cervix')], dtype=object))
# ('--', 80, 'batch loss : ', 2.1337361, ' | info:', array([('618', 'Type_2_cervix'), ('694', 'Type_3_cervix'),
#        ('745', 'Type_1_cervix'), ('621', 'Type_2_cervix')], dtype=object))
# ('--', 84, 'batch loss : ', 0.80381876, ' | info:', array([('695', 'Type_3_cervix'), ('751', 'Type_1_cervix'),
#        ('622', 'Type_2_cervix'), ('697', 'Type_3_cervix')], dtype=object))
# ('--', 88, 'batch loss : ', 2.7514758, ' | info:', array([('759', 'Type_1_cervix'), ('632', 'Type_2_cervix'),
#        ('70', 'Type_3_cervix'), ('763', 'Type_1_cervix')], dtype=object))
# ('--', 92, 'batch loss : ', 2.7472563, ' | info:', array([('633', 'Type_2_cervix'), ('706', 'Type_3_cervix'),
#        ('764', 'Type_1_cervix'), ('634', 'Type_2_cervix')], dtype=object))
# ('--', 96, 'batch loss : ', 1.2794945, ' | info:', array([('71', 'Type_3_cervix'), ('765', 'Type_1_cervix'),
#        ('639', 'Type_2_cervix'), ('711', 'Type_3_cervix')], dtype=object))
# ('--', 100, 'batch loss : ', 1.8940413, ' | info:', array([('769', 'Type_1_cervix'), ('64', 'Type_2_cervix'),
#        ('715', 'Type_3_cervix'), ('779', 'Type_1_cervix')], dtype=object))
# ('--', 104, 'batch loss : ', 2.2879004, ' | info:', array([('640', 'Type_2_cervix'), ('721', 'Type_3_cervix'),
#        ('783', 'Type_1_cervix'), ('642', 'Type_2_cervix')], dtype=object))
# ('--', 108, 'batch loss : ', 1.7749363, ' | info:', array([('728', 'Type_3_cervix'), ('787', 'Type_1_cervix'),
#        ('644', 'Type_2_cervix'), ('73', 'Type_3_cervix')], dtype=object))
# ('--', 112, 'batch loss : ', 2.7157192, ' | info:', array([('791', 'Type_1_cervix'), ('647', 'Type_2_cervix'),
#        ('731', 'Type_3_cervix'), ('802', 'Type_1_cervix')], dtype=object))
# ('--', 116, 'batch loss : ', 2.6036663, ' | info:', array([('648', 'Type_2_cervix'), ('733', 'Type_3_cervix'),
#        ('805', 'Type_1_cervix'), ('65', 'Type_2_cervix')], dtype=object))
# ('--', 120, 'batch loss : ', 0.99359906, ' | info:', array([('734', 'Type_3_cervix'), ('809', 'Type_1_cervix'),
#        ('651', 'Type_2_cervix'), ('735', 'Type_3_cervix')], dtype=object))
# ('--', 124, 'batch loss : ', 2.4468675, ' | info:', array([('81', 'Type_1_cervix'), ('652', 'Type_2_cervix'),
#        ('736', 'Type_3_cervix'), ('810', 'Type_1_cervix')], dtype=object))
# ('--', 128, 'batch loss : ', 3.136997, ' | info:', array([('655', 'Type_2_cervix'), ('737', 'Type_3_cervix'),
#        ('814', 'Type_1_cervix'), ('656', 'Type_2_cervix')], dtype=object))
# ('--', 132, 'batch loss : ', 1.4944279, ' | info:', array([('740', 'Type_3_cervix'), ('817', 'Type_1_cervix'),
#        ('657', 'Type_2_cervix'), ('742', 'Type_3_cervix')], dtype=object))
# ('--', 136, 'batch loss : ', 1.5862927, ' | info:', array([('821', 'Type_1_cervix'), ('658', 'Type_2_cervix'),
#        ('746', 'Type_3_cervix'), ('833', 'Type_1_cervix')], dtype=object))
# ('--', 140, 'batch loss : ', 1.721303, ' | info:', array([('659', 'Type_2_cervix'), ('747', 'Type_3_cervix'),
#        ('836', 'Type_1_cervix'), ('66', 'Type_2_cervix')], dtype=object))
# ('--', 144, 'batch loss : ', 1.1125276, ' | info:', array([('750', 'Type_3_cervix'), ('842', 'Type_1_cervix'),
#        ('662', 'Type_2_cervix'), ('752', 'Type_3_cervix')], dtype=object))
# ('--', 148, 'batch loss : ', 2.730099, ' | info:', array([('846', 'Type_1_cervix'), ('665', 'Type_2_cervix'),
#        ('755', 'Type_3_cervix'), ('855', 'Type_1_cervix')], dtype=object))
# ('--', 152, 'batch loss : ', 1.9235812, ' | info:', array([('666', 'Type_2_cervix'), ('757', 'Type_3_cervix'),
#        ('873', 'Type_1_cervix'), ('67', 'Type_2_cervix')], dtype=object))
# ('--', 156, 'batch loss : ', 1.5991974, ' | info:', array([('758', 'Type_3_cervix'), ('879', 'Type_1_cervix'),
#        ('671', 'Type_2_cervix'), ('766', 'Type_3_cervix')], dtype=object))
# ('--', 160, 'batch loss : ', 2.6048229, ' | info:', array([('880', 'Type_1_cervix'), ('673', 'Type_2_cervix'),
#        ('767', 'Type_3_cervix'), ('887', 'Type_1_cervix')], dtype=object))
# ('--', 164, 'batch loss : ', 1.451436, ' | info:', array([('674', 'Type_2_cervix'), ('770', 'Type_3_cervix'),
#        ('889', 'Type_1_cervix'), ('676', 'Type_2_cervix')], dtype=object))
# ('--', 168, 'batch loss : ', 1.3882885, ' | info:', array([('773', 'Type_3_cervix'), ('890', 'Type_1_cervix'),
#        ('678', 'Type_2_cervix'), ('774', 'Type_3_cervix')], dtype=object))
# ('--', 172, 'batch loss : ', 2.6082783, ' | info:', array([('891', 'Type_1_cervix'), ('68', 'Type_2_cervix'),
#        ('776', 'Type_3_cervix'), ('895', 'Type_1_cervix')], dtype=object))
# ('--', 176, 'batch loss : ', 1.8669796, ' | info:', array([('680', 'Type_2_cervix'), ('778', 'Type_3_cervix'),
#        ('901', 'Type_1_cervix'), ('681', 'Type_2_cervix')], dtype=object))
# ('--', 180, 'batch loss : ', 1.0831677, ' | info:', array([('780', 'Type_3_cervix'), ('906', 'Type_1_cervix'),
#        ('684', 'Type_2_cervix'), ('782', 'Type_3_cervix')], dtype=object))
# ('--', 184, 'batch loss : ', 2.3917856, ' | info:', array([('908', 'Type_1_cervix'), ('686', 'Type_2_cervix'),
#        ('784', 'Type_3_cervix'), ('917', 'Type_1_cervix')], dtype=object))
# ('--', 188, 'batch loss : ', 1.694293, ' | info:', array([('687', 'Type_2_cervix'), ('788', 'Type_3_cervix'),
#        ('918', 'Type_1_cervix'), ('688', 'Type_2_cervix')], dtype=object))
# ('--', 192, 'batch loss : ', 1.0647339, ' | info:', array([('796', 'Type_3_cervix'), ('920', 'Type_1_cervix'),
#        ('691', 'Type_2_cervix'), ('799', 'Type_3_cervix')], dtype=object))
# ('--', 196, 'batch loss : ', 2.1436625, ' | info:', array([('921', 'Type_1_cervix'), ('693', 'Type_2_cervix'),
#        ('800', 'Type_3_cervix'), ('928', 'Type_1_cervix')], dtype=object))
# ('--', 200, 'batch loss : ', 2.1801209, ' | info:', array([('696', 'Type_2_cervix'), ('801', 'Type_3_cervix'),
#        ('930', 'Type_1_cervix'), ('698', 'Type_2_cervix')], dtype=object))
# ('--', 204, 'batch loss : ', 2.0475187, ' | info:', array([('803', 'Type_3_cervix'), ('96', 'Type_1_cervix'),
#        ('699', 'Type_2_cervix'), ('806', 'Type_3_cervix')], dtype=object))
# ('--', 208, 'batch loss : ', 2.4068348, ' | info:', array([('965', 'Type_1_cervix'), ('701', 'Type_2_cervix'),
#        ('808', 'Type_3_cervix'), ('972', 'Type_1_cervix')], dtype=object))
# ('--', 212, 'batch loss : ', 1.6800134, ' | info:', array([('702', 'Type_2_cervix'), ('811', 'Type_3_cervix'),
#        ('977', 'Type_1_cervix'), ('703', 'Type_2_cervix')], dtype=object))
# ('--', 216, 'batch loss : ', 1.0962081, ' | info:', array([('812', 'Type_3_cervix'), ('982', 'Type_1_cervix'),
#        ('704', 'Type_2_cervix'), ('818', 'Type_3_cervix')], dtype=object))
# ('--', 220, 'batch loss : ', 2.3591404, ' | info:', array([('984', 'Type_1_cervix'), ('705', 'Type_2_cervix'),
#        ('82', 'Type_3_cervix'), ('991', 'Type_1_cervix')], dtype=object))
# ('--', 224, 'batch loss : ', 2.1509049, ' | info:', array([('707', 'Type_2_cervix'), ('820', 'Type_3_cervix'),
#        ('998', 'Type_1_cervix'), ('712', 'Type_2_cervix')], dtype=object))
# ('--', 228, 'batch loss : ', 1.6766419, ' | info:', array([('822', 'Type_3_cervix'), ('619', 'Type_1_cervix'),
#        ('714', 'Type_2_cervix'), ('823', 'Type_3_cervix')], dtype=object))
# ('--', 232, 'batch loss : ', 2.6117368, ' | info:', array([('620', 'Type_1_cervix'), ('716', 'Type_2_cervix'),
#        ('825', 'Type_3_cervix'), ('623', 'Type_1_cervix')], dtype=object))
# ('--', 236, 'batch loss : ', 1.6890993, ' | info:', array([('717', 'Type_2_cervix'), ('828', 'Type_3_cervix'),
#        ('624', 'Type_1_cervix'), ('718', 'Type_2_cervix')], dtype=object))
# ('--', 240, 'batch loss : ', 1.7127012, ' | info:', array([('83', 'Type_3_cervix'), ('641', 'Type_1_cervix'),
#        ('719', 'Type_2_cervix'), ('835', 'Type_3_cervix')], dtype=object))
# ('--', 244, 'batch loss : ', 2.3636494, ' | info:', array([('643', 'Type_1_cervix'), ('72', 'Type_2_cervix'),
#        ('837', 'Type_3_cervix'), ('645', 'Type_1_cervix')], dtype=object))
# ('--', 248, 'batch loss : ', 1.7501149, ' | info:', array([('720', 'Type_2_cervix'), ('839', 'Type_3_cervix'),
#        ('649', 'Type_1_cervix'), ('722', 'Type_2_cervix')], dtype=object))
# ('--', 252, 'batch loss : ', 1.4009475, ' | info:', array([('840', 'Type_3_cervix'), ('653', 'Type_1_cervix'),
#        ('723', 'Type_2_cervix'), ('845', 'Type_3_cervix')], dtype=object))
# ('--', 256, 'batch loss : ', 2.1913071, ' | info:', array([('660', 'Type_1_cervix'), ('724', 'Type_2_cervix'),
#        ('848', 'Type_3_cervix'), ('663', 'Type_1_cervix')], dtype=object))
# ('--', 260, 'batch loss : ', 2.281491, ' | info:', array([('726', 'Type_2_cervix'), ('853', 'Type_3_cervix'),
#        ('667', 'Type_1_cervix'), ('729', 'Type_2_cervix')], dtype=object))
# ('--', 264, 'batch loss : ', 2.0415933, ' | info:', array([('864', 'Type_3_cervix'), ('668', 'Type_1_cervix'),
#        ('730', 'Type_2_cervix'), ('866', 'Type_3_cervix')], dtype=object))
# ('--', 268, 'batch loss : ', 1.6426585, ' | info:', array([('677', 'Type_1_cervix'), ('738', 'Type_2_cervix'),
#        ('869', 'Type_3_cervix'), ('683', 'Type_1_cervix')], dtype=object))
# ('--', 272, 'batch loss : ', 2.1417239, ' | info:', array([('74', 'Type_2_cervix'), ('87', 'Type_3_cervix'),
#        ('685', 'Type_1_cervix'), ('741', 'Type_2_cervix')], dtype=object))
# ('--', 276, 'batch loss : ', 1.3975505, ' | info:', array([('870', 'Type_3_cervix'), ('7', 'Type_1_cervix'),
#        ('743', 'Type_2_cervix'), ('872', 'Type_3_cervix')], dtype=object))
# ('--', 280, 'batch loss : ', 2.3592904, ' | info:', array([('700', 'Type_1_cervix'), ('744', 'Type_2_cervix'),
#        ('875', 'Type_3_cervix'), ('708', 'Type_1_cervix')], dtype=object))
# ('--', 284, 'batch loss : ', 2.1535583, ' | info:', array([('748', 'Type_2_cervix'), ('876', 'Type_3_cervix'),
#        ('709', 'Type_1_cervix'), ('749', 'Type_2_cervix')], dtype=object))
# ('--', 288, 'batch loss : ', 1.7329563, ' | info:', array([('877', 'Type_3_cervix'), ('710', 'Type_1_cervix'),
#        ('75', 'Type_2_cervix'), ('878', 'Type_3_cervix')], dtype=object))
# ('--', 292, 'batch loss : ', 2.6064482, ' | info:', array([('713', 'Type_1_cervix'), ('753', 'Type_2_cervix'),
#        ('881', 'Type_3_cervix'), ('725', 'Type_1_cervix')], dtype=object))
# ('--', 296, 'batch loss : ', 2.3326342, ' | info:', array([('754', 'Type_2_cervix'), ('885', 'Type_3_cervix'),
#        ('727', 'Type_1_cervix'), ('756', 'Type_2_cervix')], dtype=object))
# ('--', 300, 'batch loss : ', 1.2768997, ' | info:', array([('892', 'Type_3_cervix'), ('732', 'Type_1_cervix'),
#        ('76', 'Type_2_cervix'), ('893', 'Type_3_cervix')], dtype=object))
# ('--', 304, 'batch loss : ', 2.5270214, ' | info:', array([('739', 'Type_1_cervix'), ('760', 'Type_2_cervix'),
#        ('897', 'Type_3_cervix'), ('745', 'Type_1_cervix')], dtype=object))
# ('--', 308, 'batch loss : ', 1.8885975, ' | info:', array([('761', 'Type_2_cervix'), ('898', 'Type_3_cervix'),
#        ('751', 'Type_1_cervix'), ('762', 'Type_2_cervix')], dtype=object))
# ('--', 312, 'batch loss : ', 2.3554263, ' | info:', array([('899', 'Type_3_cervix'), ('759', 'Type_1_cervix'),
#        ('768', 'Type_2_cervix'), ('900', 'Type_3_cervix')], dtype=object))
# ('--', 316, 'batch loss : ', 2.3072414, ' | info:', array([('763', 'Type_1_cervix'), ('77', 'Type_2_cervix'),
#        ('902', 'Type_3_cervix'), ('764', 'Type_1_cervix')], dtype=object))
# ('--', 320, 'batch loss : ', 2.0057654, ' | info:', array([('771', 'Type_2_cervix'), ('907', 'Type_3_cervix'),
#        ('765', 'Type_1_cervix'), ('772', 'Type_2_cervix')], dtype=object))
# ('--', 324, 'batch loss : ', 2.0960884, ' | info:', array([('909', 'Type_3_cervix'), ('769', 'Type_1_cervix'),
#        ('775', 'Type_2_cervix'), ('910', 'Type_3_cervix')], dtype=object))
# ('--', 328, 'batch loss : ', 2.1129961, ' | info:', array([('779', 'Type_1_cervix'), ('777', 'Type_2_cervix'),
#        ('914', 'Type_3_cervix'), ('783', 'Type_1_cervix')], dtype=object))
# ('--', 332, 'batch loss : ', 2.5565519, ' | info:', array([('78', 'Type_2_cervix'), ('916', 'Type_3_cervix'),
#        ('787', 'Type_1_cervix'), ('781', 'Type_2_cervix')], dtype=object))
# ('--', 336, 'batch loss : ', 1.5598564, ' | info:', array([('923', 'Type_3_cervix'), ('791', 'Type_1_cervix'),
#        ('785', 'Type_2_cervix'), ('924', 'Type_3_cervix')], dtype=object))
# ('--', 340, 'batch loss : ', 3.0606833, ' | info:', array([('802', 'Type_1_cervix'), ('786', 'Type_2_cervix'),
#        ('927', 'Type_3_cervix'), ('805', 'Type_1_cervix')], dtype=object))
# ('--', 344, 'batch loss : ', 2.0141644, ' | info:', array([('789', 'Type_2_cervix'), ('931', 'Type_3_cervix'),
#        ('809', 'Type_1_cervix'), ('79', 'Type_2_cervix')], dtype=object))
# ('--', 348, 'batch loss : ', 1.1509192, ' | info:', array([('941', 'Type_3_cervix'), ('81', 'Type_1_cervix'),
#        ('790', 'Type_2_cervix'), ('943', 'Type_3_cervix')], dtype=object))
# ('--', 352, 'batch loss : ', 3.7317801, ' | info:', array([('810', 'Type_1_cervix'), ('792', 'Type_2_cervix'),
#        ('944', 'Type_3_cervix'), ('814', 'Type_1_cervix')], dtype=object))
# ('--', 356, 'batch loss : ', 1.987027, ' | info:', array([('793', 'Type_2_cervix'), ('945', 'Type_3_cervix'),
#        ('817', 'Type_1_cervix'), ('794', 'Type_2_cervix')], dtype=object))
# ('--', 360, 'batch loss : ', 1.5498925, ' | info:', array([('947', 'Type_3_cervix'), ('821', 'Type_1_cervix'),
#        ('795', 'Type_2_cervix'), ('949', 'Type_3_cervix')], dtype=object))
# ('--', 364, 'batch loss : ', 1.7622513, ' | info:', array([('833', 'Type_1_cervix'), ('797', 'Type_2_cervix'),
#        ('950', 'Type_3_cervix'), ('836', 'Type_1_cervix')], dtype=object))
# ('--', 368, 'batch loss : ', 1.5020242, ' | info:', array([('798', 'Type_2_cervix'), ('951', 'Type_3_cervix'),
#        ('842', 'Type_1_cervix'), ('8', 'Type_2_cervix')], dtype=object))
# ('--', 372, 'batch loss : ', 2.5396173, ' | info:', array([('952', 'Type_3_cervix'), ('846', 'Type_1_cervix'),
#        ('80', 'Type_2_cervix'), ('953', 'Type_3_cervix')], dtype=object))
# ('--', 376, 'batch loss : ', 1.9902902, ' | info:', array([('855', 'Type_1_cervix'), ('804', 'Type_2_cervix'),
#        ('954', 'Type_3_cervix'), ('873', 'Type_1_cervix')], dtype=object))
# ('--', 380, 'batch loss : ', 2.1101043, ' | info:', array([('807', 'Type_2_cervix'), ('962', 'Type_3_cervix'),
#        ('879', 'Type_1_cervix'), ('813', 'Type_2_cervix')], dtype=object))
# ('--', 384, 'batch loss : ', 1.093275, ' | info:', array([('968', 'Type_3_cervix'), ('880', 'Type_1_cervix'),
#        ('815', 'Type_2_cervix'), ('975', 'Type_3_cervix')], dtype=object))
# ('--', 388, 'batch loss : ', 2.7928667, ' | info:', array([('887', 'Type_1_cervix'), ('816', 'Type_2_cervix'),
#        ('98', 'Type_3_cervix'), ('889', 'Type_1_cervix')], dtype=object))
# ('--', 392, 'batch loss : ', 2.0340149, ' | info:', array([('819', 'Type_2_cervix'), ('980', 'Type_3_cervix'),
#        ('890', 'Type_1_cervix'), ('824', 'Type_2_cervix')], dtype=object))
# ('--', 396, 'batch loss : ', 1.3791101, ' | info:', array([('983', 'Type_3_cervix'), ('891', 'Type_1_cervix'),
#        ('826', 'Type_2_cervix'), ('986', 'Type_3_cervix')], dtype=object))
# ('--', 400, 'batch loss : ', 2.4507496, ' | info:', array([('895', 'Type_1_cervix'), ('827', 'Type_2_cervix'),
#        ('993', 'Type_3_cervix'), ('901', 'Type_1_cervix')], dtype=object))
# ('--', 404, 'batch loss : ', 1.7258803, ' | info:', array([('829', 'Type_2_cervix'), ('995', 'Type_3_cervix'),
#        ('906', 'Type_1_cervix'), ('830', 'Type_2_cervix')], dtype=object))
# ('--', 408, 'batch loss : ', 2.1264806, ' | info:', array([('996', 'Type_3_cervix'), ('908', 'Type_1_cervix'),
#        ('831', 'Type_2_cervix'), ('627', 'Type_3_cervix')], dtype=object))
# ('--', 412, 'batch loss : ', 1.9258298, ' | info:', array([('917', 'Type_1_cervix'), ('832', 'Type_2_cervix'),
#        ('628', 'Type_3_cervix'), ('918', 'Type_1_cervix')], dtype=object))
# ('--', 416, 'batch loss : ', 1.170203, ' | info:', array([('834', 'Type_2_cervix'), ('629', 'Type_3_cervix'),
#        ('920', 'Type_1_cervix'), ('838', 'Type_2_cervix')], dtype=object))
# ('--', 420, 'batch loss : ', 1.2993766, ' | info:', array([('63', 'Type_3_cervix'), ('921', 'Type_1_cervix'),
#        ('84', 'Type_2_cervix'), ('630', 'Type_3_cervix')], dtype=object))
# ('--', 424, 'batch loss : ', 2.4812999, ' | info:', array([('928', 'Type_1_cervix'), ('841', 'Type_2_cervix'),
#        ('631', 'Type_3_cervix'), ('930', 'Type_1_cervix')], dtype=object))
# ('--', 428, 'batch loss : ', 2.6308982, ' | info:', array([('843', 'Type_2_cervix'), ('635', 'Type_3_cervix'),
#        ('96', 'Type_1_cervix'), ('844', 'Type_2_cervix')], dtype=object))
# ('--', 432, 'batch loss : ', 1.9233295, ' | info:', array([('636', 'Type_3_cervix'), ('965', 'Type_1_cervix'),
#        ('847', 'Type_2_cervix'), ('637', 'Type_3_cervix')], dtype=object))
# ('--', 436, 'batch loss : ', 1.3926775, ' | info:', array([('972', 'Type_1_cervix'), ('849', 'Type_2_cervix'),
#        ('638', 'Type_3_cervix'), ('977', 'Type_1_cervix')], dtype=object))
# ('--', 440, 'batch loss : ', 1.6229415, ' | info:', array([('85', 'Type_2_cervix'), ('646', 'Type_3_cervix'),
#        ('982', 'Type_1_cervix'), ('850', 'Type_2_cervix')], dtype=object))
# ('--', 444, 'batch loss : ', 1.6869332, ' | info:', array([('650', 'Type_3_cervix'), ('984', 'Type_1_cervix'),
#        ('851', 'Type_2_cervix'), ('654', 'Type_3_cervix')], dtype=object))
# ('--', 448, 'batch loss : ', 3.0012436, ' | info:', array([('991', 'Type_1_cervix'), ('852', 'Type_2_cervix'),
#        ('661', 'Type_3_cervix'), ('998', 'Type_1_cervix')], dtype=object))
# ('--', 452, 'batch loss : ', 2.5601461, ' | info:', array([('854', 'Type_2_cervix'), ('664', 'Type_3_cervix'),
#        ('619', 'Type_1_cervix'), ('856', 'Type_2_cervix')], dtype=object))
# ('--', 456, 'batch loss : ', 1.3250507, ' | info:', array([('669', 'Type_3_cervix'), ('620', 'Type_1_cervix'),
#        ('857', 'Type_2_cervix'), ('670', 'Type_3_cervix')], dtype=object))
# ('--', 460, 'batch loss : ', 2.4156961, ' | info:', array([('623', 'Type_1_cervix'), ('858', 'Type_2_cervix'),
#        ('672', 'Type_3_cervix'), ('624', 'Type_1_cervix')], dtype=object))
# ('--', 464, 'batch loss : ', 2.3747749, ' | info:', array([('859', 'Type_2_cervix'), ('675', 'Type_3_cervix'),
#        ('641', 'Type_1_cervix'), ('86', 'Type_2_cervix')], dtype=object))
# ('--', 468, 'batch loss : ', 1.485147, ' | info:', array([('679', 'Type_3_cervix'), ('643', 'Type_1_cervix'),
#        ('860', 'Type_2_cervix'), ('682', 'Type_3_cervix')], dtype=object))
# ('--', 472, 'batch loss : ', 2.3179975, ' | info:', array([('645', 'Type_1_cervix'), ('861', 'Type_2_cervix'),
#        ('689', 'Type_3_cervix'), ('649', 'Type_1_cervix')], dtype=object))
# ('--', 476, 'batch loss : ', 2.6006176, ' | info:', array([('862', 'Type_2_cervix'), ('69', 'Type_3_cervix'),
#        ('653', 'Type_1_cervix'), ('863', 'Type_2_cervix')], dtype=object))
# ('--', 480, 'batch loss : ', 1.6892431, ' | info:', array([('690', 'Type_3_cervix'), ('660', 'Type_1_cervix'),
#        ('865', 'Type_2_cervix'), ('692', 'Type_3_cervix')], dtype=object))
# ('--', 484, 'batch loss : ', 2.3209231, ' | info:', array([('663', 'Type_1_cervix'), ('867', 'Type_2_cervix'),
#        ('694', 'Type_3_cervix'), ('667', 'Type_1_cervix')], dtype=object))
# ('--', 488, 'batch loss : ', 2.5190506, ' | info:', array([('868', 'Type_2_cervix'), ('695', 'Type_3_cervix'),
#        ('668', 'Type_1_cervix'), ('871', 'Type_2_cervix')], dtype=object))
# ('--', 492, 'batch loss : ', 1.1998806, ' | info:', array([('697', 'Type_3_cervix'), ('677', 'Type_1_cervix'),
#        ('874', 'Type_2_cervix'), ('70', 'Type_3_cervix')], dtype=object))
# ('--', 496, 'batch loss : ', 2.1632912, ' | info:', array([('683', 'Type_1_cervix'), ('88', 'Type_2_cervix'),
#        ('706', 'Type_3_cervix'), ('685', 'Type_1_cervix')], dtype=object))
# ('--', 500, 'batch loss : ', 2.1443524, ' | info:', array([('882', 'Type_2_cervix'), ('71', 'Type_3_cervix'),
#        ('7', 'Type_1_cervix'), ('883', 'Type_2_cervix')], dtype=object))
# ('--', 504, 'batch loss : ', 1.4708835, ' | info:', array([('711', 'Type_3_cervix'), ('700', 'Type_1_cervix'),
#        ('884', 'Type_2_cervix'), ('715', 'Type_3_cervix')], dtype=object))
# ('--', 508, 'batch loss : ', 3.0583012, ' | info:', array([('708', 'Type_1_cervix'), ('886', 'Type_2_cervix'),
#        ('721', 'Type_3_cervix'), ('709', 'Type_1_cervix')], dtype=object))
# ('--', 512, 'batch loss : ', 2.2281096, ' | info:', array([('888', 'Type_2_cervix'), ('728', 'Type_3_cervix'),
#        ('710', 'Type_1_cervix'), ('89', 'Type_2_cervix')], dtype=object))
# ('--', 516, 'batch loss : ', 1.092545, ' | info:', array([('73', 'Type_3_cervix'), ('713', 'Type_1_cervix'),
#        ('894', 'Type_2_cervix'), ('731', 'Type_3_cervix')], dtype=object))
# ('--', 520, 'batch loss : ', 1.9145415, ' | info:', array([('725', 'Type_1_cervix'), ('896', 'Type_2_cervix'),
#        ('733', 'Type_3_cervix'), ('727', 'Type_1_cervix')], dtype=object))
# ('--', 524, 'batch loss : ', 1.7839379, ' | info:', array([('9', 'Type_2_cervix'), ('734', 'Type_3_cervix'),
#        ('732', 'Type_1_cervix'), ('90', 'Type_2_cervix')], dtype=object))
# ('--', 528, 'batch loss : ', 1.5274874, ' | info:', array([('735', 'Type_3_cervix'), ('739', 'Type_1_cervix'),
#        ('903', 'Type_2_cervix'), ('736', 'Type_3_cervix')], dtype=object))
# ('--', 532, 'batch loss : ', 2.0930579, ' | info:', array([('745', 'Type_1_cervix'), ('904', 'Type_2_cervix'),
#        ('737', 'Type_3_cervix'), ('751', 'Type_1_cervix')], dtype=object))
# ('--', 536, 'batch loss : ', 3.6399393, ' | info:', array([('905', 'Type_2_cervix'), ('740', 'Type_3_cervix'),
#        ('759', 'Type_1_cervix'), ('91', 'Type_2_cervix')], dtype=object))
# ('--', 540, 'batch loss : ', 1.630924, ' | info:', array([('742', 'Type_3_cervix'), ('763', 'Type_1_cervix'),
#        ('911', 'Type_2_cervix'), ('746', 'Type_3_cervix')], dtype=object))
# ('--', 544, 'batch loss : ', 2.8632832, ' | info:', array([('764', 'Type_1_cervix'), ('912', 'Type_2_cervix'),
#        ('747', 'Type_3_cervix'), ('765', 'Type_1_cervix')], dtype=object))
# ('--', 548, 'batch loss : ', 2.6938214, ' | info:', array([('913', 'Type_2_cervix'), ('750', 'Type_3_cervix'),
#        ('769', 'Type_1_cervix'), ('915', 'Type_2_cervix')], dtype=object))
# ('--', 552, 'batch loss : ', 0.89104384, ' | info:', array([('752', 'Type_3_cervix'), ('779', 'Type_1_cervix'),
#        ('919', 'Type_2_cervix'), ('755', 'Type_3_cervix')], dtype=object))
# ('--', 556, 'batch loss : ', 2.2006373, ' | info:', array([('783', 'Type_1_cervix'), ('92', 'Type_2_cervix'),
#        ('757', 'Type_3_cervix'), ('787', 'Type_1_cervix')], dtype=object))
# ('--', 560, 'batch loss : ', 2.4204845, ' | info:', array([('922', 'Type_2_cervix'), ('758', 'Type_3_cervix'),
#        ('791', 'Type_1_cervix'), ('925', 'Type_2_cervix')], dtype=object))
# ('--', 564, 'batch loss : ', 1.8482366, ' | info:', array([('766', 'Type_3_cervix'), ('802', 'Type_1_cervix'),
#        ('926', 'Type_2_cervix'), ('767', 'Type_3_cervix')], dtype=object))
# ('--', 568, 'batch loss : ', 2.0619004, ' | info:', array([('805', 'Type_1_cervix'), ('929', 'Type_2_cervix'),
#        ('770', 'Type_3_cervix'), ('809', 'Type_1_cervix')], dtype=object))
# ('--', 572, 'batch loss : ', 1.8126806, ' | info:', array([('93', 'Type_2_cervix'), ('773', 'Type_3_cervix'),
#        ('81', 'Type_1_cervix'), ('932', 'Type_2_cervix')], dtype=object))
# ('--', 576, 'batch loss : ', 2.0648997, ' | info:', array([('774', 'Type_3_cervix'), ('810', 'Type_1_cervix'),
#        ('933', 'Type_2_cervix'), ('776', 'Type_3_cervix')], dtype=object))
# ('--', 580, 'batch loss : ', 2.7088015, ' | info:', array([('814', 'Type_1_cervix'), ('934', 'Type_2_cervix'),
#        ('778', 'Type_3_cervix'), ('817', 'Type_1_cervix')], dtype=object))
# ('--', 584, 'batch loss : ', 1.4637058, ' | info:', array([('935', 'Type_2_cervix'), ('780', 'Type_3_cervix'),
#        ('821', 'Type_1_cervix'), ('936', 'Type_2_cervix')], dtype=object))
# ('--', 588, 'batch loss : ', 1.0602238, ' | info:', array([('782', 'Type_3_cervix'), ('833', 'Type_1_cervix'),
#        ('937', 'Type_2_cervix'), ('784', 'Type_3_cervix')], dtype=object))
# ('--', 592, 'batch loss : ', 1.5475595, ' | info:', array([('836', 'Type_1_cervix'), ('938', 'Type_2_cervix'),
#        ('788', 'Type_3_cervix'), ('842', 'Type_1_cervix')], dtype=object))
# ('--', 596, 'batch loss : ', 2.9075251, ' | info:', array([('939', 'Type_2_cervix'), ('796', 'Type_3_cervix'),
#        ('846', 'Type_1_cervix'), ('94', 'Type_2_cervix')], dtype=object))
# ('--', 600, 'batch loss : ', 2.0373409, ' | info:', array([('799', 'Type_3_cervix'), ('855', 'Type_1_cervix'),
#        ('940', 'Type_2_cervix'), ('800', 'Type_3_cervix')], dtype=object))
# ('--', 604, 'batch loss : ', 2.1852164, ' | info:', array([('873', 'Type_1_cervix'), ('942', 'Type_2_cervix'),
#        ('801', 'Type_3_cervix'), ('879', 'Type_1_cervix')], dtype=object))
# ('--', 608, 'batch loss : ', 1.450285, ' | info:', array([('946', 'Type_2_cervix'), ('803', 'Type_3_cervix'),
#        ('880', 'Type_1_cervix'), ('948', 'Type_2_cervix')], dtype=object))
# ('--', 612, 'batch loss : ', 2.3976486, ' | info:', array([('806', 'Type_3_cervix'), ('887', 'Type_1_cervix'),
#        ('95', 'Type_2_cervix'), ('808', 'Type_3_cervix')], dtype=object))
# ('--', 616, 'batch loss : ', 1.2410073, ' | info:', array([('889', 'Type_1_cervix'), ('955', 'Type_2_cervix'),
#        ('811', 'Type_3_cervix'), ('890', 'Type_1_cervix')], dtype=object))
# ('--', 620, 'batch loss : ', 2.2567081, ' | info:', array([('956', 'Type_2_cervix'), ('812', 'Type_3_cervix'),
#        ('891', 'Type_1_cervix'), ('957', 'Type_2_cervix')], dtype=object))
# ('--', 624, 'batch loss : ', 1.6774611, ' | info:', array([('818', 'Type_3_cervix'), ('895', 'Type_1_cervix'),
#        ('958', 'Type_2_cervix'), ('82', 'Type_3_cervix')], dtype=object))
# ('--', 628, 'batch loss : ', 2.3606513, ' | info:', array([('901', 'Type_1_cervix'), ('959', 'Type_2_cervix'),
#        ('820', 'Type_3_cervix'), ('906', 'Type_1_cervix')], dtype=object))
# ('--', 632, 'batch loss : ', 2.3955724, ' | info:', array([('960', 'Type_2_cervix'), ('822', 'Type_3_cervix'),
#        ('908', 'Type_1_cervix'), ('961', 'Type_2_cervix')], dtype=object))
# ('--', 636, 'batch loss : ', 0.59859312, ' | info:', array([('823', 'Type_3_cervix'), ('917', 'Type_1_cervix'),
#        ('963', 'Type_2_cervix'), ('825', 'Type_3_cervix')], dtype=object))
# ('--', 640, 'batch loss : ', 1.8523734, ' | info:', array([('918', 'Type_1_cervix'), ('964', 'Type_2_cervix'),
#        ('828', 'Type_3_cervix'), ('920', 'Type_1_cervix')], dtype=object))
# ('--', 644, 'batch loss : ', 1.4887269, ' | info:', array([('966', 'Type_2_cervix'), ('83', 'Type_3_cervix'),
#        ('921', 'Type_1_cervix'), ('967', 'Type_2_cervix')], dtype=object))
# ('--', 648, 'batch loss : ', 1.5126925, ' | info:', array([('835', 'Type_3_cervix'), ('928', 'Type_1_cervix'),
#        ('969', 'Type_2_cervix'), ('837', 'Type_3_cervix')], dtype=object))
# ('--', 652, 'batch loss : ', 3.2362432, ' | info:', array([('930', 'Type_1_cervix'), ('97', 'Type_2_cervix'),
#        ('839', 'Type_3_cervix'), ('96', 'Type_1_cervix')], dtype=object))
# ('--', 656, 'batch loss : ', 2.2108915, ' | info:', array([('970', 'Type_2_cervix'), ('840', 'Type_3_cervix'),
#        ('965', 'Type_1_cervix'), ('971', 'Type_2_cervix')], dtype=object))
# ('--', 660, 'batch loss : ', 1.2800899, ' | info:', array([('845', 'Type_3_cervix'), ('972', 'Type_1_cervix'),
#        ('973', 'Type_2_cervix'), ('848', 'Type_3_cervix')], dtype=object))
# ('--', 664, 'batch loss : ', 1.524824, ' | info:', array([('977', 'Type_1_cervix'), ('974', 'Type_2_cervix'),
#        ('853', 'Type_3_cervix'), ('982', 'Type_1_cervix')], dtype=object))
# ('--', 668, 'batch loss : ', 2.5389967, ' | info:', array([('976', 'Type_2_cervix'), ('864', 'Type_3_cervix'),
#        ('984', 'Type_1_cervix'), ('978', 'Type_2_cervix')], dtype=object))
# ('--', 672, 'batch loss : ', 1.8455034, ' | info:', array([('866', 'Type_3_cervix'), ('991', 'Type_1_cervix'),
#        ('979', 'Type_2_cervix'), ('869', 'Type_3_cervix')], dtype=object))
# ('--', 676, 'batch loss : ', 3.018214, ' | info:', array([('998', 'Type_1_cervix'), ('981', 'Type_2_cervix'),
#        ('87', 'Type_3_cervix'), ('619', 'Type_1_cervix')], dtype=object))
# ('--', 680, 'batch loss : ', 1.6252375, ' | info:', array([('985', 'Type_2_cervix'), ('870', 'Type_3_cervix'),
#        ('620', 'Type_1_cervix'), ('987', 'Type_2_cervix')], dtype=object))
# ('--', 684, 'batch loss : ', 1.9907296, ' | info:', array([('872', 'Type_3_cervix'), ('623', 'Type_1_cervix'),
#        ('988', 'Type_2_cervix'), ('875', 'Type_3_cervix')], dtype=object))
# ('--', 688, 'batch loss : ', 2.3198154, ' | info:', array([('624', 'Type_1_cervix'), ('989', 'Type_2_cervix'),
#        ('876', 'Type_3_cervix'), ('641', 'Type_1_cervix')], dtype=object))
# ('--', 692, 'batch loss : ', 2.313765, ' | info:', array([('99', 'Type_2_cervix'), ('877', 'Type_3_cervix'),
#        ('643', 'Type_1_cervix'), ('990', 'Type_2_cervix')], dtype=object))
# ('--', 696, 'batch loss : ', 1.5989742, ' | info:', array([('878', 'Type_3_cervix'), ('645', 'Type_1_cervix'),
#        ('992', 'Type_2_cervix'), ('881', 'Type_3_cervix')], dtype=object))
# ('--', 700, 'batch loss : ', 2.1392376, ' | info:', array([('649', 'Type_1_cervix'), ('994', 'Type_2_cervix'),
#        ('885', 'Type_3_cervix'), ('653', 'Type_1_cervix')], dtype=object))
# ('--', 702, 'batch loss : ', 1.9513136, ' | info:', array([('997', 'Type_2_cervix'), ('892', 'Type_3_cervix')], dtype=object))
# ('Total loss : ', 1.9932697257425032)

# %%
print("\n {} - Start predictions and write submission ...".format(datetime.now()))
from test_utils import get_test_id_type_list
test_id_type_list = get_test_id_type_list()
cervix_test_id_type_list = [(id_type[0], id_type[1] + '_cervix') for id_type in test_id_type_list]
predict(resnet, cervix_test_id_type_list, info=save_prefix, batch_size=batch_size)
# Out:
#  2017-04-08 09:58:51.199625 - Start predictions and write submission ...
# ('--', 0, '/', 512)
# ('--', 4, '/', 512)
# ('--', 8, '/', 512)
# ('--', 12, '/', 512)
# ('--', 16, '/', 512)
# ('--', 20, '/', 512)
# ('--', 24, '/', 512)
# ('--', 28, '/', 512)
# ('--', 32, '/', 512)
# ('--', 36, '/', 512)
# ('--', 40, '/', 512)
# ('--', 44, '/', 512)
# ('--', 48, '/', 512)
# ('--', 52, '/', 512)
# ('--', 56, '/', 512)
# ('--', 60, '/', 512)
# ('--', 64, '/', 512)
# ('--', 68, '/', 512)
# ('--', 72, '/', 512)
# ('--', 76, '/', 512)
# ('--', 80, '/', 512)
# ('--', 84, '/', 512)
# ('--', 88, '/', 512)
# ('--', 92, '/', 512)
# ('--', 96, '/', 512)
# ('--', 100, '/', 512)
# ('--', 104, '/', 512)
# ('--', 108, '/', 512)
# ('--', 112, '/', 512)
# ('--', 116, '/', 512)
# ('--', 120, '/', 512)
# ('--', 124, '/', 512)
# ('--', 128, '/', 512)
# ('--', 132, '/', 512)
# ('--', 136, '/', 512)
# ('--', 140, '/', 512)
# ('--', 144, '/', 512)
# ('--', 148, '/', 512)
# ('--', 152, '/', 512)
# ('--', 156, '/', 512)
# ('--', 160, '/', 512)
# ('--', 164, '/', 512)
# ('--', 168, '/', 512)
# ('--', 172, '/', 512)
# ('--', 176, '/', 512)
# ('--', 180, '/', 512)
# ('--', 184, '/', 512)
# ('--', 188, '/', 512)
# ('--', 192, '/', 512)
# ('--', 196, '/', 512)
# ('--', 200, '/', 512)
# ('--', 204, '/', 512)
# ('--', 208, '/', 512)
# ('--', 212, '/', 512)
# ('--', 216, '/', 512)
# ('--', 220, '/', 512)
# ('--', 224, '/', 512)
# ('--', 228, '/', 512)
# ('--', 232, '/', 512)
# ('--', 236, '/', 512)
# ('--', 240, '/', 512)
# ('--', 244, '/', 512)
# ('--', 248, '/', 512)
# ('--', 252, '/', 512)
# ('--', 256, '/', 512)
# ('--', 260, '/', 512)
# ('--', 264, '/', 512)
# ('--', 268, '/', 512)
# ('--', 272, '/', 512)
# ('--', 276, '/', 512)
# ('--', 280, '/', 512)
# ('--', 284, '/', 512)
# ('--', 288, '/', 512)
# ('--', 292, '/', 512)
# ('--', 296, '/', 512)
# ('--', 300, '/', 512)
# ('--', 304, '/', 512)
# ('--', 308, '/', 512)
# ('--', 312, '/', 512)
# ('--', 316, '/', 512)
# ('--', 320, '/', 512)
# ('--', 324, '/', 512)
# ('--', 328, '/', 512)
# ('--', 332, '/', 512)
# ('--', 336, '/', 512)
# ('--', 340, '/', 512)
# ('--', 344, '/', 512)
# ('--', 348, '/', 512)
# ('--', 352, '/', 512)
# ('--', 356, '/', 512)
# ('--', 360, '/', 512)
# ('--', 364, '/', 512)
# ('--', 368, '/', 512)
# ('--', 372, '/', 512)
# ('--', 376, '/', 512)
# ('--', 380, '/', 512)
# ('--', 384, '/', 512)
# ('--', 388, '/', 512)
# ('--', 392, '/', 512)
# ('--', 396, '/', 512)
# ('--', 400, '/', 512)
# ('--', 404, '/', 512)
# ('--', 408, '/', 512)
# ('--', 412, '/', 512)
# ('--', 416, '/', 512)
# ('--', 420, '/', 512)
# ('--', 424, '/', 512)
# ('--', 428, '/', 512)
# ('--', 432, '/', 512)
# ('--', 436, '/', 512)
# ('--', 440, '/', 512)
# ('--', 444, '/', 512)
# ('--', 448, '/', 512)
# ('--', 452, '/', 512)
# ('--', 456, '/', 512)
# ('--', 460, '/', 512)
# ('--', 464, '/', 512)
# ('--', 468, '/', 512)
# ('--', 472, '/', 512)
# ('--', 476, '/', 512)
# ('--', 480, '/', 512)
# ('--', 484, '/', 512)
# ('--', 488, '/', 512)
# ('--', 492, '/', 512)
# ('--', 496, '/', 512)
# ('--', 500, '/', 512)
# ('--', 504, '/', 512)
# ('--', 508, '/', 512)

# %% [markdown]
# ## Analyse predictions

# %%
batch_size = 4
from xy_providers import cached_image_label_provider
from preprocessing.image.iterators import ImageDataIterator
from metrics import logloss_mc

xy_provider = cached_image_label_provider
val_iter = ImageDataIterator(xy_provider(cervix_val_id_type_list,
                                         test_mode=True,
                                         cache=cache),
                             len(cervix_val_id_type_list),
                             None,  # image generator
                             batch_size=batch_size,
                             data_format='channels_first')
total_counter = 0

# %%
for x, y_true, info in val_iter:
    s = y_true.shape[0]
    y_pred = resnet.predict(x)
    print("--", total_counter*batch_size + s)    
    total_counter += 1
    plt_st(12, 4)
    for i in range(s):
        print(info[i], y_pred[i])
        plt.subplot(1, s, i+1)
        plt.title("Pred={}, {:.3f} \n GT = {}".format(np.argmax(y_pred[i])+1, np.max(y_pred[i]), info[i]))
        plt.imshow(x[i, :, :, :].transpose([1, 2, 0]))
    break
# Out:
# ('--', 20)
# (('602', 'Type_2_cervix'), array([ 0.00190561,  0.03086733,  0.9672271 ], dtype=float32))
# (('661', 'Type_3_cervix'), array([ 0.00191835,  0.02823581,  0.96984577], dtype=float32))
# (('683', 'Type_1_cervix'), array([ 0.27233556,  0.3641119 ,  0.36355254], dtype=float32))
# (('603', 'Type_2_cervix'), array([ 0.020846  ,  0.10928339,  0.86987054], dtype=float32))
