# %% [markdown]
# # Cervix detector with [Single Shot Detector (SSD)](https://github.com/weiliu89/caffe/tree/ssd)
#
# Use Caffe-MSLS
#
#
# Useful links :
#
# - [Train SSD on custom dataset](https://github.com/weiliu89/caffe/wiki/Train-SSD-on-custom-dataset)
#
# - [SSD detect notebook](https://github.com/weiliu89/caffe/blob/ssd/examples/ssd_detect.ipynb)
#
# - [SSD notebook](https://github.com/weiliu89/caffe/tree/ssd)

# %%
# https://ipython.org/ipython-doc/3/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

# %%
sys.path.append(os.path.join("..","common"))

# %% [markdown]
# ## Check available `Caffe` distributions

# %%
# !ls /opt/caffe*
# Out:
# /opt/caffe-master:
# build		 data	     include	      Makefile.config.example  src
# caffe.cloc	 distribute  INSTALL.md       matlab		       tools
# cmake		 docker      LICENSE	      models		       xbyak
# CMakeLists.txt	 docs	     Makefile	      python
# CONTRIBUTING.md  examples    Makefile.bak     README.md
# CONTRIBUTORS.md  external    Makefile.config  scripts
#
# /opt/caffe-mlsl:
# build		 data	     include		      matlab	 tools
# caffe.cloc	 distribute  INSTALL.md		      models	 xbyak
# cmake		 docker      LICENSE		      python
# CMakeLists.txt	 docs	     Makefile		      README.md
# CONTRIBUTING.md  examples    Makefile.config	      scripts
# CONTRIBUTORS.md  external    Makefile.config.example  src

# %%
#!diff /opt/caffe-master/Makefile.config  /opt/caffe-mlsl/Makefile.config

# %% [markdown]
# ## Setup `Caffe` and check SSD512\* model

# %%
#os.environ["CAFFE_ROOT"] = "/opt/caffe-master"
os.environ["CAFFE_ROOT"] = "/opt/caffe-mlsl"
os.environ["PATH"] += ":%s/build/tools" % os.environ["CAFFE_ROOT"]
# LD_LIBRARY_PATH is setup in .bash_profile
# os.environ["LD_LIBRARY_PATH"] += ":%s/external/mkl/mklml_lnx_2017.0.2.20170110/lib" % os.environ["CAFFE_ROOT"]
# os.environ["LD_LIBRARY_PATH"] += ":/opt/intel/mlsl_2017.0.006/intel64/lib"

# %%
sys.path.append("%s/python" % os.environ["CAFFE_ROOT"])

# %%
# !ls "$CAFFE_ROOT"/models/intel_optimized_models
# Out:
# alexnet  googlenet  googlenet_v2  resnet_50

# %% [markdown]
# ## Setup trainval datasets

# %%
from data_utils import get_annotations
from PIL import Image

# %%
labels_dict = {
    'os': 0,
    'cervix': 1,
}
sloth_annotations_filename =  os.path.join('..', 'resources', 'cervix_os.json')

# %%
def write_images_labels(data_path, annotations, labels_dict, output_path):
    """
    Method to convert create image files (sym links) and txt annotations and write a listfile
    
    - plain txt detection annotation: label_id, xmin, ymin, xmax, ymax
    """
    output_images_folder = os.path.join(output_path, "images")
    os.makedirs(output_images_folder)
    
    output_labels_folder = os.path.join(output_path, "labels")
    os.makedirs(output_labels_folder)
    
    def _clamp(x, dim):
        return min(max(x, 0), dim-1)
    
    listfile = os.path.join(output_path, "listfile.txt")
    with open(listfile, 'w') as listfile_writer:    
        for annotation in annotations:
            img_filename = annotation['filename']
            basename, ext = os.path.splitext(os.path.basename(img_filename))
            basename = os.path.split(os.path.dirname(img_filename))[1] + '_' + basename
            src_image_filename = os.path.abspath(os.path.join(data_path, img_filename))
            dst_image_filename = "%s%s" % (basename,ext)
            dst_label_filename = "%s.txt" % basename
            listfile_writer.write("%s %s\n" % (os.path.join("images", dst_image_filename), 
                                               os.path.join("labels", dst_label_filename)))
                                  
            dst_image_filename = os.path.abspath(os.path.join(output_images_folder, dst_image_filename))
            dst_label_filename = os.path.abspath(os.path.join(output_labels_folder, dst_label_filename))
            os.symlink(src_image_filename, dst_image_filename)
            pil_image = Image.open(img_filename)
            image_size = pil_image.size       

            with open(dst_label_filename, 'w') as writer:
                for obj in annotation['annotations']:
                    # format : class_name bbox_left bbox_top bbox_right bbox_bottom
                    l, t, w, h = int(obj['x']), int(obj['y']), int(obj['width']), int(obj['height'])
                    r = l+w; b = t+h
                    l = _clamp(l, image_size[0])
                    t = _clamp(t, image_size[1])
                    r = _clamp(r, image_size[0])
                    b = _clamp(b, image_size[1])
                    line = "{label_id} {l} {t} {r} {b}\n".format(
                        label_id=labels_dict[obj['class']],
                        l=l, t=t, r=r, b=b
                    )   
                    writer.write(line)

    return output_images_folder, output_labels_folder, listfile

# %%
import numpy as np
np.random.seed(2017)

train_test_split = 0.75

annotations = get_annotations(sloth_annotations_filename)
# Create data split
num_labels = len(annotations)
indices = np.random.permutation(num_labels)
split_index = int(num_labels * train_test_split)
train_annotations = np.array(annotations)[indices[:split_index]]
test_annotations = np.array(annotations)[indices[split_index:]]

print "Total : %s, Train : %s, Val : %s" % (num_labels, len(train_annotations), len(test_annotations))
# Out:
# Total : 208, Train : 156, Val : 52

# %% [markdown]
# Create LMDB for training and validation datasets

# %%
INPUT_DATA = os.path.abspath(os.path.join("..", "input"))
RESOURCES_PATH = os.path.abspath(os.path.join("..", "resources"))
GENERATED_DATA = os.path.abspath(os.path.join(INPUT_DATA, "generated"))

# %%
label_map_filename = os.path.join(RESOURCES_PATH,"labelmap_ccs.prototxt")

# %%
import shutil

for _dataset, _annotations in zip(['train', 'val'], [train_annotations, test_annotations]):
    
    _dataset_path = os.path.join(GENERATED_DATA, _dataset)

#     if os.path.exists(os.path.join(_dataset_path, _dataset + ".lmdb")):
#         print("Found existing file: ", os.path.join(_dataset_path, _dataset + ".lmdb"))
#         continue
    
    if os.path.isdir(_dataset_path):
        shutil.rmtree(_dataset_path)        
    ret = write_images_labels(RESOURCES_PATH, _annotations, labels_dict, _dataset_path)
    output_images_folder, output_labels_folder, listfile = ret
    
    args = [
        # See the code source : https://github.com/intel/caffe/blob/master/tools/convert_annoset.cpp 
        "--anno_type=detection", # The type of annotation {classification, detection}.
        "--label_type=txt", # The type of label file format for detection {xml, json, txt}.
        "--backend=lmdb",
        "--label_map_file=" + label_map_filename, # A file with LabelMap protobuf message.
        "--check_label=True", # Check that there is no duplicated name/label. 
        "--resize_height=512", # Height images are resized to.
        "--resize_width=512", # Width images are resized to.
        "--encode_type=png", 
        "--encoded=True",
        "--shuffle=True", # Randomly shuffle the order of images and their labels.
        os.path.join(GENERATED_DATA, _dataset_path) + '/', # root, The root directory which contains the images and annotations.
        os.path.join(RESOURCES_PATH, listfile), # listfile, The file which contains image paths and annotation info paths.
        os.path.join(_dataset_path, _dataset + ".lmdb"), # outdir, The output directory which stores the database file.        
    ]
    
    args_str = " ".join(args)
    qsub_script = "\"#PBS -V -I -x -N convert_annoset\nconvert_annoset %s\"" % args_str
    # !echo {qsub_script} > qsub_script
    # !chmod +x qsub_script
    # !qsub $PWD/qsub_script    
    
    # !rm $PWD/qsub_script
# Out:
# qsub: waiting for job 4235.c001 to start
# qsub: job 4235.c001 ready
#
#
#   ########################################################################
#   # Colfax Cluster - https://colfaxresearch.com/
#   #      Date:           Thu Mar 23 09:01:37 PDT 2017
#   #    Job ID:           4235.c001
#   #      User:           u2459
#   # Resources:           neednodes=1,nodes=1,walltime=24:00:00
#   ########################################################################
#
# I0323 09:01:38.870036 190317 convert_annoset.cpp:156] Shuffling data
# I0323 09:01:38.873212 190317 convert_annoset.cpp:159] A total of 156 images.
# I0323 09:01:38.941279 190317 db_lmdb.cpp:72] Opened lmdb /home/u2459/Intel_MobileODT/input/generated/train/train.lmdb

# %%
# !echo Training : $(ls {GENERATED_DATA}/train)
# !echo Validation : $(ls {GENERATED_DATA}/val)
# Out:
# Training : images labels listfile.txt train.lmdb
# Validation : detection_out images labels listfile.txt val.lmdb

# %% [markdown]
# ## Setup network and solver
#
# Following https://github.com/intel/caffe/wiki/SSD:-Single-Shot-MultiBox-Detector

# %%
ssd300_path = os.path.join(RESOURCES_PATH, "SSD_300x300")
weights_filename = os.path.join(ssd300_path, "VGG_ILSVRC_16_layers_fc_reduced.caffemodel")

if not os.path.exists(weights_filename):
    # !cd {RESOURCES_PATH}/SSD_300x300 && wget http://cs.unc.edu/~wliu/projects/ParseNet/VGG_ILSVRC_16_layers_fc_reduced.caffemodel -o {weights_filename}

# %%
batch_size = 32
n_epochs = 100
data_augmentation_factor = 7
train_dataset_size = !cat {GENERATED_DATA}/train/listfile.txt | wc -l
train_dataset_size = int(train_dataset_size[0])
val_dataset_size = !cat {GENERATED_DATA}/val/listfile.txt | wc -l
val_dataset_size = int(val_dataset_size[0])

train_dataset_size, val_dataset_size

n_train_iterations = int(data_augmentation_factor * train_dataset_size * n_epochs * 1.0 / batch_size + 0.5)
n_train_iterations_per_epoch = int(data_augmentation_factor * train_dataset_size * 1.0 / batch_size + 0.5)
n_val_iterations = int(val_dataset_size * 1.0 / batch_size + 0.5)

n_iterations = n_train_iterations + n_val_iterations


print("max_iter", n_train_iterations)
print("test_iter", n_val_iterations)
print("test_interval", n_train_iterations_per_epoch)
# Out:
# ('max_iter', 3413)
# ('test_iter', 2)
# ('test_interval', 34)

# %%
#train_dataset_filename = os.path.join(GENERATED_DATA, "train", "train.lmdb")
#val_dataset_filename = os.path.join(GENERATED_DATA, "train", "val.lmdb")

# %% [markdown]
# ## Train network

# %%
from datetime import datetime

# Create job folder
JOBS_PATH = os.path.join(GENERATED_DATA, 'jobs')
if not os.path.exists(JOBS_PATH):
    os.makedirs(JOBS_PATH)

# Create current job path
#now = datetime.now()
#current_job_path = os.path.join(JOBS_PATH, "train_%s" % str(now.strftime("%Y-%m-%d-%H-%M")))
#os.makedirs(current_job_path)

# %%
# !ls {GENERATED_DATA}
# !ls {JOBS_PATH}
# Out:
# jobs  train  val

# %%
from qsub_utils import submit_job
from qsub_utils import setup_configuration
from qsub_utils import PBS_CONFIGURATION

# %%
setup_configuration(nodes='4:knl7210:ram96gb')

# %%
# !cat {os.path.join(ssd300_path, "solver.prototxt")}
# Out:
# ###### Networks ######
# train_net: "train.prototxt"
# test_net: "val.prototxt"
# ###### Training parameters ######
# base_lr: 0.0001
# max_iter: 3413
# lr_policy: "exp"
# gamma: 0.975
# weight_decay: 7e-07
# ###### Validation parameters ######
# test_iter: 2
# test_interval: 34
# test_initialization: false
# ###### Optimizer ######
# type: "AdaDelta"
# momentum: 0.9
# ###### Other ######
# display: 5
# solver_mode: CPU
# snapshot: 34
# snapshot_prefix: "snapshot_VGG_VOC0712_SSD_300x300"
# debug_info: false
# snapshot_after_train: true
# average_loss: 34
# iter_size: 1
# eval_type: "detection"
# ap_version: "11point"

# %%
caffe_train_cmd = [
    "caffe",
    "train",
    "-solver", os.path.join(ssd300_path, "solver.prototxt"),
    #"-weights", weights_filename
]

process, job_info = submit_job(caffe_train_cmd, name='caffe_train_ssd300', cwd=ssd300_path)

try:
    while True:
        out = process.stdout.readline()    
        if len(out) > 0:        
            print out

        if process.poll() is not None and len(out) == 0:
            break
except KeyboardInterupt:
    # !qdel {job_info['id']}
    # !qstat
# Out:
# qsub: job 4232.c001 ready
#
#
#
#
#
#   ########################################################################
#
#   # Colfax Cluster - https://colfaxresearch.com/
#
#   #      Date:           Thu Mar 23 08:37:56 PDT 2017
#
#   #    Job ID:           4232.c001
#
#   #      User:           u2459
#
#   # Resources:           neednodes=4:knl7210:ram96gb,nodes=4:knl7210:ram96gb,walltime=24:00:00
#
#   ########################################################################
#
#
#
# I0323 08:37:58.363988 189992 caffe.cpp:274] Use CPU.
#
# I0323 08:37:58.365396 189992 solver.cpp:108] Initializing solver from parameters:
#
# train_net: "train.prototxt"
#
# test_net: "val.prototxt"
#
# test_iter: 2
#
# test_interval: 34
#
# base_lr: 0.0001
#
# display: 5
#
# max_iter: 3413
#
# lr_policy: "exp"
#
# gamma: 0.975
#
# momentum: 0.9
#
# weight_decay: 7e-07
#
# snapshot: 34
#
# snapshot_prefix: "snapshot_VGG_VOC0712_SSD_300x300"
#
# solver_mode: CPU
#
# debug_info: false
#
# train_state {
#
#   level: 0
#
#   stage: ""
#
# }
#
# snapshot_after_train: true
#
# test_initialization: false
#
# average_loss: 34
#
# iter_size: 1
#
# type: "AdaDelta"
#
# eval_type: "detection"
#
# ap_version: "11point"
#
# I0323 08:37:58.427878 189992 solver.cpp:147] Creating training net from train_net file: train.prototxt
#
# I0323 08:37:58.564208 189992 cpu_info.cpp:452] Processor speed [MHz]: 1300
#
# I0323 08:37:58.564398 189992 cpu_info.cpp:455] Total number of sockets: 1
#
# I0323 08:37:58.564463 189992 cpu_info.cpp:458] Total number of CPU cores: 64
#
# I0323 08:37:58.565021 189992 cpu_info.cpp:461] Total number of processors: 256
#
# I0323 08:37:58.565397 189992 cpu_info.cpp:464] GPU is used: no
#
# I0323 08:37:58.565731 189992 cpu_info.cpp:467] OpenMP environmental variables are specified: no
#
# I0323 08:37:58.566103 189992 cpu_info.cpp:470] OpenMP thread bind allowed: yes
#
# I0323 08:37:58.566480 189992 cpu_info.cpp:473] Number of OpenMP threads: 64
#
# I0323 08:37:58.574100 189992 net.cpp:155] Initializing net from parameters:
#
# name: "VGG_VOC0712_SSD_300x300_train"
#
# state {
#
#   phase: TRAIN
#
#   level: 0
#
#   stage: ""
#
# }
#
# layer {
#
#   name: "data"
#
#   type: "AnnotatedData"
#
#   top: "data"
#
#   top: "label"
#
#   include {
#
#     phase: TRAIN
#
#   }
#
#   transform_param {
#
#     mirror: true
#
#     resize_param {
#
#       prob: 1
#
#       resize_mode: WARP
#
#       height: 300
#
#       width: 300
#
#       interp_mode: LINEAR
#
#       interp_mode: AREA
#
#       interp_mode: NEAREST
#
#       interp_mode: CUBIC
#
#       interp_mode: LANCZOS4
#
#     }
#
#     emit_constraint {
#
#       emit_type: CENTER
#
#     }
#
#     distort_param {
#
#       brightness_prob: 0.5
#
#       brightness_delta: 32
#
#       contrast_prob: 0.5
#
#       contrast_lower: 0.5
#
#       contrast_upper: 1.5
#
#       hue_prob: 0.5
#
#       hue_delta: 18
#
#       saturation_prob: 0.5
#
#       saturation_lower: 0.5
#
#       saturation_upper: 1.5
#
#       random_order_prob: 0
#
#     }
#
#     expand_param {
#
#       prob: 0.5
#
#       max_expand_ratio: 4
#
#     }
#
#   }
#
#   data_param {
#
#     source: "../../input/generated/train/train.lmdb"
#
#     batch_size: 32
#
#     backend: LMDB
#
#   }
#
#   annotated_data_param {
#
#     batch_sampler {
#
#       max_sample: 1
#
#       max_trials: 1
#
#     }
#
#     batch_sampler {
#
#       sampler {
#
#         min_scale: 0.3
#
#         max_scale: 1
#
#         min_aspect_ratio: 0.5
#
#         max_aspect_ratio: 2
#
#       }
#
#       sample_constraint {
#
#         min_jaccard_overlap: 0.1
#
#       }
#
#       max_sample: 1
#
#       max_trials: 50
#
#     }
#
#     batch_sampler {
#
#       sampler {
#
#         min_scale: 0.3
#
#         max_scale: 1
#
#         min_aspect_ratio: 0.5
#
#         max_aspect_ratio: 2
#
#       }
#
#       sample_constraint {
#
#         min_jaccard_overlap: 0.3
#
#       }
#
#       max_sample: 1
#
#       max_trials: 50
#
#     }
#
#     batch_sampler {
#
#       sampler {
#
#         min_scale: 0.3
#
#         max_scale: 1
#
#         min_aspect_ratio: 0.5
#
#         max_aspect_ratio: 2
#
#       }
#
#       sample_constraint {
#
#         min_jaccard_overlap: 0.5
#
#       }
#
#       max_sample: 1
#
#       max_trials: 50
#
#     }
#
#     batch_sampler {
#
#       sampler {
#
#         min_scale: 0.3
#
#         max_scale: 1
#
#         min_aspect_ratio: 0.5
#
#         max_aspect_ratio: 2
#
#       }
#
#       sample_constraint {
#
#         min_jaccard_overlap: 0.7
#
#       }
#
#       max_sample: 1
#
#       max_trials: 50
#
#     }
#
#     batch_sampler {
#
#       sampler {
#
#         min_scale: 0.3
#
#         max_scale: 1
#
#         min_aspect_ratio: 0.5
#
#         max_aspect_ratio: 2
#
#       }
#
#       sample_constraint {
#
#         min_jaccard_overlap: 0.9
#
#       }
#
#       max_sample: 1
#
#       max_trials: 50
#
#     }
#
#     batch_sampler {
#
#       sampler {
#
#         min_scale: 0.3
#
#         max_scale: 1
#
#         min_aspect_ratio: 0.5
#
#         max_aspect_ratio: 2
#
#       }
#
#       sample_constraint {
#
#         max_jaccard_overlap: 1
#
#       }
#
#       max_sample: 1
#
#       max_trials: 50
#
#     }
#
#     label_map_file: "../labelmap_ccs.prototxt"
#
#   }
#
# }
#
# layer {
#
#   name: "data_data_0_split"
#
#   type: "Split"
#
#   bottom: "data"
#
#   top: "data_data_0_split_0"
#
#   top: "data_data_0_split_1"
#
#   top: "data_data_0_split_2"
#
#   top: "data_data_0_split_3"
#
#   top: "data_data_0_split_4"
#
#   top: "data_data_0_split_5"
#
#   top: "data_data_0_split_6"
#
# }
#
# layer {
#
#   name: "conv1_1"
#
#   type: "Convolution"
#
#   bottom: "data_data_0_split_0"
#
#   top: "conv1_1"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 64
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu1_1"
#
#   type: "ReLU"
#
#   bottom: "conv1_1"
#
#   top: "conv1_1"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv1_2"
#
#   type: "Convolution"
#
#   bottom: "conv1_1"
#
#   top: "conv1_2"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 64
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu1_2"
#
#   type: "ReLU"
#
#   bottom: "conv1_2"
#
#   top: "conv1_2"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "pool1"
#
#   type: "Pooling"
#
#   bottom: "conv1_2"
#
#   top: "pool1"
#
#   pooling_param {
#
#     pool: MAX
#
#     kernel_size: 2
#
#     stride: 2
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv2_1"
#
#   type: "Convolution"
#
#   bottom: "pool1"
#
#   top: "conv2_1"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 128
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu2_1"
#
#   type: "ReLU"
#
#   bottom: "conv2_1"
#
#   top: "conv2_1"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv2_2"
#
#   type: "Convolution"
#
#   bottom: "conv2_1"
#
#   top: "conv2_2"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 128
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu2_2"
#
#   type: "ReLU"
#
#   bottom: "conv2_2"
#
#   top: "conv2_2"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "pool2"
#
#   type: "Pooling"
#
#   bottom: "conv2_2"
#
#   top: "pool2"
#
#   pooling_param {
#
#     pool: MAX
#
#     kernel_size: 2
#
#     stride: 2
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv3_1"
#
#   type: "Convolution"
#
#   bottom: "pool2"
#
#   top: "conv3_1"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 256
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu3_1"
#
#   type: "ReLU"
#
#   bottom: "conv3_1"
#
#   top: "conv3_1"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv3_2"
#
#   type: "Convolution"
#
#   bottom: "conv3_1"
#
#   top: "conv3_2"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 256
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu3_2"
#
#   type: "ReLU"
#
#   bottom: "conv3_2"
#
#   top: "conv3_2"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv3_3"
#
#   type: "Convolution"
#
#   bottom: "conv3_2"
#
#   top: "conv3_3"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 256
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu3_3"
#
#   type: "ReLU"
#
#   bottom: "conv3_3"
#
#   top: "conv3_3"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "pool3"
#
#   type: "Pooling"
#
#   bottom: "conv3_3"
#
#   top: "pool3"
#
#   pooling_param {
#
#     pool: MAX
#
#     kernel_size: 2
#
#     stride: 2
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv4_1"
#
#   type: "Convolution"
#
#   bottom: "pool3"
#
#   top: "conv4_1"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 512
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu4_1"
#
#   type: "ReLU"
#
#   bottom: "conv4_1"
#
#   top: "conv4_1"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv4_2"
#
#   type: "Convolution"
#
#   bottom: "conv4_1"
#
#   top: "conv4_2"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 512
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu4_2"
#
#   type: "ReLU"
#
#   bottom: "conv4_2"
#
#   top: "conv4_2"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv4_3"
#
#   type: "Convolution"
#
#   bottom: "conv4_2"
#
#   top: "conv4_3"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 512
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu4_3"
#
#   type: "ReLU"
#
#   bottom: "conv4_3"
#
#   top: "conv4_3"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv4_3_relu4_3_0_split"
#
#   type: "Split"
#
#   bottom: "conv4_3"
#
#   top: "conv4_3_relu4_3_0_split_0"
#
#   top: "conv4_3_relu4_3_0_split_1"
#
# }
#
# layer {
#
#   name: "pool4"
#
#   type: "Pooling"
#
#   bottom: "conv4_3_relu4_3_0_split_0"
#
#   top: "pool4"
#
#   pooling_param {
#
#     pool: MAX
#
#     kernel_size: 2
#
#     stride: 2
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv5_1"
#
#   type: "Convolution"
#
#   bottom: "pool4"
#
#   top: "conv5_1"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 512
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#     dilation: 1
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu5_1"
#
#   type: "ReLU"
#
#   bottom: "conv5_1"
#
#   top: "conv5_1"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv5_2"
#
#   type: "Convolution"
#
#   bottom: "conv5_1"
#
#   top: "conv5_2"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 512
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#     dilation: 1
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu5_2"
#
#   type: "ReLU"
#
#   bottom: "conv5_2"
#
#   top: "conv5_2"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv5_3"
#
#   type: "Convolution"
#
#   bottom: "conv5_2"
#
#   top: "conv5_3"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 512
#
#     pad: 1
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#     dilation: 1
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu5_3"
#
#   type: "ReLU"
#
#   bottom: "conv5_3"
#
#   top: "conv5_3"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "pool5"
#
#   type: "Pooling"
#
#   bottom: "conv5_3"
#
#   top: "pool5"
#
#   pooling_param {
#
#     pool: MAX
#
#     kernel_size: 3
#
#     stride: 1
#
#     pad: 1
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "fc6"
#
#   type: "Convolution"
#
#   bottom: "pool5"
#
#   top: "fc6"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 1024
#
#     pad: 6
#
#     kernel_size: 3
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#     dilation: 6
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu6"
#
#   type: "ReLU"
#
#   bottom: "fc6"
#
#   top: "fc6"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "fc7"
#
#   type: "Convolution"
#
#   bottom: "fc6"
#
#   top: "fc7"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 1024
#
#     kernel_size: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "relu7"
#
#   type: "ReLU"
#
#   bottom: "fc7"
#
#   top: "fc7"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "fc7_relu7_0_split"
#
#   type: "Split"
#
#   bottom: "fc7"
#
#   top: "fc7_relu7_0_split_0"
#
#   top: "fc7_relu7_0_split_1"
#
#   top: "fc7_relu7_0_split_2"
#
#   top: "fc7_relu7_0_split_3"
#
# }
#
# layer {
#
#   name: "conv6_1"
#
#   type: "Convolution"
#
#   bottom: "fc7_relu7_0_split_0"
#
#   top: "conv6_1"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 256
#
#     pad: 0
#
#     kernel_size: 1
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv6_1_relu"
#
#   type: "ReLU"
#
#   bottom: "conv6_1"
#
#   top: "conv6_1"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv6_2"
#
#   type: "Convolution"
#
#   bottom: "conv6_1"
#
#   top: "conv6_2"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 512
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 2
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv6_2_relu"
#
#   type: "ReLU"
#
#   bottom: "conv6_2"
#
#   top: "conv6_2"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv6_2_conv6_2_relu_0_split"
#
#   type: "Split"
#
#   bottom: "conv6_2"
#
#   top: "conv6_2_conv6_2_relu_0_split_0"
#
#   top: "conv6_2_conv6_2_relu_0_split_1"
#
#   top: "conv6_2_conv6_2_relu_0_split_2"
#
#   top: "conv6_2_conv6_2_relu_0_split_3"
#
# }
#
# layer {
#
#   name: "conv7_1"
#
#   type: "Convolution"
#
#   bottom: "conv6_2_conv6_2_relu_0_split_0"
#
#   top: "conv7_1"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 128
#
#     pad: 0
#
#     kernel_size: 1
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv7_1_relu"
#
#   type: "ReLU"
#
#   bottom: "conv7_1"
#
#   top: "conv7_1"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv7_2"
#
#   type: "Convolution"
#
#   bottom: "conv7_1"
#
#   top: "conv7_2"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 256
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 2
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv7_2_relu"
#
#   type: "ReLU"
#
#   bottom: "conv7_2"
#
#   top: "conv7_2"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv7_2_conv7_2_relu_0_split"
#
#   type: "Split"
#
#   bottom: "conv7_2"
#
#   top: "conv7_2_conv7_2_relu_0_split_0"
#
#   top: "conv7_2_conv7_2_relu_0_split_1"
#
#   top: "conv7_2_conv7_2_relu_0_split_2"
#
#   top: "conv7_2_conv7_2_relu_0_split_3"
#
# }
#
# layer {
#
#   name: "conv8_1"
#
#   type: "Convolution"
#
#   bottom: "conv7_2_conv7_2_relu_0_split_0"
#
#   top: "conv8_1"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 128
#
#     pad: 0
#
#     kernel_size: 1
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv8_1_relu"
#
#   type: "ReLU"
#
#   bottom: "conv8_1"
#
#   top: "conv8_1"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv8_2"
#
#   type: "Convolution"
#
#   bottom: "conv8_1"
#
#   top: "conv8_2"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 256
#
#     pad: 0
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv8_2_relu"
#
#   type: "ReLU"
#
#   bottom: "conv8_2"
#
#   top: "conv8_2"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv8_2_conv8_2_relu_0_split"
#
#   type: "Split"
#
#   bottom: "conv8_2"
#
#   top: "conv8_2_conv8_2_relu_0_split_0"
#
#   top: "conv8_2_conv8_2_relu_0_split_1"
#
#   top: "conv8_2_conv8_2_relu_0_split_2"
#
#   top: "conv8_2_conv8_2_relu_0_split_3"
#
# }
#
# layer {
#
#   name: "conv9_1"
#
#   type: "Convolution"
#
#   bottom: "conv8_2_conv8_2_relu_0_split_0"
#
#   top: "conv9_1"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 128
#
#     pad: 0
#
#     kernel_size: 1
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv9_1_relu"
#
#   type: "ReLU"
#
#   bottom: "conv9_1"
#
#   top: "conv9_1"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv9_2"
#
#   type: "Convolution"
#
#   bottom: "conv9_1"
#
#   top: "conv9_2"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 256
#
#     pad: 0
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv9_2_relu"
#
#   type: "ReLU"
#
#   bottom: "conv9_2"
#
#   top: "conv9_2"
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv9_2_conv9_2_relu_0_split"
#
#   type: "Split"
#
#   bottom: "conv9_2"
#
#   top: "conv9_2_conv9_2_relu_0_split_0"
#
#   top: "conv9_2_conv9_2_relu_0_split_1"
#
#   top: "conv9_2_conv9_2_relu_0_split_2"
#
# }
#
# layer {
#
#   name: "conv4_3_norm"
#
#   type: "Normalize"
#
#   bottom: "conv4_3_relu4_3_0_split_1"
#
#   top: "conv4_3_norm"
#
#   norm_param {
#
#     across_spatial: false
#
#     scale_filler {
#
#       type: "constant"
#
#       value: 20
#
#     }
#
#     channel_shared: false
#
#   }
#
# }
#
# layer {
#
#   name: "conv4_3_norm_conv4_3_norm_0_split"
#
#   type: "Split"
#
#   bottom: "conv4_3_norm"
#
#   top: "conv4_3_norm_conv4_3_norm_0_split_0"
#
#   top: "conv4_3_norm_conv4_3_norm_0_split_1"
#
#   top: "conv4_3_norm_conv4_3_norm_0_split_2"
#
# }
#
# layer {
#
#   name: "conv4_3_norm_mbox_loc"
#
#   type: "Convolution"
#
#   bottom: "conv4_3_norm_conv4_3_norm_0_split_0"
#
#   top: "conv4_3_norm_mbox_loc"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 16
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
# }
#
# layer {
#
#   name: "conv4_3_norm_mbox_loc_perm"
#
#   type: "Permute"
#
#   bottom: "conv4_3_norm_mbox_loc"
#
#   top: "conv4_3_norm_mbox_loc_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv4_3_norm_mbox_loc_flat"
#
#   type: "Flatten"
#
#   bottom: "conv4_3_norm_mbox_loc_perm"
#
#   top: "conv4_3_norm_mbox_loc_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv4_3_norm_mbox_conf"
#
#   type: "Convolution"
#
#   bottom: "conv4_3_norm_conv4_3_norm_0_split_1"
#
#   top: "conv4_3_norm_mbox_conf"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 84
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
# }
#
# layer {
#
#   name: "conv4_3_norm_mbox_conf_perm"
#
#   type: "Permute"
#
#   bottom: "conv4_3_norm_mbox_conf"
#
#   top: "conv4_3_norm_mbox_conf_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv4_3_norm_mbox_conf_flat"
#
#   type: "Flatten"
#
#   bottom: "conv4_3_norm_mbox_conf_perm"
#
#   top: "conv4_3_norm_mbox_conf_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv4_3_norm_mbox_priorbox"
#
#   type: "PriorBox"
#
#   bottom: "conv4_3_norm_conv4_3_norm_0_split_2"
#
#   bottom: "data_data_0_split_1"
#
#   top: "conv4_3_norm_mbox_priorbox"
#
#   prior_box_param {
#
#     min_size: 30
#
#     max_size: 60
#
#     aspect_ratio: 2
#
#     flip: true
#
#     clip: false
#
#     variance: 0.1
#
#     variance: 0.1
#
#     variance: 0.2
#
#     variance: 0.2
#
#     step: 8
#
#     offset: 0.5
#
#   }
#
# }
#
# layer {
#
#   name: "fc7_mbox_loc"
#
#   type: "Convolution"
#
#   bottom: "fc7_relu7_0_split_1"
#
#   top: "fc7_mbox_loc"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 24
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "fc7_mbox_loc_perm"
#
#   type: "Permute"
#
#   bottom: "fc7_mbox_loc"
#
#   top: "fc7_mbox_loc_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "fc7_mbox_loc_flat"
#
#   type: "Flatten"
#
#   bottom: "fc7_mbox_loc_perm"
#
#   top: "fc7_mbox_loc_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "fc7_mbox_conf"
#
#   type: "Convolution"
#
#   bottom: "fc7_relu7_0_split_2"
#
#   top: "fc7_mbox_conf"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 126
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
# }
#
# layer {
#
#   name: "fc7_mbox_conf_perm"
#
#   type: "Permute"
#
#   bottom: "fc7_mbox_conf"
#
#   top: "fc7_mbox_conf_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "fc7_mbox_conf_flat"
#
#   type: "Flatten"
#
#   bottom: "fc7_mbox_conf_perm"
#
#   top: "fc7_mbox_conf_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "fc7_mbox_priorbox"
#
#   type: "PriorBox"
#
#   bottom: "fc7_relu7_0_split_3"
#
#   bottom: "data_data_0_split_2"
#
#   top: "fc7_mbox_priorbox"
#
#   prior_box_param {
#
#     min_size: 60
#
#     max_size: 111
#
#     aspect_ratio: 2
#
#     aspect_ratio: 3
#
#     flip: true
#
#     clip: false
#
#     variance: 0.1
#
#     variance: 0.1
#
#     variance: 0.2
#
#     variance: 0.2
#
#     step: 16
#
#     offset: 0.5
#
#   }
#
# }
#
# layer {
#
#   name: "conv6_2_mbox_loc"
#
#   type: "Convolution"
#
#   bottom: "conv6_2_conv6_2_relu_0_split_1"
#
#   top: "conv6_2_mbox_loc"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 24
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv6_2_mbox_loc_perm"
#
#   type: "Permute"
#
#   bottom: "conv6_2_mbox_loc"
#
#   top: "conv6_2_mbox_loc_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv6_2_mbox_loc_flat"
#
#   type: "Flatten"
#
#   bottom: "conv6_2_mbox_loc_perm"
#
#   top: "conv6_2_mbox_loc_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv6_2_mbox_conf"
#
#   type: "Convolution"
#
#   bottom: "conv6_2_conv6_2_relu_0_split_2"
#
#   top: "conv6_2_mbox_conf"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 126
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
# }
#
# layer {
#
#   name: "conv6_2_mbox_conf_perm"
#
#   type: "Permute"
#
#   bottom: "conv6_2_mbox_conf"
#
#   top: "conv6_2_mbox_conf_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv6_2_mbox_conf_flat"
#
#   type: "Flatten"
#
#   bottom: "conv6_2_mbox_conf_perm"
#
#   top: "conv6_2_mbox_conf_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv6_2_mbox_priorbox"
#
#   type: "PriorBox"
#
#   bottom: "conv6_2_conv6_2_relu_0_split_3"
#
#   bottom: "data_data_0_split_3"
#
#   top: "conv6_2_mbox_priorbox"
#
#   prior_box_param {
#
#     min_size: 111
#
#     max_size: 162
#
#     aspect_ratio: 2
#
#     aspect_ratio: 3
#
#     flip: true
#
#     clip: false
#
#     variance: 0.1
#
#     variance: 0.1
#
#     variance: 0.2
#
#     variance: 0.2
#
#     step: 32
#
#     offset: 0.5
#
#   }
#
# }
#
# layer {
#
#   name: "conv7_2_mbox_loc"
#
#   type: "Convolution"
#
#   bottom: "conv7_2_conv7_2_relu_0_split_1"
#
#   top: "conv7_2_mbox_loc"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 24
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
# }
#
# layer {
#
#   name: "conv7_2_mbox_loc_perm"
#
#   type: "Permute"
#
#   bottom: "conv7_2_mbox_loc"
#
#   top: "conv7_2_mbox_loc_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv7_2_mbox_loc_flat"
#
#   type: "Flatten"
#
#   bottom: "conv7_2_mbox_loc_perm"
#
#   top: "conv7_2_mbox_loc_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv7_2_mbox_conf"
#
#   type: "Convolution"
#
#   bottom: "conv7_2_conv7_2_relu_0_split_2"
#
#   top: "conv7_2_mbox_conf"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 126
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv7_2_mbox_conf_perm"
#
#   type: "Permute"
#
#   bottom: "conv7_2_mbox_conf"
#
#   top: "conv7_2_mbox_conf_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv7_2_mbox_conf_flat"
#
#   type: "Flatten"
#
#   bottom: "conv7_2_mbox_conf_perm"
#
#   top: "conv7_2_mbox_conf_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv7_2_mbox_priorbox"
#
#   type: "PriorBox"
#
#   bottom: "conv7_2_conv7_2_relu_0_split_3"
#
#   bottom: "data_data_0_split_4"
#
#   top: "conv7_2_mbox_priorbox"
#
#   prior_box_param {
#
#     min_size: 162
#
#     max_size: 213
#
#     aspect_ratio: 2
#
#     aspect_ratio: 3
#
#     flip: true
#
#     clip: false
#
#     variance: 0.1
#
#     variance: 0.1
#
#     variance: 0.2
#
#     variance: 0.2
#
#     step: 64
#
#     offset: 0.5
#
#   }
#
# }
#
# layer {
#
#   name: "conv8_2_mbox_loc"
#
#   type: "Convolution"
#
#   bottom: "conv8_2_conv8_2_relu_0_split_1"
#
#   top: "conv8_2_mbox_loc"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 16
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv8_2_mbox_loc_perm"
#
#   type: "Permute"
#
#   bottom: "conv8_2_mbox_loc"
#
#   top: "conv8_2_mbox_loc_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv8_2_mbox_loc_flat"
#
#   type: "Flatten"
#
#   bottom: "conv8_2_mbox_loc_perm"
#
#   top: "conv8_2_mbox_loc_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv8_2_mbox_conf"
#
#   type: "Convolution"
#
#   bottom: "conv8_2_conv8_2_relu_0_split_2"
#
#   top: "conv8_2_mbox_conf"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 84
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv8_2_mbox_conf_perm"
#
#   type: "Permute"
#
#   bottom: "conv8_2_mbox_conf"
#
#   top: "conv8_2_mbox_conf_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv8_2_mbox_conf_flat"
#
#   type: "Flatten"
#
#   bottom: "conv8_2_mbox_conf_perm"
#
#   top: "conv8_2_mbox_conf_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv8_2_mbox_priorbox"
#
#   type: "PriorBox"
#
#   bottom: "conv8_2_conv8_2_relu_0_split_3"
#
#   bottom: "data_data_0_split_5"
#
#   top: "conv8_2_mbox_priorbox"
#
#   prior_box_param {
#
#     min_size: 213
#
#     max_size: 264
#
#     aspect_ratio: 2
#
#     flip: true
#
#     clip: false
#
#     variance: 0.1
#
#     variance: 0.1
#
#     variance: 0.2
#
#     variance: 0.2
#
#     step: 100
#
#     offset: 0.5
#
#   }
#
# }
#
# layer {
#
#   name: "conv9_2_mbox_loc"
#
#   type: "Convolution"
#
#   bottom: "conv9_2_conv9_2_relu_0_split_0"
#
#   top: "conv9_2_mbox_loc"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 16
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
# }
#
# layer {
#
#   name: "conv9_2_mbox_loc_perm"
#
#   type: "Permute"
#
#   bottom: "conv9_2_mbox_loc"
#
#   top: "conv9_2_mbox_loc_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv9_2_mbox_loc_flat"
#
#   type: "Flatten"
#
#   bottom: "conv9_2_mbox_loc_perm"
#
#   top: "conv9_2_mbox_loc_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv9_2_mbox_conf"
#
#   type: "Convolution"
#
#   bottom: "conv9_2_conv9_2_relu_0_split_1"
#
#   top: "conv9_2_mbox_conf"
#
#   param {
#
#     lr_mult: 1
#
#     decay_mult: 1
#
#   }
#
#   param {
#
#     lr_mult: 2
#
#     decay_mult: 0
#
#   }
#
#   convolution_param {
#
#     num_output: 84
#
#     pad: 1
#
#     kernel_size: 3
#
#     stride: 1
#
#     weight_filler {
#
#       type: "xavier"
#
#     }
#
#     bias_filler {
#
#       type: "constant"
#
#       value: 0
#
#     }
#
#   }
#
#   engine: "MKL2017"
#
# }
#
# layer {
#
#   name: "conv9_2_mbox_conf_perm"
#
#   type: "Permute"
#
#   bottom: "conv9_2_mbox_conf"
#
#   top: "conv9_2_mbox_conf_perm"
#
#   permute_param {
#
#     order: 0
#
#     order: 2
#
#     order: 3
#
#     order: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv9_2_mbox_conf_flat"
#
#   type: "Flatten"
#
#   bottom: "conv9_2_mbox_conf_perm"
#
#   top: "conv9_2_mbox_conf_flat"
#
#   flatten_param {
#
#     axis: 1
#
#   }
#
# }
#
# layer {
#
#   name: "conv9_2_mbox_priorbox"
#
#   type: "PriorBox"
#
#   bottom: "conv9_2_conv9_2_relu_0_split_2"
#
#   bottom: "data_data_0_split_6"
#
#   top: "conv9_2_mbox_priorbox"
#
#   prior_box_param {
#
#     min_size: 264
#
#     max_size: 315
#
#     aspect_ratio: 2
#
#     flip: true
#
#     clip: false
#
#     variance: 0.1
#
#     variance: 0.1
#
#     variance: 0.2
#
#     variance: 0.2
#
#     step: 300
#
#     offset: 0.5
#
#   }
#
# }
#
# layer {
#
#   name: "mbox_loc"
#
#   type: "Concat"
#
#   bottom: "conv4_3_norm_mbox_loc_flat"
#
#   bottom: "fc7_mbox_loc_flat"
#
#   bottom: "conv6_2_mbox_loc_flat"
#
#   bottom: "conv7_2_mbox_loc_flat"
#
#   bottom: "conv8_2_mbox_loc_flat"
#
#   bottom: "conv9_2_mbox_loc_flat"
#
#   top: "mbox_loc"
#
#   concat_param {
#
#     axis: 1
#
#   }
#
#   engine: "CAFFE"
#
# }
#
# layer {
#
#   name: "mbox_conf"
#
#   type: "Concat"
#
#   bottom: "conv4_3_norm_mbox_conf_flat"
#
#   bottom: "fc7_mbox_conf_flat"
#
#   bottom: "conv6_2_mbox_conf_flat"
#
#   bottom: "conv7_2_mbox_conf_flat"
#
#   bottom: "conv8_2_mbox_conf_flat"
#
#   bottom: "conv9_2_mbox_conf_flat"
#
#   top: "mbox_conf"
#
#   concat_param {
#
#     axis: 1
#
#   }
#
#   engine: "CAFFE"
#
# }
#
# layer {
#
#   name: "mbox_priorbox"
#
#   type: "Concat"
#
#   bottom: "conv4_3_norm_mbox_priorbox"
#
#   bottom: "fc7_mbox_priorbox"
#
#   bottom: "conv6_2_mbox_priorbox"
#
#   bottom: "conv7_2_mbox_priorbox"
#
#   bottom: "conv8_2_mbox_priorbox"
#
#   bottom: "conv9_2_mbox_priorbox"
#
#   top: "mbox_priorbox"
#
#   concat_param {
#
#     axis: 2
#
#   }
#
#   engine: "CAFFE"
#
# }
#
# layer {
#
#   name: "mbox_loss"
#
#   type: "MultiBoxLoss"
#
#   bottom: "mbox_loc"
#
#   bottom: "mbox_conf"
#
#   bottom: "mbox_priorbox"
#
#   bottom: "label"
#
#
#
# I0323 08:37:58.603950 189992 layer_factory.hpp:114] Creating layer data
#
# I0323 08:37:58.606132 189992 net.cpp:197] Creating Layer data
#
# I0323 08:37:58.606245 189992 net.cpp:866] data -> data
#
# I0323 08:37:58.606396 189992 net.cpp:866] data -> label
#
# I0323 08:37:58.727380 190059 db_lmdb.cpp:72] Opened lmdb ../../input/generated/train/train.lmdb
#
# I0323 08:37:58.732329 189992 annotated_data_layer.cpp:100] output data size: 32,3,300,300
#
# I0323 08:37:58.801519 189992 net.cpp:282] Setting up data
#
# I0323 08:37:58.801983 189992 net.cpp:289] Top shape: 32 3 300 300 (8640000)
#
# I0323 08:37:58.802460 189992 net.cpp:289] Top shape: 1 1 2 8 (16)
#
# I0323 08:37:58.802887 189992 net.cpp:297] Memory required for data: 34560064
#
# I0323 08:37:58.803272 189992 layer_factory.hpp:114] Creating layer data_data_0_split
#
# I0323 08:37:58.803472 189992 net.cpp:197] Creating Layer data_data_0_split
#
# I0323 08:37:58.803598 189992 net.cpp:892] data_data_0_split <- data
#
# I0323 08:37:58.803731 189992 net.cpp:866] data_data_0_split -> data_data_0_split_0
#
# I0323 08:37:58.803872 189992 net.cpp:866] data_data_0_split -> data_data_0_split_1
#
# I0323 08:37:58.804003 189992 net.cpp:866] data_data_0_split -> data_data_0_split_2
#
# I0323 08:37:58.804131 189992 net.cpp:866] data_data_0_split -> data_data_0_split_3
#
# I0323 08:37:58.804244 189992 net.cpp:866] data_data_0_split -> data_data_0_split_4
#
# I0323 08:37:58.804388 189992 net.cpp:866] data_data_0_split -> data_data_0_split_5
#
# I0323 08:37:58.804553 189992 net.cpp:866] data_data_0_split -> data_data_0_split_6
#
# I0323 08:37:58.804890 189992 net.cpp:282] Setting up data_data_0_split
#
# I0323 08:37:58.805037 189992 net.cpp:289] Top shape: 32 3 300 300 (8640000)
#
# I0323 08:37:58.805161 189992 net.cpp:289] Top shape: 32 3 300 300 (8640000)
#
# I0323 08:37:58.805258 189992 net.cpp:289] Top shape: 32 3 300 300 (8640000)
#
# I0323 08:37:58.805374 189992 net.cpp:289] Top shape: 32 3 300 300 (8640000)
#
# I0323 08:37:58.805470 189992 net.cpp:289] Top shape: 32 3 300 300 (8640000)
#
# I0323 08:37:58.805555 189992 net.cpp:289] Top shape: 32 3 300 300 (8640000)
#
# I0323 08:37:58.805639 189992 net.cpp:289] Top shape: 32 3 300 300 (8640000)
#
# I0323 08:37:58.805721 189992 net.cpp:297] Memory required for data: 276480064
#
# I0323 08:37:58.805805 189992 layer_factory.hpp:114] Creating layer conv1_1
#
# I0323 08:37:58.805990 189992 net.cpp:197] Creating Layer conv1_1
#
# I0323 08:37:58.806097 189992 net.cpp:892] conv1_1 <- data_data_0_split_0
#
# I0323 08:37:58.806205 189992 net.cpp:866] conv1_1 -> conv1_1
#
# I0323 08:37:59.173032 189992 net.cpp:282] Setting up conv1_1
#
# I0323 08:37:59.173557 189992 net.cpp:289] Top shape: 32 64 300 300 (184320000)
#
# I0323 08:37:59.173985 189992 net.cpp:297] Memory required for data: 1013760064
#
# I0323 08:37:59.174506 189992 layer_factory.hpp:114] Creating layer relu1_1
#
# I0323 08:37:59.174983 189992 net.cpp:197] Creating Layer relu1_1
#
# I0323 08:37:59.175124 189992 net.cpp:892] relu1_1 <- conv1_1
#
# I0323 08:37:59.175237 189992 net.cpp:853] relu1_1 -> conv1_1 (in-place)
#
# I0323 08:37:59.175439 189992 net.cpp:282] Setting up relu1_1
#
# I0323 08:37:59.175540 189992 net.cpp:289] Top shape: 32 64 300 300 (184320000)
#
# I0323 08:37:59.175637 189992 net.cpp:297] Memory required for data: 1751040064
#
# I0323 08:37:59.175721 189992 layer_factory.hpp:114] Creating layer conv1_2
#
# I0323 08:37:59.175870 189992 net.cpp:197] Creating Layer conv1_2
#
# I0323 08:37:59.175956 189992 net.cpp:892] conv1_2 <- conv1_1
#
# I0323 08:37:59.176054 189992 net.cpp:866] conv1_2 -> conv1_2
#
# I0323 08:38:01.219172 189992 net.cpp:282] Setting up conv1_2
#
# I0323 08:38:01.219434 189992 net.cpp:289] Top shape: 32 64 300 300 (184320000)
#
# I0323 08:38:01.219708 189992 net.cpp:297] Memory required for data: 2488320064
#
# I0323 08:38:01.220006 189992 layer_factory.hpp:114] Creating layer relu1_2
#
# I0323 08:38:01.220170 189992 net.cpp:197] Creating Layer relu1_2
#
# I0323 08:38:01.220273 189992 net.cpp:892] relu1_2 <- conv1_2
#
# I0323 08:38:01.220649 189992 net.cpp:853] relu1_2 -> conv1_2 (in-place)
#
# I0323 08:38:01.221017 189992 net.cpp:282] Setting up relu1_2
#
# I0323 08:38:01.221099 189992 net.cpp:289] Top shape: 32 64 300 300 (184320000)
#
# I0323 08:38:01.221197 189992 net.cpp:297] Memory required for data: 3225600064
#
# I0323 08:38:01.221274 189992 layer_factory.hpp:114] Creating layer pool1
#
# I0323 08:38:01.221436 189992 net.cpp:197] Creating Layer pool1
#
# I0323 08:38:01.221529 189992 net.cpp:892] pool1 <- conv1_2
#
# I0323 08:38:01.221626 189992 net.cpp:866] pool1 -> pool1
#
# I0323 08:38:01.221829 189992 net.cpp:282] Setting up pool1
#
# I0323 08:38:01.221909 189992 net.cpp:289] Top shape: 32 64 150 150 (46080000)
#
# I0323 08:38:01.222002 189992 net.cpp:297] Memory required for data: 3409920064
#
# I0323 08:38:01.222092 189992 layer_factory.hpp:114] Creating layer conv2_1
#
# I0323 08:38:01.222252 189992 net.cpp:197] Creating Layer conv2_1
#
# I0323 08:38:01.222326 189992 net.cpp:892] conv2_1 <- pool1
#
# I0323 08:38:01.222463 189992 net.cpp:866] conv2_1 -> conv2_1
#
# I0323 08:38:01.732383 189992 net.cpp:282] Setting up conv2_1
#
# I0323 08:38:01.732542 189992 net.cpp:289] Top shape: 32 128 150 150 (92160000)
#
# I0323 08:38:01.732645 189992 net.cpp:297] Memory required for data: 3778560064
#
# I0323 08:38:01.732969 189992 layer_factory.hpp:114] Creating layer relu2_1
#
# I0323 08:38:01.733106 189992 net.cpp:197] Creating Layer relu2_1
#
# I0323 08:38:01.733186 189992 net.cpp:892] relu2_1 <- conv2_1
#
# I0323 08:38:01.733274 189992 net.cpp:853] relu2_1 -> conv2_1 (in-place)
#
# I0323 08:38:01.733572 189992 net.cpp:282] Setting up relu2_1
#
# I0323 08:38:01.733654 189992 net.cpp:289] Top shape: 32 128 150 150 (92160000)
#
# I0323 08:38:01.733741 189992 net.cpp:297] Memory required for data: 4147200064
#
# I0323 08:38:01.733939 189992 layer_factory.hpp:114] Creating layer conv2_2
#
# I0323 08:38:01.734107 189992 net.cpp:197] Creating Layer conv2_2
#
# I0323 08:38:01.734190 189992 net.cpp:892] conv2_2 <- conv2_1
#
# I0323 08:38:01.734285 189992 net.cpp:866] conv2_2 -> conv2_2
#
# I0323 08:38:02.799928 189992 net.cpp:282] Setting up conv2_2
#
# I0323 08:38:02.800093 189992 net.cpp:289] Top shape: 32 128 150 150 (92160000)
#
# I0323 08:38:02.800192 189992 net.cpp:297] Memory required for data: 4515840064
#
# I0323 08:38:02.800559 189992 layer_factory.hpp:114] Creating layer relu2_2
#
# I0323 08:38:02.800859 189992 net.cpp:197] Creating Layer relu2_2
#
# I0323 08:38:02.800942 189992 net.cpp:892] relu2_2 <- conv2_2
#
# I0323 08:38:02.801237 189992 net.cpp:853] relu2_2 -> conv2_2 (in-place)
#
# I0323 08:38:02.801425 189992 net.cpp:282] Setting up relu2_2
#
# I0323 08:38:02.801707 189992 net.cpp:289] Top shape: 32 128 150 150 (92160000)
#
# I0323 08:38:02.801798 189992 net.cpp:297] Memory required for data: 4884480064
#
# I0323 08:38:02.801882 189992 layer_factory.hpp:114] Creating layer pool2
#
# I0323 08:38:02.802007 189992 net.cpp:197] Creating Layer pool2
#
# I0323 08:38:02.802090 189992 net.cpp:892] pool2 <- conv2_2
#
# I0323 08:38:02.802178 189992 net.cpp:866] pool2 -> pool2
#
# I0323 08:38:02.802371 189992 net.cpp:282] Setting up pool2
#
# I0323 08:38:02.802467 189992 net.cpp:289] Top shape: 32 128 75 75 (23040000)
#
# I0323 08:38:02.802563 189992 net.cpp:297] Memory required for data: 4976640064
#
# I0323 08:38:02.802652 189992 layer_factory.hpp:114] Creating layer conv3_1
#
# I0323 08:38:02.802812 189992 net.cpp:197] Creating Layer conv3_1
#
# I0323 08:38:02.802917 189992 net.cpp:892] conv3_1 <- pool2
#
# I0323 08:38:02.803020 189992 net.cpp:866] conv3_1 -> conv3_1
#
# I0323 08:38:03.087571 189992 net.cpp:282] Setting up conv3_1
#
# I0323 08:38:03.087731 189992 net.cpp:289] Top shape: 32 256 75 75 (46080000)
#
# I0323 08:38:03.087831 189992 net.cpp:297] Memory required for data: 5160960064
#
# I0323 08:38:03.088152 189992 layer_factory.hpp:114] Creating layer relu3_1
#
# I0323 08:38:03.088270 189992 net.cpp:197] Creating Layer relu3_1
#
# I0323 08:38:03.088379 189992 net.cpp:892] relu3_1 <- conv3_1
#
# I0323 08:38:03.088651 189992 net.cpp:853] relu3_1 -> conv3_1 (in-place)
#
# I0323 08:38:03.089025 189992 net.cpp:282] Setting up relu3_1
#
# I0323 08:38:03.089097 189992 net.cpp:289] Top shape: 32 256 75 75 (46080000)
#
# I0323 08:38:03.089386 189992 net.cpp:297] Memory required for data: 5345280064
#
# I0323 08:38:03.089457 189992 layer_factory.hpp:114] Creating layer conv3_2
#
# I0323 08:38:03.089607 189992 net.cpp:197] Creating Layer conv3_2
#
# I0323 08:38:03.089686 189992 net.cpp:892] conv3_2 <- conv3_1
#
# I0323 08:38:03.089787 189992 net.cpp:866] conv3_2 -> conv3_2
#
# I0323 08:38:03.640985 189992 net.cpp:282] Setting up conv3_2
#
# I0323 08:38:03.641158 189992 net.cpp:289] Top shape: 32 256 75 75 (46080000)
#
# I0323 08:38:03.641260 189992 net.cpp:297] Memory required for data: 5529600064
#
# I0323 08:38:03.641619 189992 layer_factory.hpp:114] Creating layer relu3_2
#
# I0323 08:38:03.641885 189992 net.cpp:197] Creating Layer relu3_2
#
# I0323 08:38:03.641964 189992 net.cpp:892] relu3_2 <- conv3_2
#
# I0323 08:38:03.642230 189992 net.cpp:853] relu3_2 -> conv3_2 (in-place)
#
# I0323 08:38:03.642711 189992 net.cpp:282] Setting up relu3_2
#
# I0323 08:38:03.642797 189992 net.cpp:289] Top shape: 32 256 75 75 (46080000)
#
# I0323 08:38:03.642895 189992 net.cpp:297] Memory required for data: 5713920064
#
# I0323 08:38:03.642978 189992 layer_factory.hpp:114] Creating layer conv3_3
#
# I0323 08:38:03.643143 189992 net.cpp:197] Creating Layer conv3_3
#
# I0323 08:38:03.643237 189992 net.cpp:892] conv3_3 <- conv3_2
#
# I0323 08:38:03.643329 189992 net.cpp:866] conv3_3 -> conv3_3
#
# I0323 08:38:04.229750 189992 net.cpp:282] Setting up conv3_3
#
# I0323 08:38:04.229923 189992 net.cpp:289] Top shape: 32 256 75 75 (46080000)
#
# I0323 08:38:04.230022 189992 net.cpp:297] Memory required for data: 5898240064
#
# I0323 08:38:04.230383 189992 layer_factory.hpp:114] Creating layer relu3_3
#
# I0323 08:38:04.230511 189992 net.cpp:197] Creating Layer relu3_3
#
# I0323 08:38:04.230590 189992 net.cpp:892] relu3_3 <- conv3_3
#
# I0323 08:38:04.230834 189992 net.cpp:853] relu3_3 -> conv3_3 (in-place)
#
# I0323 08:38:04.231091 189992 net.cpp:282] Setting up relu3_3
#
# I0323 08:38:04.231381 189992 net.cpp:289] Top shape: 32 256 75 75 (46080000)
#
# I0323 08:38:04.231479 189992 net.cpp:297] Memory required for data: 6082560064
#
# I0323 08:38:04.231552 189992 layer_factory.hpp:114] Creating layer pool3
#
# I0323 08:38:04.231827 189992 net.cpp:197] Creating Layer pool3
#
# I0323 08:38:04.231894 189992 net.cpp:892] pool3 <- conv3_3
#
# I0323 08:38:04.231992 189992 net.cpp:866] pool3 -> pool3
#
# I0323 08:38:04.232147 189992 net.cpp:282] Setting up pool3
#
# I0323 08:38:04.232221 189992 net.cpp:289] Top shape: 32 256 38 38 (11829248)
#
# I0323 08:38:04.232316 189992 net.cpp:297] Memory required for data: 6129877056
#
# I0323 08:38:04.232410 189992 layer_factory.hpp:114] Creating layer conv4_1
#
# I0323 08:38:04.232553 189992 net.cpp:197] Creating Layer conv4_1
#
# I0323 08:38:04.232630 189992 net.cpp:892] conv4_1 <- pool3
#
# I0323 08:38:04.232713 189992 net.cpp:866] conv4_1 -> conv4_1
#
# I0323 08:38:04.444259 189992 net.cpp:282] Setting up conv4_1
#
# I0323 08:38:04.444473 189992 net.cpp:289] Top shape: 32 512 38 38 (23658496)
#
# I0323 08:38:04.444576 189992 net.cpp:297] Memory required for data: 6224511040
#
# I0323 08:38:04.445013 189992 layer_factory.hpp:114] Creating layer relu4_1
#
# I0323 08:38:04.445139 189992 net.cpp:197] Creating Layer relu4_1
#
# I0323 08:38:04.445441 189992 net.cpp:892] relu4_1 <- conv4_1
#
# I0323 08:38:04.445689 189992 net.cpp:853] relu4_1 -> conv4_1 (in-place)
#
# I0323 08:38:04.445844 189992 net.cpp:282] Setting up relu4_1
#
# I0323 08:38:04.445936 189992 net.cpp:289] Top shape: 32 512 38 38 (23658496)
#
# I0323 08:38:04.446018 189992 net.cpp:297] Memory required for data: 6319145024
#
# I0323 08:38:04.446108 189992 layer_factory.hpp:114] Creating layer conv4_2
#
# I0323 08:38:04.446264 189992 net.cpp:197] Creating Layer conv4_2
#
# I0323 08:38:04.446382 189992 net.cpp:892] conv4_2 <- conv4_1
#
# I0323 08:38:04.446483 189992 net.cpp:866] conv4_2 -> conv4_2
#
# I0323 08:38:04.876842 189992 net.cpp:282] Setting up conv4_2
#
# I0323 08:38:04.877008 189992 net.cpp:289] Top shape: 32 512 38 38 (23658496)
#
# I0323 08:38:04.877106 189992 net.cpp:297] Memory required for data: 6413779008
#
# I0323 08:38:04.877490 189992 layer_factory.hpp:114] Creating layer relu4_2
#
# I0323 08:38:04.877626 189992 net.cpp:197] Creating Layer relu4_2
#
# I0323 08:38:04.877720 189992 net.cpp:892] relu4_2 <- conv4_2
#
# I0323 08:38:04.877990 189992 net.cpp:853] relu4_2 -> conv4_2 (in-place)
#
# I0323 08:38:04.878155 189992 net.cpp:282] Setting up relu4_2
#
# I0323 08:38:04.878252 189992 net.cpp:289] Top shape: 32 512 38 38 (23658496)
#
# I0323 08:38:04.878377 189992 net.cpp:297] Memory required for data: 6508412992
#
# I0323 08:38:04.878655 189992 layer_factory.hpp:114] Creating layer conv4_3
#
# I0323 08:38:04.878841 189992 net.cpp:197] Creating Layer conv4_3
#
# I0323 08:38:04.878937 189992 net.cpp:892] conv4_3 <- conv4_2
#
# I0323 08:38:04.879055 189992 net.cpp:866] conv4_3 -> conv4_3
#
# I0323 08:38:05.291780 189992 net.cpp:282] Setting up conv4_3
#
# I0323 08:38:05.291944 189992 net.cpp:289] Top shape: 32 512 38 38 (23658496)
#
# I0323 08:38:05.292043 189992 net.cpp:297] Memory required for data: 6603046976
#
# I0323 08:38:05.292402 189992 layer_factory.hpp:114] Creating layer relu4_3
#
# I0323 08:38:05.292770 189992 net.cpp:197] Creating Layer relu4_3
#
# I0323 08:38:05.292845 189992 net.cpp:892] relu4_3 <- conv4_3
#
# I0323 08:38:05.293097 189992 net.cpp:853] relu4_3 -> conv4_3 (in-place)
#
# I0323 08:38:05.293242 189992 net.cpp:282] Setting up relu4_3
#
# I0323 08:38:05.293314 189992 net.cpp:289] Top shape: 32 512 38 38 (23658496)
#
# I0323 08:38:05.293524 189992 net.cpp:297] Memory required for data: 6697680960
#
# I0323 08:38:05.293594 189992 layer_factory.hpp:114] Creating layer conv4_3_relu4_3_0_split
#
# I0323 08:38:05.293699 189992 net.cpp:197] Creating Layer conv4_3_relu4_3_0_split
#
# I0323 08:38:05.293771 189992 net.cpp:892] conv4_3_relu4_3_0_split <- conv4_3
#
# I0323 08:38:05.293849 189992 net.cpp:866] conv4_3_relu4_3_0_split -> conv4_3_relu4_3_0_split_0
#
# I0323 08:38:05.293939 189992 net.cpp:866] conv4_3_relu4_3_0_split -> conv4_3_relu4_3_0_split_1
#
# I0323 08:38:05.294039 189992 net.cpp:282] Setting up conv4_3_relu4_3_0_split
#
# I0323 08:38:05.294230 189992 net.cpp:289] Top shape: 32 512 38 38 (23658496)
#
# I0323 08:38:05.294313 189992 net.cpp:289] Top shape: 32 512 38 38 (23658496)
#
# I0323 08:38:05.294420 189992 net.cpp:297] Memory required for data: 6886948928
#
# I0323 08:38:05.294502 189992 layer_factory.hpp:114] Creating layer pool4
#
# ...
#
# I0323 08:38:18.738900 189992 net.cpp:289] Top shape: 32 34928 (1117696)
#
# I0323 08:38:18.738979 189992 net.cpp:297] Memory required for data: 7996085696
#
# I0323 08:38:18.739050 189992 layer_factory.hpp:114] Creating layer mbox_conf
#
# I0323 08:38:18.739140 189992 net.cpp:197] Creating Layer mbox_conf
#
# I0323 08:38:18.739210 189992 net.cpp:892] mbox_conf <- conv4_3_norm_mbox_conf_flat
#
# I0323 08:38:18.739285 189992 net.cpp:892] mbox_conf <- fc7_mbox_conf_flat
#
# I0323 08:38:18.739384 189992 net.cpp:892] mbox_conf <- conv6_2_mbox_conf_flat
#
# I0323 08:38:18.739454 189992 net.cpp:892] mbox_conf <- conv7_2_mbox_conf_flat
#
# I0323 08:38:18.739523 189992 net.cpp:892] mbox_conf <- conv8_2_mbox_conf_flat
#
# I0323 08:38:18.739596 189992 net.cpp:892] mbox_conf <- conv9_2_mbox_conf_flat
#
# I0323 08:38:18.739672 189992 net.cpp:866] mbox_conf -> mbox_conf
#
# I0323 08:38:18.739763 189992 net.cpp:282] Setting up mbox_conf
#
# I0323 08:38:18.739830 189992 net.cpp:289] Top shape: 32 183372 (5867904)
#
# I0323 08:38:18.739907 189992 net.cpp:297] Memory required for data: 8019557312
#
# I0323 08:38:18.739975 189992 layer_factory.hpp:114] Creating layer mbox_priorbox
#
# I0323 08:38:18.740057 189992 net.cpp:197] Creating Layer mbox_priorbox
#
# I0323 08:38:18.740124 189992 net.cpp:892] mbox_priorbox <- conv4_3_norm_mbox_priorbox
#
# I0323 08:38:18.740195 189992 net.cpp:892] mbox_priorbox <- fc7_mbox_priorbox
#
# I0323 08:38:18.740265 189992 net.cpp:892] mbox_priorbox <- conv6_2_mbox_priorbox
#
# I0323 08:38:18.740360 189992 net.cpp:892] mbox_priorbox <- conv7_2_mbox_priorbox
#
# I0323 08:38:18.740434 189992 net.cpp:892] mbox_priorbox <- conv8_2_mbox_priorbox
#
# I0323 08:38:18.740505 189992 net.cpp:892] mbox_priorbox <- conv9_2_mbox_priorbox
#
# I0323 08:38:18.740597 189992 net.cpp:866] mbox_priorbox -> mbox_priorbox
#
# I0323 08:38:18.740689 189992 net.cpp:282] Setting up mbox_priorbox
#
# I0323 08:38:18.740756 189992 net.cpp:289] Top shape: 1 2 34928 (69856)
#
# I0323 08:38:18.740831 189992 net.cpp:297] Memory required for data: 8019836736
#
# I0323 08:38:18.740900 189992 layer_factory.hpp:114] Creating layer mbox_conf_reshape
#
# I0323 08:38:18.740998 189992 net.cpp:197] Creating Layer mbox_conf_reshape
#
# I0323 08:38:18.741067 189992 net.cpp:892] mbox_conf_reshape <- mbox_conf
#
# I0323 08:38:18.741147 189992 net.cpp:866] mbox_conf_reshape -> mbox_conf_reshape
#
# I0323 08:38:18.741263 189992 net.cpp:282] Setting up mbox_conf_reshape
#
# I0323 08:38:18.741331 189992 net.cpp:289] Top shape: 32 8732 21 (5867904)
#
# I0323 08:38:18.741432 189992 net.cpp:297] Memory required for data: 8043308352
#
# I0323 08:38:18.741508 189992 layer_factory.hpp:114] Creating layer mbox_conf_softmax
#
# I0323 08:38:18.741590 189992 net.cpp:197] Creating Layer mbox_conf_softmax
#
# I0323 08:38:18.741657 189992 net.cpp:892] mbox_conf_softmax <- mbox_conf_reshape
#
# I0323 08:38:18.741734 189992 net.cpp:866] mbox_conf_softmax -> mbox_conf_softmax
#
# I0323 08:38:18.741869 189992 net.cpp:282] Setting up mbox_conf_softmax
#
# I0323 08:38:18.741941 189992 net.cpp:289] Top shape: 32 8732 21 (5867904)
#
# I0323 08:38:18.742039 189992 net.cpp:297] Memory required for data: 8066779968
#
# I0323 08:38:18.742107 189992 layer_factory.hpp:114] Creating layer mbox_conf_flatten
#
# I0323 08:38:18.742187 189992 net.cpp:197] Creating Layer mbox_conf_flatten
#
# I0323 08:38:18.742254 189992 net.cpp:892] mbox_conf_flatten <- mbox_conf_softmax
#
# I0323 08:38:18.742331 189992 net.cpp:866] mbox_conf_flatten -> mbox_conf_flatten
#
# I0323 08:38:18.742452 189992 net.cpp:282] Setting up mbox_conf_flatten
#
# I0323 08:38:18.742517 189992 net.cpp:289] Top shape: 32 183372 (5867904)
#
# I0323 08:38:18.742694 189992 net.cpp:297] Memory required for data: 8090251584
#
# I0323 08:38:18.742770 189992 layer_factory.hpp:114] Creating layer detection_out
#
# I0323 08:38:18.742887 189992 net.cpp:197] Creating Layer detection_out
#
# I0323 08:38:18.742959 189992 net.cpp:892] detection_out <- mbox_loc
#
# I0323 08:38:18.743036 189992 net.cpp:892] detection_out <- mbox_conf_flatten
#
# I0323 08:38:18.743108 189992 net.cpp:892] detection_out <- mbox_priorbox
#
# I0323 08:38:18.743204 189992 net.cpp:866] detection_out -> detection_out
#
# I0323 08:38:18.792208 189992 net.cpp:282] Setting up detection_out
#
# I0323 08:38:18.792671 189992 net.cpp:289] Top shape: 1 1 1 7 (7)
#
# I0323 08:38:18.792912 189992 net.cpp:297] Memory required for data: 8090251612
#
# I0323 08:38:18.793151 189992 layer_factory.hpp:114] Creating layer detection_eval
#
# I0323 08:38:18.793455 189992 net.cpp:197] Creating Layer detection_eval
#
# I0323 08:38:18.793551 189992 net.cpp:892] detection_eval <- detection_out
#
# I0323 08:38:18.793638 189992 net.cpp:892] detection_eval <- label
#
# I0323 08:38:18.793725 189992 net.cpp:866] detection_eval -> detection_eval
#
# I0323 08:38:18.793887 189992 net.cpp:282] Setting up detection_eval
#
# I0323 08:38:18.793970 189992 net.cpp:289] Top shape: 1 1 21 5 (105)
#
# I0323 08:38:18.794059 189992 net.cpp:297] Memory required for data: 8090252032
#
# I0323 08:38:18.794132 189992 net.cpp:361] detection_eval does not need backward computation.
#
# I0323 08:38:18.794215 189992 net.cpp:361] detection_out does not need backward computation.
#
# I0323 08:38:18.794286 189992 net.cpp:361] mbox_conf_flatten does not need backward computation.
#
# I0323 08:38:18.794394 189992 net.cpp:361] mbox_conf_softmax does not need backward computation.
#
# I0323 08:38:18.794469 189992 net.cpp:361] mbox_conf_reshape does not need backward computation.
#
# I0323 08:38:18.794538 189992 net.cpp:361] mbox_priorbox does not need backward computation.
#
# I0323 08:38:18.794611 189992 net.cpp:361] mbox_conf does not need backward computation.
#
# I0323 08:38:18.794683 189992 net.cpp:361] mbox_loc does not need backward computation.
#
# I0323 08:38:18.794757 189992 net.cpp:361] conv9_2_mbox_priorbox does not need backward computation.
#
# I0323 08:38:18.794826 189992 net.cpp:361] conv9_2_mbox_conf_flat does not need backward computation.
#
# I0323 08:38:18.794894 189992 net.cpp:361] conv9_2_mbox_conf_perm does not need backward computation.
#
# I0323 08:38:18.794970 189992 net.cpp:361] conv9_2_mbox_conf does not need backward computation.
#
# I0323 08:38:18.795040 189992 net.cpp:361] conv9_2_mbox_loc_flat does not need backward computation.
#
# I0323 08:38:18.795110 189992 net.cpp:361] conv9_2_mbox_loc_perm does not need backward computation.
#
# I0323 08:38:18.795177 189992 net.cpp:361] conv9_2_mbox_loc does not need backward computation.
#
# I0323 08:38:18.795245 189992 net.cpp:361] conv8_2_mbox_priorbox does not need backward computation.
#
# I0323 08:38:18.795315 189992 net.cpp:361] conv8_2_mbox_conf_flat does not need backward computation.
#
# I0323 08:38:18.795406 189992 net.cpp:361] conv8_2_mbox_conf_perm does not need backward computation.
#
# I0323 08:38:18.795476 189992 net.cpp:361] conv8_2_mbox_conf does not need backward computation.
#
# I0323 08:38:18.795543 189992 net.cpp:361] conv8_2_mbox_loc_flat does not need backward computation.
#
# I0323 08:38:18.795610 189992 net.cpp:361] conv8_2_mbox_loc_perm does not need backward computation.
#
# I0323 08:38:18.795677 189992 net.cpp:361] conv8_2_mbox_loc does not need backward computation.
#
# I0323 08:38:18.795744 189992 net.cpp:361] conv7_2_mbox_priorbox does not need backward computation.
#
# I0323 08:38:18.795814 189992 net.cpp:361] conv7_2_mbox_conf_flat does not need backward computation.
#
# I0323 08:38:18.795882 189992 net.cpp:361] conv7_2_mbox_conf_perm does not need backward computation.
#
# I0323 08:38:18.795948 189992 net.cpp:361] conv7_2_mbox_conf does not need backward computation.
#
# I0323 08:38:18.796016 189992 net.cpp:361] conv7_2_mbox_loc_flat does not need backward computation.
#
# I0323 08:38:18.796085 189992 net.cpp:361] conv7_2_mbox_loc_perm does not need backward computation.
#
# I0323 08:38:18.796154 189992 net.cpp:361] conv7_2_mbox_loc does not need backward computation.
#
# I0323 08:38:18.796317 189992 net.cpp:361] conv6_2_mbox_priorbox does not need backward computation.
#
# I0323 08:38:18.796407 189992 net.cpp:361] conv6_2_mbox_conf_flat does not need backward computation.
#
# I0323 08:38:18.796476 189992 net.cpp:361] conv6_2_mbox_conf_perm does not need backward computation.
#
# I0323 08:38:18.796545 189992 net.cpp:361] conv6_2_mbox_conf does not need backward computation.
#
# I0323 08:38:18.796612 189992 net.cpp:361] conv6_2_mbox_loc_flat does not need backward computation.
#
# I0323 08:38:18.796680 189992 net.cpp:361] conv6_2_mbox_loc_perm does not need backward computation.
#
# I0323 08:38:18.796748 189992 net.cpp:361] conv6_2_mbox_loc does not need backward computation.
#
# I0323 08:38:18.796816 189992 net.cpp:361] fc7_mbox_priorbox does not need backward computation.
#
# I0323 08:38:18.796885 189992 net.cpp:361] fc7_mbox_conf_flat does not need backward computation.
#
# I0323 08:38:18.796952 189992 net.cpp:361] fc7_mbox_conf_perm does not need backward computation.
#
# I0323 08:38:18.797019 189992 net.cpp:361] fc7_mbox_conf does not need backward computation.
#
# I0323 08:38:18.797086 189992 net.cpp:361] fc7_mbox_loc_flat does not need backward computation.
#
# I0323 08:38:18.797155 189992 net.cpp:361] fc7_mbox_loc_perm does not need backward computation.
#
# I0323 08:38:18.797224 189992 net.cpp:361] fc7_mbox_loc does not need backward computation.
#
# I0323 08:38:18.797291 189992 net.cpp:361] conv4_3_norm_mbox_priorbox does not need backward computation.
#
# I0323 08:38:18.797381 189992 net.cpp:361] conv4_3_norm_mbox_conf_flat does not need backward computation.
#
# I0323 08:38:18.797452 189992 net.cpp:361] conv4_3_norm_mbox_conf_perm does not need backward computation.
#
# I0323 08:38:18.797524 189992 net.cpp:361] conv4_3_norm_mbox_conf does not need backward computation.
#
# I0323 08:38:18.797593 189992 net.cpp:361] conv4_3_norm_mbox_loc_flat does not need backward computation.
#
# I0323 08:38:18.797660 189992 net.cpp:361] conv4_3_norm_mbox_loc_perm does not need backward computation.
#
# I0323 08:38:18.797729 189992 net.cpp:361] conv4_3_norm_mbox_loc does not need backward computation.
#
# I0323 08:38:18.797798 189992 net.cpp:361] conv4_3_norm_conv4_3_norm_0_split does not need backward computation.
#
# I0323 08:38:18.797865 189992 net.cpp:361] conv4_3_norm does not need backward computation.
#
# I0323 08:38:18.797935 189992 net.cpp:361] conv9_2_conv9_2_relu_0_split does not need backward computation.
#
# I0323 08:38:18.798002 189992 net.cpp:361] conv9_2_relu does not need backward computation.
#
# I0323 08:38:18.798069 189992 net.cpp:361] conv9_2 does not need backward computation.
#
# I0323 08:38:18.798137 189992 net.cpp:361] conv9_1_relu does not need backward computation.
#
# I0323 08:38:18.798203 189992 net.cpp:361] conv9_1 does not need backward computation.
#
# I0323 08:38:18.798272 189992 net.cpp:361] conv8_2_conv8_2_relu_0_split does not need backward computation.
#
# I0323 08:38:18.798358 189992 net.cpp:361] conv8_2_relu does not need backward computation.
#
# I0323 08:38:18.798426 189992 net.cpp:361] conv8_2 does not need backward computation.
#
# I0323 08:38:18.798494 189992 net.cpp:361] conv8_1_relu does not need backward computation.
#
# I0323 08:38:18.798560 189992 net.cpp:361] conv8_1 does not need backward computation.
#
# I0323 08:38:18.798629 189992 net.cpp:361] conv7_2_conv7_2_relu_0_split does not need backward computation.
#
# I0323 08:38:18.798696 189992 net.cpp:361] conv7_2_relu does not need backward computation.
#
# I0323 08:38:18.798763 189992 net.cpp:361] conv7_2 does not need backward computation.
#
# I0323 08:38:18.798830 189992 net.cpp:361] conv7_1_relu does not need backward computation.
#
# I0323 08:38:18.798897 189992 net.cpp:361] conv7_1 does not need backward computation.
#
# I0323 08:38:18.798966 189992 net.cpp:361] conv6_2_conv6_2_relu_0_split does not need backward computation.
#
# I0323 08:38:18.799034 189992 net.cpp:361] conv6_2_relu does not need backward computation.
#
# I0323 08:38:18.799101 189992 net.cpp:361] conv6_2 does not need backward computation.
#
# I0323 08:38:18.799167 189992 net.cpp:361] conv6_1_relu does not need backward computation.
#
# I0323 08:38:18.799235 189992 net.cpp:361] conv6_1 does not need backward computation.
#
# I0323 08:38:18.799360 189992 net.cpp:361] fc7_relu7_0_split does not need backward computation.
#
# I0323 08:38:18.799432 189992 net.cpp:361] relu7 does not need backward computation.
#
# I0323 08:38:18.799504 189992 net.cpp:361] fc7 does not need backward computation.
#
# I0323 08:38:18.799576 189992 net.cpp:361] relu6 does not need backward computation.
#
# I0323 08:38:18.799643 189992 net.cpp:361] fc6 does not need backward computation.
#
# I0323 08:38:18.799715 189992 net.cpp:361] pool5 does not need backward computation.
#
# I0323 08:38:18.799784 189992 net.cpp:361] relu5_3 does not need backward computation.
#
# I0323 08:38:18.799852 189992 net.cpp:361] conv5_3 does not need backward computation.
#
# I0323 08:38:18.799921 189992 net.cpp:361] relu5_2 does not need backward computation.
#
# I0323 08:38:18.799988 189992 net.cpp:361] conv5_2 does not need backward computation.
#
# I0323 08:38:18.800056 189992 net.cpp:361] relu5_1 does not need backward computation.
#
# I0323 08:38:18.800122 189992 net.cpp:361] conv5_1 does not need backward computation.
#
# I0323 08:38:18.800190 189992 net.cpp:361] pool4 does not need backward computation.
#
# I0323 08:38:18.800259 189992 net.cpp:361] conv4_3_relu4_3_0_split does not need backward computation.
#
# I0323 08:38:18.800328 189992 net.cpp:361] relu4_3 does not need backward computation.
#
# I0323 08:38:18.800427 189992 net.cpp:361] conv4_3 does not need backward computation.
#
# I0323 08:38:18.800495 189992 net.cpp:361] relu4_2 does not need backward computation.
#
# I0323 08:38:18.800562 189992 net.cpp:361] conv4_2 does not need backward computation.
#
# I0323 08:38:18.800631 189992 net.cpp:361] relu4_1 does not need backward computation.
#
# I0323 08:38:18.800698 189992 net.cpp:361] conv4_1 does not need backward computation.
#
# I0323 08:38:18.800762 189992 net.cpp:361] pool3 does not need backward computation.
#
# I0323 08:38:18.800830 189992 net.cpp:361] relu3_3 does not need backward computation.
#
# I0323 08:38:18.800896 189992 net.cpp:361] conv3_3 does not need backward computation.
#
# I0323 08:38:18.800966 189992 net.cpp:361] relu3_2 does not need backward computation.
#
# I0323 08:38:18.801033 189992 net.cpp:361] conv3_2 does not need backward computation.
#
# I0323 08:38:18.801103 189992 net.cpp:361] relu3_1 does not need backward computation.
#
# I0323 08:38:18.801174 189992 net.cpp:361] conv3_1 does not need backward computation.
#
# I0323 08:38:18.801244 189992 net.cpp:361] pool2 does not need backward computation.
#
# I0323 08:38:18.801313 189992 net.cpp:361] relu2_2 does not need backward computation.
#
# I0323 08:38:18.801403 189992 net.cpp:361] conv2_2 does not need backward computation.
#
# I0323 08:38:18.801478 189992 net.cpp:361] relu2_1 does not need backward computation.
#
# I0323 08:38:18.801553 189992 net.cpp:361] conv2_1 does not need backward computation.
#
# I0323 08:38:18.801628 189992 net.cpp:361] pool1 does not need backward computation.
#
# I0323 08:38:18.801702 189992 net.cpp:361] relu1_2 does not need backward computation.
#
# I0323 08:38:18.801776 189992 net.cpp:361] conv1_2 does not need backward computation.
#
# I0323 08:38:18.801852 189992 net.cpp:361] relu1_1 does not need backward computation.
#
# I0323 08:38:18.801926 189992 net.cpp:361] conv1_1 does not need backward computation.
#
# I0323 08:38:18.802002 189992 net.cpp:361] data_data_0_split does not need backward computation.
#
# I0323 08:38:18.802074 189992 net.cpp:361] data does not need backward computation.
#
# I0323 08:38:18.802141 189992 net.cpp:403] This network produces output detection_eval
#
# I0323 08:38:18.802451 189992 net.cpp:496] Network initialization done.
#
# I0323 08:38:18.804152 189992 solver.cpp:122] Solver scaffolding done.
#
# I0323 08:38:18.804877 189992 caffe.cpp:324] Starting Optimization
#
# I0323 08:38:18.804973 189992 solver.cpp:495] Solving VGG_VOC0712_SSD_300x300_train
#
# I0323 08:38:18.805043 189992 solver.cpp:496] Learning Rate Policy: exp
#
# E0323 08:38:18.849820 189992 data_transformer.cpp:669] Only support encoded datum now
#
# *** Aborted at 1490284530 (unix time) try "date -d @1490284530" if you are using GNU date ***
#
#
#
# qsub: job 4232.c001 completed
