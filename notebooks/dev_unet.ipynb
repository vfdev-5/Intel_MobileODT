# %% [markdown]
# # Tryouts with U-net NN

# %%
# https://ipython.org/ipython-doc/3/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../common')

# %%
from unet import get_unet
# Out:
# Using Theano backend.
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# Using gpu device 0: GeForce GT 750M (CNMeM is enabled with initial size: 50.0% of memory, cuDNN 5103)

# %%
unet = get_unet()
unet.summary()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-20-7feb03e6e86a> in <module>()
# ----> 1 unet = get_unet()
#       2 unet.summary()
#
# /Users/vfomin/Documents/ML/Kaggle/Intel_MobileODT/common/unet.py in get_unet(image_size, n_filters)
#      62
#      63     model = Model(inputs=inputs, outputs=outputs)
# ---> 64     model.compile(loss='categorical_crossentropy', optimizer='adadelta', metrics=['accuracy', 'recall', 'precision'])
#      65     return model
#
# /usr/local/lib/python2.7/site-packages/keras/engine/training.pyc in compile(self, optimizer, loss, metrics, loss_weights, sample_weight_mode, **kwargs)
#     952                     append_metric(i, 'acc', masked_fn(y_true, y_pred, mask=masks[i]))
#     953                 else:
# --> 954                     metric_fn = metrics_module.get(metric)
#     955                     masked_metric_fn = _masked_objective(metric_fn)
#     956                     metric_result = masked_metric_fn(y_true, y_pred, mask=masks[i])
#
# /usr/local/lib/python2.7/site-packages/keras/metrics.pyc in get(identifier)
#      57     if isinstance(identifier, six.string_types):
#      58         identifier = str(identifier)
# ---> 59         return deserialize(identifier)
#      60     elif callable(identifier):
#      61         return identifier
#
# /usr/local/lib/python2.7/site-packages/keras/metrics.pyc in deserialize(name, custom_objects)
#      51                                     module_objects=globals(),
#      52                                     custom_objects=custom_objects,
# ---> 53                                     printable_module_name='metric function')
#      54
#      55
#
# /usr/local/lib/python2.7/site-packages/keras/utils/generic_utils.pyc in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     155             if fn is None:
#     156                 raise ValueError('Unknown ' + printable_module_name,
# --> 157                                  ':' + class_name)
#     158         return fn
#     159     else:
#
# UnboundLocalError: local variable 'class_name' referenced before assignment

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(unet, show_shapes=True).create(prog='dot', format='svg'))
